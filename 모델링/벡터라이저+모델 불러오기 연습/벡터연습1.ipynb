# %%
from konlpy.tag import Okt
from sklearn.feature_extraction.text import TfidfVectorizer

#이안에 불용어제거하는 속성있음
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
import pickle

corpus = [
    '아 더빙.. 진짜 짜증나네요 목소리',
    '흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나',
    '너무재밓었다그래서보는것을추천한다',
    '교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정',
]

#1. okt().morphs 토큰화를 먼저하고 저장
okt = Okt()
tokenized_corpus = [okt.morphs(text) for text in corpus]

tokenized_corpus
# tokenized_corpus
# okt.morphs(tokenized_corpus)

#===========여기쯤에 텍스트 클리닝===========

# 2. vectorizer도 저장된 토큰에 fit_transform하고 저장\
test_vectorizer = TfidfVectorizer()
X = test_vectorizer.fit_transform(tokenized_corpus)
print(X.toarray())  #형태 확인

# vectorizer 객체를 저장
with open('test_vectorizer.pkl', 'wb') as f:
    pickle.dump(test_vectorizer, f)

# 저장된 vectorizer 객체를 불러오기
with open('test_vectorizer.pkl', 'rb') as f:
    loaded_test_vectorizer = pickle.load(f)

# loaded_vectorizer를 사용하여 텍스트를 변환할 수 있습니다.

test_corpus = ['교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정']
X_new = loaded_test_vectorizer.transform(new_clean_texts)
# Out:
# [['아', '더빙', '..', '진짜', '짜증나네요', '목소리'],
#  ['흠',
#   '...',
#   '포스터',
#   '보고',
#   '초딩',
#   '영화',
#   '줄',
#   '....',
#   '오버',
#   '연기',
#   '조차',
#   '가볍지',
#   '않구나'],
#  ['너', '무재', '밓었', '다그', '래서', '보는것을', '추천', '한', '다'],
#  ['교도소', '이야기', '구먼', '..', '솔직히', '재미', '는', '없다', '..', '평점', '조정']]

# %%
a= ['교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정']

# from konlpy.tag import Okt

# aaa=Okt().morphs(a[0])
# print(aaa)
# test_vectorizer = TfidfVectorizer(tokenizer=aaa)
#토큰화된 데이터 자체를 토크나이저 속성으로 가져간다.
tes1_vectorizer
# Out:
# TfidfVectorizer(tokenizer=['교도소', '이야기', '구먼', '..', '솔직히', '재미', '는', '없다',
#                            '..', '평점', '조정'])

# %%
#토근화된 데이터를 저장하였음
with open('test_vectorizer.pkl','wb') as f:
    pickle.dump(test1_vectorizer,f)

# %%
#토큰화된 데이터 불러오기
with open('test1_vectorizer.pkl','rb') as f:
    test1_vectorizer_loaded = pickle.load(f)

test1_vectorizer_loaded

# %% [markdown]
# 1. okt().morphs 토큰화를 먼저하고 저장
# 2. tfidfvectorizer 속성에 저장된 토큰들 넣기
# 3. vectorizer도 저장된 토큰에 fit_transform하고 저장
# 그러면 모델학습 테스트 데이터
# 1. 테스트 데이터들 okt().morphs 토큰화를 먼저하고
# 2. 불러온 vectorizer객체에 transform()해서 model.predict에 넣기

# %%
import tensorflow as tf
import numpy as np

#1. Naver Sentiment Movie Corpus v1.0 다운로드
train_file = tf.keras.utils.get_file('train.txt', 'https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt')

#파일을 이진모드로 읽어온다. 디코드는 utf8로한다.
train_text = open(train_file,'rb').read().decode(encoding='utf-8')

import pandas as pd

df_train = pd.DataFrame({
    'feature':[row.split('\t')[1] for row in train_text.split('\n')[1:] if row.count('\t')>0],
    'target': [ int(row.split('\t')[2]) for row in train_text.split('\n')[1:] if row.count('\t')>0]
})
#데이터 조금만가져오기
df_train = df_train[::6]

# %%
#다시정리
# 1. okt().morphs 토큰화를 먼저하고 저장
from konlpy.tag import Okt
tokenized_data =[]
for i in df_train.iloc[:,0]:
    tokenized_data.append(Okt().morphs( i ))

tokenized_data
# Out:
# [['아', '더빙', '..', '진짜', '짜증나네요', '목소리'],
#  ['원작', '의', '긴장감', '을', '제대로', '살려내지못', '했다', '.'],
#  ['울면',
#   '서',
#   '손',
#   '들',
#   '고',
#   '횡단보도',
#   '건널',
#   '때',
#   '뛰',
#   '쳐나',
#   '올',
#   '뻔',
#   '이범수',
#   '연기',
#   '드럽게',
#   '못',
#   '해'],
#  ['이건',
#   '정말',
#   '깨알',
#   '캐스팅',
#   '과',
#   '질퍽',
#   '하',
#   '지',
#   '않은',
#   '산뜻한',
#   '내',
#   '용구성',
#   '이',
#   '잘',
#   '버무러진',
#   '깨알',
#   '일드',
#   '!!',
#   '♥'],
#  ['주제', '는', '좋은데', '중반', '부터', '지루하다'],
#  ['엄포스',
#   '의',
#   '위력',
#   '을',
#   '다시',
#   '한번',
#   '깨닫게',
#   '해준',
#   '적',
#   '.',
#   '남',
#   '꽃',
#   '검사',
#   '님',
#   '도',
#   '연기',
#   '정말',
#   '좋았어요',
#   '!',
#   '완전',
#   '명품',
#   '드라마',
#   '!'],
#  ['키이라', '나이틀리', '가', '연기', '하고자', '했던건', '대체', '정신장애', '일까', '틱장애', '일까'],
#  ['오게', '두어라', '!', '서리', '한', '이', '굶주렸다', '!'],
#  ['난', '우리', '영화', '를', '사랑', '합니다', '....^^;'],
#  ['재미있어요'],
#  ['보는내내', '그대로', '들어맞는', '예측', '카리스마', '없는', '악역'],
#  ['예전',
#   '작품',
#   '캐릭터',
#   ',',
#   '에피소드',
#   '재탕',
#   '삼',
#   '탕',
#   '사골',
#   '우려',
#   '먹듯',
#   '우리',
#   '고',
#   '내용',
#   '은',
#   '산',
#   '으로',
#   '가고',
#   '시청률',
#   '은',
#   '아예',
#   '안',
#   '나오고',
#   '이제',
#   '70회',
#   '중반인데',
#   '120',
#   '부작',
#   '이라니',
#   '...'],
#  ['졸작'],
#  ['한국영',
#   '화',
#   '흥행',
#   '코드',
#   ':',
#   '갈등',
#   '-',
#   '갈등',
#   '-',
#   '계',
#   '~',
#   '에',
#   '속',
#   '갈등',
#   '-',
#   '화해',
#   '-',
#   '감동',
#   '-',
#   '평점',
#   '10',
#   '점',
#   '남발',
#   '-',
#   '흥행',
#   '뻔하지',
#   '뭐',
#   '...'],
#  ['정말', '쓰레기', '영화', '입니다'],
#  ['성룡', '영화', '중', '최악', '인', '듯', 'ㅋㅋ'],
#  ['재미있는', '영화', '입니다', '.'],
#  ['잔잔한게', '생각', '보다', '볼', '만', '한', '영화', '인거', '같습니다', 'ㅋ'],
#  ['재미있게',
#   '봤습니다',
#   '.',
#   '매력',
#   '적',
#   '인',
#   '행복',
#   '이네',
#   '요',
#   ',',
#   "'-'",
#   'ㅎㅎㅎ',
#   '.'],
#  ['시청률',
#   '기준',
#   '이',
#   '되는',
#   '패널',
#   '가구',
#   '들',
#   '머',
#   '하는거지',
#   '명작',
#   '드라마',
#   '다',
#   '망치',
#   '네',
#   'ㅡㅡ',
#   '내',
#   '가',
#   '다',
#   '서운하다',
#   '...'],
#  ['중국인',
#   '특유',
#   '의',
#   '과장',
#   ',',
#   '허풍',
#   '...',
#   '있어',
#   '보이려고',
#   '안간힘',
#   '쓴',
#   '노력',
#   '은',
#   '가상하나',
#   ',',
#   '고증',
#   '과',
#   '현',
#   '실감',
#   '떨어지는',
#   '설정',
#   '이',
#   '거북',
#   '스럽다',
#   '...',
#   '도대체',
#   '그',
#   '들',
#   '은',
#   '왜',
#   '이렇게',
#   '까지',
#   '스스로',
#   '를',
#   '과대',
#   '포장',
#   '하',
#   '는',
#   '것',
#   '인지',
#   '...'],
#  ['아니', '이', '게', '왜', '9', '점', '대', '일까', '...;;;'],
#  ['아주', '모자라진', '않다', '.'],
#  ['다르덴',
#   ',',
#   '이냐리',
#   '투',
#   ',',
#   '차이밍량',
#   '이',
#   '하나',
#   '도',
#   '안',
#   '섞인',
#   '채',
#   '짬뽕',
#   '그릇',
#   '에',
#   '담겨있다',
#   '.'],
#  ['재미있다고', '허풍', '떨지', '마세요'],
#  ['그만', '좀', '끌', '고', '이제', '끝내', '라', '.', '지겹다', '지겨워', '.'],
#  ['배우',
#   '들',
#   '은',
#   '지네',
#   '들',
#   '안',
#   '뜨니까',
#   '이런',
#   '영화',
#   '찍을껀데',
#   '???',
#   '왜',
#   '안',
#   '뜨는지',
#   '진짜',
#   '모르는거야',
#   '?',
#   '면상',
#   '딱',
#   '보면',
#   '알겠구만',
#   '...',
#   '왜',
#   '지네',
#   '자신',
#   '들',
#   '은',
#   '모를까',
#   '?'],
#  ['오랜', '만', '에', '재밋', '는', '영화', '봤네요'],
#  ['소파', '에', '죽', '치고', '앉아', '지켜', '볼', '이유', '가', '없는', '작품', '.'],
#  ['알바', '는', '꺼', '저', '라'],
#  ['정말',
#   '짜증',
#   '의',
#   '극치',
#   '를',
#   '보여주는',
#   '영화',
#   '.',
#   '굉장히',
#   '언밸러스',
#   '한',
#   '느낌',
#   '.',
#   '뚱뚱하고',
#   '못',
#   '생긴',
#   '남자',
#   '애',
#   '의',
#   '발연기',
#   '를',
#   '시종일관',
#   '봐야하는게',
#   '고역',
#   '인',
#   '듯',
#   '.',
#   '간간히',
#   '흘러나오는',
#   '잔잔한',
#   '클래식',
#   '풍',
#   '의',
#   '음악',
#   '조차도',
#   '듣기',
#   '싫어',
#   '짜증날',
#   '정도',
#   '로',
#   '상당히',
#   '싫은',
#   '영화',
#   '.'],
#  ['유치하고', '지루하고', '잠', '이', '왔다'],
#  ['기존',
#   '멜로영화',
#   '형식',
#   '을',
#   '탈피',
#   '하려고',
#   '하였으나',
#   '감정',
#   '의',
#   '절제',
#   '가',
#   '지나쳐',
#   '너무',
#   '담백한',
#   '영화'],
#  ['넘',
#   '사랑스러운',
#   '영화',
#   '다',
#   'ㅠㅠ',
#   '1',
#   '보고',
#   '2',
#   '연',
#   '이',
#   '어',
#   '봤다',
#   '~!!',
#   '넘',
#   '귀여워',
#   'ㅠㅠ',
#   '♥♥'],
#  ['새벽',
#   '시간',
#   '에',
#   '하는',
#   '일본',
#   '영화',
#   '들',
#   '은',
#   '전부',
#   '개',
#   '졸작',
#   '이다',
#   '.',
#   '일',
#   '본',
#   '영화',
#   '원',
#   '래',
#   '다',
#   '이래',
#   '??'],
#  ['감동', '적', '인', '영화'],
#  ['아',
#   '너무',
#   '웃기',
#   '고',
#   '배꼽',
#   '빠질',
#   '뻔했네',
#   '^^',
#   '내',
#   '컴',
#   '에',
#   '이',
#   '영화',
#   '있는데',
#   '^^'],
#  ['더럽게',
#   '재미없다',
#   '어떤',
#   '형태',
#   '로',
#   '도',
#   '와',
#   '닿지',
#   '않는',
#   '허무하고',
#   '완벽히',
#   '지루한',
#   '영화',
#   '고',
#   '영양가',
#   '하나',
#   '도',
#   '없는',
#   '영화',
#   '다'],
#  ['영화',
#   '를',
#   '보는것만으로도',
#   '마음',
#   '의',
#   '휴가',
#   '를',
#   '다녀온',
#   '느낌',
#   '.',
#   '소박하지고',
#   '잔잔하지만',
#   '지루하지',
#   '않은',
#   '..',
#   '그래서',
#   '다시',
#   '보고싶은',
#   '영화',
#   '.',
#   '햇살',
#   '가득한',
#   '비',
#   '이의',
#   '부엌',
#   '과',
#   '요리',
#   '도',
#   '인상',
#   '적'],
#  ['정치인', '의', '모순', '인가', ',', '정치범', '의', '모순', '인가', '....'],
#  ['푸하하하', '이', '거', '기대', '안', '했지만', '..', '역시', '나', '구만', '..', 'ㅋ'],
#  ['드럽게', '재미없네', '시간', '이', '돈', '이다', '?', '내', '시간', '은', '어쩔', '건데'],
#  ['아', '진짜', '너무', '좋아요', 'ㅜㅜ', '짱짱', '!!!'],
#  ['액션영화',
#   '가',
#   '아니다',
#   '.',
#   '범죄',
#   '느와르',
#   '영화',
#   '다',
#   '.',
#   '허나',
#   '범죄',
#   '느와르',
#   '영화로서도',
#   '실패',
#   '작',
#   '.......'],
#  ['또', '보고', '싶은데', '어디서', '보죠', '???'],
#  ['좋은', '영화'],
#  ['정은지',
#   '언니',
#   '!!',
#   '연기',
#   '잘',
#   '하구',
#   '..',
#   '노래',
#   '도',
#   '잘',
#   '부르시고',
#   '!',
#   '마지막',
#   '회',
#   '웃으면서',
#   '즐겁게',
#   '!',
#   '봤습니다',
#   '!',
#   '트로트',
#   '의',
#   '연인',
#   '!',
#   '♥'],
#  ['여',
#   '주인공',
#   '인터뷰',
#   '할',
#   '때',
#   '지루해',
#   '죽는줄',
#   '알았음',
#   'ㅡㅡ',
#   '그냥',
#   '저',
#   '냥',
#   '킬링타임',
#   '용',
#   '스릴러'],
#  ['스토리',
#   '도',
#   '말',
#   '이',
#   '안되고',
#   '개막',
#   '장',
#   '사랑',
#   '이야기',
#   '도',
#   '아니예요',
#   '이',
#   '걸',
#   '보고',
#   '계신다면',
#   '당신',
#   '의',
#   '시간',
#   '과',
#   '돈',
#   '을',
#   '아낀거예요',
#   '^.^',
#   '휴',
#   '그래도',
#   '본다면',
#   '호구'],
#  ['나이', '들', '수록', '이해', '가', '가는', '영화'],
#  ['일본',
#   '영화',
#   '수입',
#   '금지',
#   '시절',
#   '에도',
#   '비디오',
#   '테이프',
#   '로',
#   '돌려',
#   '봤던',
#   '불후',
#   '의',
#   '명작',
#   '아',
#   '그립다'],
#  ['지금', '이', '거', '티비', '로', '돈', '내고', '보고있는', '내', '가', '한심하다'],
#  ['잊을', '수', '없는', '안개', '낀', '워터', '루', '다리', '와', '마스코트', '.'],
#  ['비디오',
#   '가',
#   '있어서',
#   '봤는데',
#   '1997년',
#   '도인줄모를정도로',
#   '잘',
#   '만들었습니다',
#   '긴장감',
#   '도',
#   '있고'],
#  ['고', '다미', '괜찮음'],
#  ['줄리아', '로버츠', '귀여운', '연인', '은', '이', '거', '보다', '5년', '전꺼다', '...'],
#  ['여자애',
#   '한',
#   '명',
#   '이',
#   '잘',
#   '못',
#   '해서',
#   '몇',
#   '명',
#   '이',
#   '죽는거야',
#   'ㅋㅋ',
#   '답',
#   '도',
#   '없다',
#   'ㅋ'],
#  ['국산',
#   '코미디',
#   '영화',
#   '중',
#   '에서',
#   '난',
#   '신라',
#   '의',
#   '달밤',
#   '이',
#   '제일',
#   '좋았음',
#   '뭔가',
#   '푸근하고',
#   '따뜻함',
#   '..'],
#  ['대한민국',
#   '영화',
#   '수준',
#   '의',
#   '평균',
#   '치를',
#   '하락',
#   '시키기에',
#   '충분한',
#   'C',
#   '급',
#   '영상',
#   '물'],
#  ['네러티브',
#   '는',
#   '하나',
#   '도',
#   '없는',
#   '예쁜',
#   '음악',
#   '동영상',
#   '.',
#   '취미',
#   '로',
#   '영화',
#   '만드는',
#   '것',
#   '은',
#   '이',
#   '걸',
#   '로',
#   '끝나길',
#   '.',
#   '잘',
#   '하는',
#   '음악',
#   '에',
#   '올인',
#   '하길',
#   '.'],
#  ['무섭지도', '않고', '기분', '만', '나쁘고', '쩝'],
#  ['왜',
#   '극',
#   '을',
#   '끌어가는',
#   '중심',
#   '있는',
#   '캐릭터',
#   '가',
#   '있어야',
#   '하는지',
#   '알',
#   '게',
#   '된',
#   '영화',
#   '살인마',
#   '와',
#   '대적',
#   '하는',
#   '그리고',
#   '사건',
#   '을',
#   '해결',
#   '하는',
#   '인물',
#   '이',
#   '없고',
#   '그리고',
#   '왜',
#   '마지막',
#   '에',
#   '다',
#   '탈출',
#   '해놓고',
#   '나서',
#   '잡히고',
#   '죽임을',
#   '당하는지',
#   '이해',
#   '할수가',
#   '없다',
#   '.',
#   '대체',
#   '조달환',
#   '정유미',
#   '는',
#   '왜',
#   '나옴',
#   '?'],
#  ['영화',
#   '진짜',
#   '보고',
#   '..',
#   '펑펑',
#   '울었습니다',
#   ',',
#   '너무',
#   '슬픈거',
#   '같아요',
#   '..',
#   'ㅜㅜㅜ',
#   '!'],
#  ['절망',
#   '과',
#   '슬픔',
#   '속',
#   '에서도',
#   '자신',
#   '을',
#   '챙겨야만하는',
#   '삶',
#   '의',
#   '잔인함',
#   '을',
#   '거부',
#   '한',
#   '비참함에',
#   '대하',
#   '여'],
#  ['잼'],
#  ['흥미롭게', '봤어요', '.', '여배우', '들', '이쁘네요', '.', '반했음'],
#  ['영화평론가',
#   '는',
#   '아니지만',
#   ',',
#   '좋았다',
#   ',',
#   '한번',
#   '보고',
#   '마는',
#   '영화',
#   '가',
#   '아닌',
#   ',',
#   '울림이있는',
#   '영화'],
#  ['슬프다', 'ㅠㅠ'],
#  ['굿', '10', '자', '이상', '.', '가나다라'],
#  ['최고', '의', '영화'],
#  ['오랜', '만', '에', '동화', '다운', '동화', '를', '본', '기분', '이다', '.'],
#  ['니노', '의', '이중인격', '연기', '두근거리네요', '♥'],
#  ['신화', '화이팅', '에릭', '화이팅', '><', '모두', '힘내요', '!'],
#  ['잘', '봤습니다'],
#  ['책', '과는', '분명히', '다른', '시선', '.', '괜찮네요'],
#  ['개답답',
#   '먼',
#   '주인공',
#   '이',
#   '지',
#   '혼자',
#   '복수',
#   '도',
#   '못',
#   '함',
#   '?',
#   '주변',
#   '에서',
#   '해주길',
#   '바라는',
#   '민폐',
#   '녀',
#   '?',
#   '아직도',
#   '끌려다니고',
#   'ㅡㅡ'],
#  ['억지스러운',
#   '시나리오',
#   '..',
#   '지루한',
#   '전개',
#   '..',
#   '1',
#   '편',
#   '보다',
#   '못',
#   '한',
#   '구성',
#   '등',
#   '..',
#   '2',
#   '편',
#   '은',
#   '안',
#   '나오는게',
#   '나았다',
#   '..',
#   '망작',
#   '..',
#   '배우',
#   '들',
#   '이',
#   '영',
#   '화보',
#   '는',
#   '눈',
#   '이',
#   '없어서',
#   '안타깝다',
#   '.'],
#  ['진짜',
#   '재미',
#   '없는',
#   '영화',
#   '공통점',
#   '....',
#   '스포츠영화',
#   ',',
#   '군대',
#   '영화',
#   ',',
#   '자막',
#   '나오는',
#   '영화'],
#  ['정말', '최고', '의', '영화', '...'],
#  ['졸면서',
#   '봤다',
#   '왜',
#   '이리',
#   '평정',
#   '이',
#   '높은',
#   '겨',
#   '내용',
#   '도',
#   '별거',
#   '없고',
#   '아오',
#   '감수성',
#   '영화',
#   '냐',
#   '이',
#   '거'],
#  ['인종차별', '과', '유괴', '라는', '두', '주제', '의', '불협화음'],
#  ['좋아', '상술', '최고', '..', '아니', '선거', '술', '최고', '...'],
#  ['내', '가', '본', '일드', '중', '쵝오', '~!!!!!>', '0', '<'],
#  ['스킨헤드', '성', '님', '들이', '이', '영화', '를', '싫어합니다', '.'],
#  ['재밌음', '귀엽고', '신남'],
#  ['이', '게', '어떻게', '평점', '이', '낮을수가', '있지', '?'],
#  ['안',
#   '봐도',
#   '별',
#   '점',
#   '한개',
#   '주고싶은',
#   '10',
#   '류',
#   '영화',
#   '같다',
#   '...',
#   'ㅋㅋ',
#   '심형래',
#   '아저씨',
#   '와',
#   '동',
#   '급',
#   '감독',
#   '인',
#   '듯',
#   'ㅋㅋㅋ'],
#  ['중심', '이', '약하니', '언', '저리', '가지', '고', '무리한', '승부', '수', '를', '띄운다'],
#  ['불',
#   '은',
#   '잘',
#   '보이지',
#   '도',
#   '않고',
#   '사람',
#   '죽어',
#   '나갈',
#   '때',
#   '는',
#   '엄청난',
#   '웅장',
#   '한',
#   '음악',
#   '만',
#   '나오고',
#   '전혀',
#   '마음',
#   '에',
#   '와',
#   '닿지',
#   '않는',
#   '설정',
#   '들'],
#  ['후속', '지금', '이라도', '나와라', '한국', '애니', '좀', '살려', '보자'],
#  ['전작', '보다', '100', '재밌다', '.', '배우', ',', '내용', '모두', '세련됨'],
#  ['말',
#   '이',
#   '필요',
#   '없다',
#   '.',
#   '로맨스',
#   '싫어하는',
#   '내',
#   '가',
#   '봤을',
#   '때',
#   '기절',
#   '할',
#   '것',
#   '같았어',
#   'ㅜㅜㅜㅜ'],
#  ['요즘', '재밌음', '!'],
#  ['극',
#   '장가',
#   '서',
#   '안',
#   '본',
#   '내',
#   '머리',
#   '를',
#   '깨',
#   '버리고싶네요',
#   '.',
#   '제',
#   '인생',
#   '최고',
#   '의',
#   '영홥니',
#   '다',
#   '.',
#   '키이라',
#   '작품',
#   '중',
#   '에서도',
#   '최고',
#   '일듯',
#   '.',
#   '알럽키',
#   '이라',
#   '♡♡'],
#  ['2%',
#   '부족한',
#   '영화',
#   '가',
#   '아닌',
#   '98%',
#   '부족한',
#   '영화',
#   '감동',
#   '이',
#   '있다길래',
#   '참고',
#   '끝',
#   '까지',
#   '다',
#   '봤는데',
#   '...;;',
#   '진심',
#   '으로',
#   '이렇게',
#   '재미없다고',
#   '느끼는건',
#   '처음',
#   ';;'],
#  ['심혜진', '이', '나와서', '겨우', '저', '정도', '라니', '실망', '이다'],
#  ['너무나', '따뜻하고', '감동', '적', '인', '영화'],
#  ['전',
#   '주',
#   '영화제',
#   '에서',
#   '봤었는',
#   '데넘',
#   '늦게',
#   '개봉',
#   '한',
#   '듯',
#   '...',
#   '종교',
#   '와',
#   '업',
#   '에',
#   '대해',
#   '한번',
#   '더',
#   '생각',
#   '할수있게만',
#   '든',
#   '영화',
#   '.',
#   '저',
#   '예산',
#   '으로만',
#   '들었으나',
#   '감독',
#   '의',
#   '노력',
#   '이',
#   '느껴져',
#   '큰',
#   '박수',
#   '를',
#   '보내고싶다',
#   '.',
#   '화이팅',
#   '!'],
#  ['자신', '의', '삶', '에', '대해', '다시', '한번', '생각', '하게하는', '영화', '...'],
#  ['이',
#   '영활',
#   '보고나면',
#   '흐뭇해진다',
#   '..',
#   '영화',
#   '는',
#   '한국',
#   '이',
#   '더',
#   '잘',
#   '만든다는',
#   '걸',
#   '느끼게',
#   '되니까',
#   '..'],
#  ['수많은', '최루성', '멜로', '는', '여기', '에서', '...'],
#  ['참', '재밌는', '영화', 'ㅎㅎ'],
#  ['진짜', '신기하다', '...', '라는', '말', '밖에', '안나', '와'],
#  ['2.2', '고고', '하자', 'ㅋㅋㅋ'],
#  ['감독', 'ㅡㅡ', '다신', '영화', '찍지마라'],
#  ['할', '말', '이', '없다'],
#  ['에린',
#   '이',
#   '초반',
#   '에',
#   '타던',
#   '차',
#   '현대',
#   '자동차',
#   '프레스토',
#   '네요',
#   '.',
#   '보면서',
#   '추억',
#   '이',
#   '세록',
#   '세록'],
#  ['일본', '영화', '좋아한다면', '꼭', '봐', '야할', '영화', '!'],
#  ['진짜',
#   '재미없다',
#   '..',
#   '영화관',
#   '에',
#   '삼십분',
#   '정도',
#   '늦게',
#   '들어갔는데',
#   '사람',
#   '이',
#   '한',
#   '명도',
#   '없고',
#   '..',
#   '그',
#   '이유',
#   '를',
#   '왠지',
#   '알것',
#   '같네',
#   '..^^',
#   '완전',
#   '비추요'],
#  ['아니',
#   '찍어놓고',
#   '모니터링',
#   '한번',
#   '안',
#   '하나',
#   '어떻게',
#   '염치',
#   '업',
#   '이',
#   '이런',
#   '걸',
#   '극장',
#   '에',
#   '걸수가',
#   '있지',
#   '?'],
#  ["'",
#   '디',
#   '워',
#   "'",
#   '랑',
#   '같은',
#   '부류',
#   '..',
#   '저',
#   '예산',
#   '+',
#   '저렴한',
#   'CG',
#   '+',
#   '마구잡이',
#   '연출'],
#  ['보면서', '어이없어서', '헛웃음', '만', '나던', '....'],
#  ['기쁨',
#   ',',
#   '슬픔',
#   ',',
#   '생명',
#   '그리고',
#   '죽음',
#   '.',
#   '인간',
#   '의',
#   '역사',
#   '속',
#   '에',
#   '거대한',
#   '하나님',
#   '의',
#   '우주',
#   '적',
#   '섭리',
#   '가',
#   '느껴지는',
#   '영화',
#   '.',
#   '특별히',
#   '어머니',
#   '의',
#   '역',
#   '을',
#   '맡은',
#   '여배우',
#   '의',
#   '여',
#   '성미',
#   '와',
#   '자애',
#   '로움',
#   '이',
#   '인상',
#   '적',
#   '이다',
#   '.',
#   '인생',
#   '을',
#   '살면서',
#   '그런',
#   '존재',
#   '가',
#   '된다면',
#   '.',
#   '영',
#   '상미',
#   '예술',
#   '이다',
#   '!'],
#  ['정말', '광해', '와', '비슷한가', '?'],
#  ['콜린', '파렐', '.', '123412341234'],
#  ['엄청나게', '기대', '를', '하고', '본게', '아니라', '괜찮았던듯', '?'],
#  ['정말', '식상하다못해', '촌스럽기까지', '~~~~~~~~~~'],
#  ['돈',
#   '에',
#   '미친',
#   '남편',
#   '과',
#   '..',
#   '아기',
#   '에',
#   '미친',
#   '돈',
#   '있는',
#   '남자',
#   '그',
#   '속',
#   '에서',
#   '갈등',
#   '하는',
#   '여자',
#   '18'],
#  ['공격',
#   '적',
#   '인',
#   '재미',
#   ',',
#   '유순한',
#   '여성성',
#   ',',
#   '일기토',
#   ',',
#   '지략',
#   '삼국지',
#   '의',
#   '그것',
#   '과',
#   '맞짱',
#   '!'],
#  ['평점', '조절', '...'],
#  ['배우', '가', '아깝다', ',,'],
#  ['감독',
#   '이',
#   '밥',
#   '은',
#   '먹고',
#   '다니는지',
#   '궁금하다',
#   '.',
#   '배틀로얄',
#   '2',
#   '이후',
#   '로',
#   '최고',
#   '쓰래',
#   '기',
#   '.'],
#  ['좋은', '영화', '~'],
#  ['무슨', '생각', '으로', '만든', '걸까', '.'],
#  ['625',
#   '를',
#   '직접',
#   '겪은',
#   '어르신',
#   '들',
#   '얘길',
#   '들어',
#   '보면',
#   '그',
#   '당시',
#   '잔인한',
#   '학살',
#   '은',
#   '대부분',
#   '주민',
#   '들',
#   '서',
#   '로간',
#   '에',
#   '(',
#   '주로',
#   '하층',
#   '민',
#   '들',
#   '의',
#   '복수심',
#   '에서',
#   '비롯',
#   '된',
#   ')',
#   '또는',
#   '군',
#   '/',
#   '경이',
#   '빨치산',
#   '학살',
#   '한다며',
#   '벌인',
#   '살인',
#   '이었지',
#   '정작',
#   '북한',
#   '군',
#   '은',
#   '민간인',
#   '들',
#   '한테',
#   '는',
#   '잘',
#   '해줬다고',
#   '하던데',
#   '?'],
#  ['네이버',
#   '별',
#   '점',
#   ',',
#   '꽤',
#   '신뢰',
#   '도',
#   '가',
#   '높네요',
#   '.',
#   '5',
#   '점',
#   '이하',
#   '는',
#   '안',
#   '보는게',
#   '좋을듯',
#   '..'],
#  ['이', '거', '시청률', '이', '너무', '낮은대', '명작', '이', '고만'],
#  ['해군', '출신', '이라', '관심', '있게', '본', '영화', '~'],
#  ['내', '가본', '영화', '중', '베스트', '5', '안', '에', '듬', '진짜', '꼭', '보세요'],
#  ['예고편',
#   '을',
#   '왜',
#   '하는',
#   '건지',
#   '모르겠음',
#   '..',
#   '예고편',
#   '에',
#   '나오는건',
#   '하나',
#   '도',
#   '안',
#   '나오고',
#   '..',
#   '예고편',
#   '은',
#   '대판',
#   '쌈질',
#   '하는것',
#   '마냥',
#   '나오더니',
#   '하하호호',
#   '하고',
#   '끝남',
#   '..',
#   '예고편',
#   '이',
#   '무슨',
#   '뜻',
#   '인지',
#   '를',
#   '모르는',
#   '건지',
#   '..',
#   '시청자',
#   '들',
#   '을',
#   '호구',
#   '로',
#   '보는',
#   '건지',
#   '..',
#   '낚시질',
#   '좀',
#   '그만하시고',
#   '차라리',
#   '시청률',
#   '걱정',
#   '되면',
#   '폐지',
#   '해'],
#  ['설득', '력', '없는', '꼴통', '페미니즘', '.', '페미나치', '적', '인', '마인드', '.'],
#  ['진짜',
#   '언제',
#   '90분',
#   '이',
#   '지나갔는지',
#   '모를',
#   '정도',
#   '로',
#   '몰입',
#   '해서',
#   '보고',
#   '정말',
#   '너무',
#   '재미있게',
#   '봄',
#   '...',
#   '너무',
#   '아련해서',
#   '영화',
#   '평',
#   '정말',
#   '처음',
#   '남겨',
#   '봄',
#   '..',
#   '진짜',
#   '내',
#   '가',
#   '이',
#   '나이',
#   '에',
#   '애니',
#   '를',
#   '보며',
#   '이',
#   '밤중',
#   '에',
#   '이렇게',
#   '울줄이야',
#   '..',
#   '에몽',
#   '아',
#   'ㅠㅠ'],
#  ['오글거리고', '유치하고', '완전', '최악', '이었음', '...'],
#  ['자꾸',
#   '뭘',
#   '설득',
#   '할',
#   '려',
#   '하고',
#   '설교',
#   '할려고',
#   '하는게',
#   '보기',
#   '거북하다',
#   '.',
#   '그리고',
#   '결혼반지',
#   '를',
#   '위해',
#   '범죄',
#   '가',
#   '담하다니',
#   '무슨',
#   '개역',
#   '지',
#   '설정',
#   '이냐',
#   '.'],
#  ['존내', '재밋습', '네', '다'],
#  ['순수함이',
#   '두근거려',
#   '좋았다',
#   '감독',
#   '님',
#   '은',
#   '관객',
#   '들',
#   '이',
#   '뭘',
#   '원하는지',
#   '잘아는듯',
#   '..',
#   '여운',
#   '이',
#   '많이',
#   '남는다'],
#  ['천녀유혼',
#   '1',
#   ',',
#   '2',
#   '에',
#   '비',
#   '하면',
#   ',',
#   '뭐라',
#   '표현',
#   '하기',
#   '힘든',
#   '퀭',
#   '한',
#   '영화'],
#  ['솔직히', '산만', '하기만', '했다'],
#  ['기억',
#   '은',
#   '조작',
#   '되기',
#   '마련',
#   '..',
#   '그',
#   '사람',
#   '이',
#   '아니고서는',
#   '함',
#   '부러',
#   '말',
#   '하지',
#   '말',
#   '자'],
#  ['정말', '사랑', '에', '대해', '다시', '생각', '한', '거', '같습니다', '감동', '이에요'],
#  ['진짜', '쓰레기', '영화', '..', '돈', '아까워', '죽는줄', '알았다', '..', '여러분', '보지', '마세요'],
#  ['독립영화',
#   '실력',
#   '자',
#   '들',
#   '의',
#   '스타',
#   '리그',
#   ',',
#   '옴니버스',
#   '라는',
#   '피로',
#   '감',
#   '이',
#   '극복',
#   '되는',
#   '수준',
#   '이다',
#   '.',
#   "'",
#   '얼음',
#   '강',
#   "'",
#   '은',
#   '단독',
#   '장편',
#   '으로',
#   '만들었어도',
#   '좋았을',
#   '듯',
#   '.',
#   '주인공',
#   '이',
#   '혹',
#   '여',
#   '-',
#   '평소',
#   '라면',
#   '1%',
#   '도',
#   '공감',
#   '안되는',
#   '-',
#   '여호와',
#   '의',
#   '증인',
#   '이라도',
#   '납득',
#   '이',
#   '될',
#   '정도',
#   '로',
#   '감정',
#   '을',
#   '설득',
#   '하는',
#   '솜씨',
#   '가',
#   '탁월하다',
#   '.'],
#  ['서스펜스', '도', '없고', '스릴', '도', '없다', '.'],
#  ['너무', '너무', '귀여운', '영화'],
#  ['아이', '들', '과', '함께', '보기', '좋았지만', ',', '그냥', '그래요', '.'],
#  ['보',
#   '니까',
#   '선정',
#   '성',
#   '이',
#   '좀',
#   '15',
#   '세',
#   '같음',
#   '::::',
#   '그래도',
#   '액션',
#   '은',
#   '좋음'],
#  ['답', '을', '알려고', '하지마라', '.'],
#  ['이',
#   '거',
#   '참',
#   '...',
#   '소재',
#   '는',
#   '참',
#   '좋은데',
#   '내용',
#   '전개',
#   '가',
#   '개판',
#   '...',
#   '사람',
#   '수도',
#   '많고',
#   '총',
#   '도',
#   '있는데',
#   '그걸',
#   '지',
#   '들',
#   '끼리',
#   '서로',
#   '다',
#   '흩어져서',
#   '일방',
#   '적',
#   '으로',
#   '밀리',
#   '네',
#   '..',
#   '거기',
#   '다',
#   '식인종',
#   '이라',
#   '면서',
#   '표현',
#   '을',
#   '좀비',
#   '로',
#   '해놓으면',
#   '어쩌잔거',
#   '야',
#   '..',
#   '식인',
#   '으로',
#   '인해',
#   '인성',
#   '이',
#   '말살',
#   '되고',
#   '짐승',
#   '화',
#   '되었다는',
#   '표현',
#   '이라도',
#   '있던가'],
#  ['8',
#   '점',
#   '대',
#   '는',
#   '나와야지',
#   '.',
#   '그냥',
#   '단순한',
#   '액션',
#   '공포물',
#   '이',
#   '아닌데도',
#   '긴장감',
#   '공포',
#   '감',
#   '연출',
#   '쩔고',
#   '음악',
#   '도',
#   '좋고',
#   '..',
#   '몇',
#   '년',
#   '이',
#   '지나도',
#   '기억나는',
#   '인상',
#   '적',
#   '인',
#   '좀비',
#   '물',
#   '인데',
#   '.',
#   '평점',
#   '너무',
#   '짜서',
#   '10',
#   '줌'],
#  ['ufo', '를', '믿으려는', '자', '들', '.'],
#  ['유투브', '동영상', '을', '돈', '내고', '보는게', '낫다', '는', '생각', '이', '들게', '한', '영화'],
#  ['구', '우우', '웃', '~~!!!!'],
#  ['이', '것', '도', '재밌는데', '...', 'ㅋㅋ'],
#  ['괜찮은',
#   '영화',
#   ',,',
#   '영화',
#   '도',
#   '괜찮았지만',
#   '나영',
#   '언니',
#   '완전',
#   '머싯',
#   '고',
#   '예뻤음',
#   'ㅠㅠ'],
#  ['슬픈', '맑음', '.', '파문', '에', '주목', '하', '라', '.'],
#  ['완전',
#   '역겨운',
#   '쓰레기',
#   '영화',
#   '다',
#   '기술',
#   '적',
#   '수준',
#   '을',
#   '떠나',
#   '각본',
#   '이',
#   '무',
#   '개념'],
#  ['유럽',
#   '영화',
#   '가',
#   '이번',
#   '정부',
#   '에',
#   '많이',
#   '들어와',
#   '즐겁긴',
#   '하다만',
#   '그',
#   '내용',
#   '들',
#   '이',
#   '왜',
#   '이리',
#   '진부한',
#   '걸까',
#   ',,,,,,,,,,,,,,,,,,,,,,,,,,,',
#   '유럽',
#   '영화',
#   '를',
#   '욕',
#   '되게',
#   '하고있단',
#   '소리',
#   '다',
#   ',,'],
#  ['정말', '재밌게', '봤고', '빈센트', '도', '꼬마', '도', '연기', '너무', '잘', '하네요', '.', 'ㅎ'],
#  ['야경', '꾼', '보다', '엉망', '지루함'],
#  ['야', '세르게이', '!!!', '작은', '고추', '의', '매운', '맛', '을', '보여주마'],
#  ['자식', '을', '그렇게', '때리냐', '?'],
#  ['의도', '는', '좋지만', '너무', '몰입', '이', '안되는걸', '어떡해'],
#  ['ㅇㅇ'],
#  ['샷',
#   '의',
#   '연결',
#   '이',
#   '아닌',
#   '충돌',
#   '만큼이나',
#   '거룩한',
#   '제목',
#   '또한',
#   '인상',
#   '적',
#   '이',
#   '구려'],
#  ['영',
#   '상미',
#   '예쁘고',
#   '좋지만',
#   '러닝',
#   '타임',
#   '이',
#   '2시간',
#   '이',
#   '넘는데',
#   '초반',
#   '30분',
#   '에',
#   '줄거리',
#   '다',
#   '나갔고',
#   '엄청',
#   '지루한',
#   '화보',
#   '집',
#   '보는',
#   '기분',
#   '일본',
#   '영화',
#   '특유',
#   '의',
#   '그',
#   '이해',
#   '못',
#   '할',
#   '희한함이',
#   '있음'],
#  ['마지막', '이', '좀', '황당했지만', '좋은', '영화'],
#  ['파괴', '된', '관객', '들', '.'],
#  ['울컥', '하는', '사회', '현실', 'ㅠㅠ'],
#  ['와', '..', '이건', '진짜', '으리', '으리', '한', '데', '..?'],
#  ['1', '점', '주기도', '아까운', '쓰레기'],
#  ['내',
#   '아까운',
#   '시간',
#   '을',
#   '버리게',
#   '한',
#   '쓰레기',
#   '재미없다',
#   '..',
#   '2',
#   '점',
#   '부터',
#   '점',
#   '수준',
#   '것',
#   '들',
#   'M',
#   '창'],
#  ['킬링타임', '용', '??', '정말', '시간', '아깝다', '!'],
#  ['퀸틴', '타란티노', '의', '포룸', '을', '어줍잖게', '패러디', '한', '졸작'],
#  ['이런게', '말', '그대로', '재미있는', '영화'],
#  ['기존',
#   '의',
#   '매력',
#   '에',
#   '화끈한',
#   '액션',
#   '까지',
#   '즐길',
#   '수',
#   '있는',
#   '건',
#   '극장판',
#   '만의',
#   '매력'],
#  ['민감한', '소재', '를', '어떻게', '이렇게', '뻔', '뻔하게', '만들', '수', '있는지', '...?'],
#  ['제발',
#   '다른',
#   '인간',
#   '들',
#   '보고',
#   '욕좀',
#   '해줘라',
#   'ㅋㅋ',
#   '시간',
#   ',',
#   '배우',
#   '정말',
#   '아깝다',
#   '.'],
#  ['장선우', '여전히', '쓰레기'],
#  ['.', '정말', '최고', '의', '드라마', '..', '외국', '드라마', '첨으로', '깊게', '빠져듬', '.'],
#  ['그럭저럭', '볼', '만', '한', '장면', '들', '.', '그런데', '좀', '늘어짐'],
#  ['의리', '로', '도', '채울수', '없는', '허전함', '...'],
#  ['구식',
#   '촬영',
#   '기법',
#   '이',
#   '그나마',
#   '있던',
#   '액션',
#   '의',
#   '격',
#   '을',
#   '떨어뜨리고',
#   ',',
#   '이해',
#   '가지',
#   '않는',
#   '인물',
#   '의',
#   '행동',
#   '은',
#   '답답하다',
#   '.'],
#  ['2005년',
#   '이면',
#   '좋은',
#   '영화',
#   '많이',
#   '나올',
#   '때',
#   '인데',
#   '...',
#   '요런',
#   'OOO',
#   '가',
#   '~~~',
#   'ㅋㅋㅋ'],
#  ['(',
#   '구',
#   ')',
#   '성',
#   '이나',
#   '연출',
#   '이',
#   '매우',
#   '(',
#   '미',
#   ')',
#   '진한',
#   '(',
#   '호',
#   ')',
#   '러물',
#   '...'],
#  ['작품', '성', '있는', '영화', '는', '10', '점', '이다', '.'],
#  ['주', 'x', '서민', '들', '돈', '빨아서', '잘', '하는', '짓', '이다'],
#  ['TV',
#   '판',
#   '8',
#   '점',
#   '을',
#   '주겠지만',
#   ',',
#   '다른',
#   '것',
#   '이',
#   '있을것이란',
#   '말',
#   '과',
#   '달리',
#   '거',
#   '시기',
#   '밖에',
#   '없다',
#   '.',
#   '실망',
#   '이다',
#   '.'],
#  ['스타트랙', '보다', '100', '배', '재미있음'],
#  ['B',
#   '급',
#   '영화',
#   '의',
#   '찬사',
#   '를',
#   '...',
#   '타란티노',
#   '와',
#   '로드리게즈',
#   '에게',
#   '찬사',
#   '를',
#   '...'],
#  ['이딴',
#   '것',
#   '도',
#   '영화',
#   '라고',
#   '...',
#   '속편',
#   '낼',
#   '생각',
#   '하고',
#   '있었다니',
#   '미쳤지',
#   '//'],
#  ['이런건', '보는거', '아니야', 'ㅡㅡ', '^'],
#  ['완전', '재밋음', '역시', '짱구', '가', '최고', '!!'],
#  ['완전', '짱', '박대동', '길', '홍도', '쾌', '!!!!'],
#  ['목포', '..', '붹'],
#  ['같은',
#   '동족',
#   '이라는',
#   '걸',
#   '떠나서',
#   '같은',
#   '인간',
#   '으로써',
#   '도울',
#   '수',
#   '없다는게',
#   '안타깝네요',
#   '.',
#   '장성택',
#   '사건',
#   '도',
#   '그렇고',
#   '머',
#   '지',
#   '않아',
#   '북한',
#   '체제',
#   '가',
#   '자멸',
#   '할',
#   '날',
#   '도',
#   '멀지',
#   '않은거',
#   '같은데',
#   '...',
#   '중국',
#   '이',
#   '호시탐탐',
#   '노리',
#   '고',
#   '있고',
#   ',',
#   '결국',
#   '엔',
#   '북한',
#   '땅',
#   '을',
#   '중국',
#   '에게',
#   '또',
#   '빼앗길',
#   '것',
#   '같네요',
#   '.'],
#  ['OOO',
#   '기',
#   '영화',
#   '...',
#   '특히',
#   '이정우',
#   '.',
#   '고',
#   '다미',
#   '.',
#   '김푸른',
#   '이',
#   '것',
#   '들',
#   '제일',
#   '심하네'],
#  ['평점', '에', '오류', '가', '있는', '영화', '다'],
#  ['언론',
#   '의',
#   '맹점',
#   '과',
#   '군중심리',
#   '.',
#   '개인',
#   '의',
#   '심리',
#   '까지',
#   '파헤치면서도',
#   '재미',
#   '까지',
#   '균형',
#   '을',
#   '잘',
#   '맞춘',
#   '멋',
#   '진영화'],
#  ['나', '의', '캣우먼', '은', '이렇지', '않아', '!!'],
#  ['시즌',
#   '4',
#   '도',
#   '만들어주세요',
#   '!!',
#   '꼭',
#   '시리즈',
#   '중',
#   '에는',
#   '3',
#   '가',
#   '젤',
#   '재밌었',
#   '찌',
#   '만',
#   '하윤',
#   '이',
#   '가',
#   '없어',
#   ',,',
#   'ㅜㅜ'],
#  ['특수', '효과', '없이도', '관객', '을', '납득', '시키던', '능력', '.'],
#  ['존쿠삭', '같은', '남자', '와', '결혼', '하고', '싶음', '.', 'ㅋㅋ'],
#  ['데이빗',
#   '린치',
#   '를',
#   '좋아하는',
#   '사람',
#   '에겐',
#   '필추',
#   '.',
#   '물론',
#   'TV',
#   '드라마',
#   '를',
#   '먼저',
#   '보고',
#   '봐야',
#   '..'],
#  ['기분', '종', '게', '웃겨주는', '영화', '...'],
#  ['그레이',
#   '아',
#   '나',
#   '토미',
#   '같은',
#   '의학',
#   '인척',
#   '하는',
#   '로맨스',
#   '가',
#   '아니라',
#   '진짜',
#   '의학',
#   '드라마',
#   'ㅋㅋ'],
#  ['예능',
#   '이라고',
#   '하기에는',
#   '서로',
#   '싸우고',
#   '갈등',
#   '생기',
#   '고',
#   '이런',
#   '거',
#   '를',
#   '보여주니까',
#   '괜히',
#   '보는',
#   '사람',
#   '도',
#   '짜증나네요',
#   ';'],
#  ['말', '이', '필요없다', '.', '보다가', '자려고', '마음', '먹엇다'],
#  ['종훈', '이형', '가오', '상하', '게', '왜', '이런데', '나와요'],
#  ['최고'],
#  ['보지마'],
#  ['재미', '있었어요', '~', '아이', '도', '재미있었데요'],
#  ['빨간',
#   '풍선',
#   '을',
#   '따라가는',
#   '아이',
#   ',',
#   '아이',
#   '를',
#   '통해',
#   '행복해지는',
#   '이',
#   '들',
#   '..',
#   '아름답다',
#   '..'],
#  ['나',
#   '이',
#   '거',
#   '중학교',
#   '때',
#   '퍼펙트',
#   '월드',
#   '랑',
#   '동시',
#   '상',
#   '열으',
#   '루',
#   '봤는데',
#   'ㅋㅋㅋ',
#   '잼있었음',
#   '!!'],
#  ['깜찍하고', '귀여운', '엄지', '왕자', ',', '사악한', '마녀', '로부터', '마을', '을', '지켜라'],
#  ['별루'],
#  ['왜', '만', '든지', '모르겟다', '.'],
#  ['실질',
#   '적',
#   '인',
#   '점수',
#   '..',
#   '미국인',
#   '친구',
#   '란',
#   '제목',
#   '은',
#   '왜',
#   '붙인',
#   '건지',
#   '..',
#   'ㅜ'],
#  ['제시카알바', '정도', '의', '배우', '가', '이따위', '쓰레기', '나온', '이유', '를', '모르겠다'],
#  ['감독',
#   '대',
#   '실망',
#   '이다',
#   '.',
#   '호화',
#   '배역',
#   '진',
#   '이',
#   '아깝다',
#   '.',
#   '죽도',
#   '밥',
#   '도',
#   '안된',
#   '엉',
#   '성함'],
#  ['감성', '팔이', '애국', '주의', '는', '그만', '~!!'],
#  ['강철중', '시리즈', '완전', '잼남'],
#  ['그냥', '별루', '다', '...', '극장', '에서', '안', '보길', '다행', '인', '듯', '...'],
#  ['별',
#   '점',
#   'ㅇ',
#   '점',
#   '옛날',
#   '미이라',
#   '생각',
#   '하고',
#   '10,000원',
#   '이나',
#   '주고',
#   '뵜는데',
#   '돈',
#   ',',
#   '시간',
#   '만',
#   '날렸음',
#   '도대체',
#   '영화',
#   '를',
#   '통해',
#   '말',
#   '하려는게',
#   '뭔',
#   '지',
#   '도통',
#   '????',
#   '재미',
#   '도',
#   '감동',
#   '도',
#   '꽝',
#   '....',
#   '다른',
#   '사람',
#   '평점',
#   '봤으면',
#   '안',
#   '봤을텐데',
#   '어휴',
#   '아까워',
#   'ㅠㅜ'],
#  ['미학', '적', '완성', '도', '가', '한국영', '화', '중', '최상급', '이다', '.'],
#  ['내용', '기대', '없이', '훈훈한', '주인공', '오빠', '보기', '엔', '굿'],
#  ['감독', '자질', '문제', '라고', '밖엔'],
#  ['어렸을',
#   '때',
#   '영화',
#   '보면서',
#   '저',
#   '쥐',
#   '가지고싶단',
#   '생각',
#   '만',
#   '했었다',
#   '-_',
#   '-',
#   'ㅋㅋ'],
#  ['영화',
#   '든',
#   '애니',
#   '든',
#   '일단',
#   '브랜드',
#   '하고',
#   '광고',
#   '로',
#   '먹어준다',
#   '.',
#   '이런',
#   '숨은',
#   '명작',
#   '은',
#   '많은',
#   '이',
#   '가',
#   '보고',
#   '감동',
#   '을',
#   '받아야',
#   '함',
#   '.',
#   '본',
#   '건',
#   '5년',
#   '전',
#   '인데',
#   '...',
#   '다시',
#   '보고',
#   '또',
#   '감동',
#   '받아서',
#   '평',
#   '씀',
#   '.'],
#  ['제목',
#   '만',
#   '보고',
#   '왠지',
#   '장르',
#   '가',
#   '공포',
#   '인',
#   '듯',
#   '한',
#   '느낌',
#   '이',
#   'ㄷㄷ',
#   '...'],
#  ['봐주기', '아까운', '영화'],
#  ['왜',
#   '이',
#   '게',
#   '이렇게',
#   '평점',
#   '이',
#   '높은지',
#   '영화',
#   '를',
#   '다',
#   '보고',
#   '나서도',
#   '잘',
#   '모르겠다',
#   '.'],
#  ['영화',
#   '보고',
#   '울어야',
#   '될',
#   '것',
#   '같아서',
#   '운',
#   '게',
#   '아니라',
#   '진짜',
#   '감동',
#   '해서',
#   '운',
#   '적',
#   '은',
#   '처음',
#   '이다',
#   '...',
#   'ㅠㅠ'],
#  ['박시후',
#   '때문',
#   '에',
#   '참고',
#   '또',
#   '참고',
#   '봐',
#   '줬다',
#   '.',
#   '15회',
#   '까지',
#   '...',
#   '야',
#   '.....',
#   '시간',
#   '이',
#   '아깝구나',
#   '.....',
#   '박시후',
#   '는',
#   '완전',
#   '한',
#   '세',
#   '경의',
#   '꼭두각시',
#   '가',
#   '되어',
#   '같은',
#   '캐릭터',
#   '로',
#   '전락',
#   '.',
#   '.....',
#   'ㅜㅠ',
#   '....',
#   '한',
#   '세',
#   '경',
#   '같은',
#   '여자',
#   '만날까봐',
#   '세상',
#   '이',
#   '무서워진다',
#   '.',
#   '정말',
#   '작가',
#   '들',
#   '이',
#   '초등생',
#   '수준',
#   '!'],
#  ['역시', '줄리엣', '비노', '쉬는', '이뻣다', '.^^', '보면', '따뜻해지는', '영화'],
#  ['짱짱한', '배우', '진임', '에도', '불구', '하고', '심심하기', '그', '지', '없는', '스릴'],
#  ['아', '재밌', '당', '아', '재밌당', '아', '재밌당', '아', '재밌당', '아', '재밌당'],
#  ['볼', '만', '합니다', '강추', '!!', 'ㅋㅋ'],
#  ['재미없다', '...'],
#  ['요즘',
#   '에도',
#   '매번',
#   '지식인',
#   '에',
#   '물어본다',
#   '.',
#   "'",
#   '프리즌브레이크',
#   '만',
#   '한',
#   '미드',
#   '없어요',
#   "?'",
#   '라고'],
#  ['보내는', '내내', '궁금증', '은', '유발', '하', '지만', '지루하게', '끝나', '버림', '.'],
#  ['화면',
#   '좋고',
#   '배우',
#   '좋고',
#   '스릴',
#   '감',
#   '있는',
#   '그리고',
#   '재미있고',
#   '...',
#   '훌륭한',
#   '드라마',
#   '라고',
#   '생각',
#   '합니다',
#   '.'],
#  ['완벽한',
#   '형태',
#   '를',
#   '가진',
#   '완벽한',
#   '날카로',
#   '움',
#   '을',
#   '가진',
#   '형이상학적',
#   '가시',
#   '로',
#   '찔린',
#   '기분',
#   '이다',
#   '.',
#   '무',
#   '지각',
#   '적',
#   '순수',
#   '가',
#   '얼마나',
#   '무서운지',
#   '공기',
#   '까지',
#   '전해진다',
#   '.'],
#  ['진짜',
#   '그지같은',
#   '영화',
#   '_',
#   '와나',
#   '_',
#   '어릴',
#   '적',
#   '에',
#   '본거라',
#   '내용',
#   '은',
#   '기억',
#   '도',
#   '안나는데',
#   '그지같았다는',
#   '느낌',
#   '만',
#   '기억',
#   '에',
#   '남아있네요',
#   '_',
#   '내',
#   '평생',
#   '에',
#   '가장',
#   '돈',
#   '아까운',
#   '영화',
#   '넘버원',
#   '임',
#   '-_-',
#   '0',
#   '점',
#   '짜리',
#   '영화'],
#  ['TV', '시리즈', '는', '못', '봤지만', '영화', '는', '볼', '만', '했다'],
#  ['짱',
#   '재밌다',
#   '!!!',
#   '김지수',
#   ',',
#   '이하나',
#   ',',
#   '한재석',
#   ',',
#   '정겨운',
#   ',',
#   '최정희',
#   '교수',
#   '님',
#   ',',
#   '장',
#   '태문',
#   '회장',
#   '님',
#   ','],
#  ['알',
#   '행',
#   '님',
#   '의',
#   '연기',
#   '쩔었음',
#   '.',
#   '특히',
#   '매니',
#   '가',
#   '문',
#   '을',
#   '열어주고',
#   '2',
#   '층',
#   '에서',
#   '여동생',
#   '을',
#   '본',
#   '후',
#   '다시',
#   '매니',
#   '를',
#   '쳐다볼',
#   '때',
#   '에그',
#   '분노',
#   '에',
#   '찬',
#   '얼굴',
#   '.',
#   '잊혀지지가',
#   '않는다',
#   '.',
#   '이번',
#   '이',
#   '이영화',
#   '3',
#   '번',
#   '째',
#   '라는',
#   '.',
#   '계속',
#   '봐도',
#   '질리',
#   '지',
#   '않는',
#   '영화',
#   '..',
#   '알',
#   '형님',
#   '의',
#   '카리스마',
#   '가',
#   '대단한',
#   '영화',
#   '였음',
#   '그리고',
#   '리즈시절',
#   '의',
#   '미쉘',
#   '누님',
#   '의'],
#  ['꼭', '보세요', '후회', '안', '합니다', '?'],
#  ['캐스팅', '도', '스토리', '도'],
#  ['이런', '영화', '를', '느와르', '라고', '하는', '것', '이다', '!!!'],
#  ['아이스크림', '이', '길', '을', '가다', '죽었다', '이유', '는', '?', '차가와', '서'],
#  ['스파이더맨',
#   '을',
#   '가장',
#   '좋아하는',
#   '1',
#   '人',
#   '~',
#   '스파이더맨',
#   '완전',
#   '사랑',
#   '합니다',
#   '.',
#   '영원했으면',
#   '좋겠네요',
#   '!!'],
#  ['고현정', '어제', '진행', '도', '좋고', '너무', '이뻤어요', '~!!'],
#  ['어려운', '영화', '여운', '이', '많이', '남는', '영화'],
#  ['내',
#   '가',
#   '영화',
#   '를',
#   '잘',
#   '몰라서',
#   '그러는데',
#   '이런',
#   '걸',
#   '컬트',
#   '영화',
#   '라고',
#   '하는',
#   '건가',
#   '?'],
#  ['막',
#   '설레고',
#   '그런게',
#   '없어서',
#   '쫌',
#   '아쉽고',
#   '알렉스',
#   '오로린',
#   '은',
#   '멋진데',
#   '스탠',
#   '은',
#   '쫌',
#   '심심',
#   '...',
#   '미묘',
#   '?',
#   '남주',
#   '여주',
#   '둘다',
#   '캐릭터',
#   '가',
#   '그닥',
#   '매력',
#   '적',
#   '이지',
#   '가',
#   '않음',
#   '.'],
#  ['한', '승려', '의', '지옥', '으로', '가게', '된', '일대기'],
#  ['몇번', '째', '보는지', '모르겠다', '..'],
#  ['믿고', '보는', '배우', '들', '의', '환상', '연기', '호흡', '!'],
#  ['내',
#   '생애',
#   '최고',
#   '의',
#   '영화인',
#   '것',
#   '같습니다',
#   '.',
#   '정말',
#   '강',
#   '추강',
#   '추',
#   '입니다',
#   '.'],
#  ['와',
#   '감상',
#   '평땜',
#   '에',
#   '진짜',
#   '눈물나게',
#   '웃네',
#   '돈',
#   '아까워',
#   '환불',
#   '해줘',
#   'ㅠ',
#   '무의미한',
#   '자음',
#   '입력',
#   '은',
#   '못',
#   '한다니',
#   '더',
#   '짜증나네'],
#  ['[', '볼륨', '을', '높여라', ']', '의', '재치', '는', '어디', '에', '..'],
#  ['뭔가',
#   '미흡하다',
#   '.',
#   '하지만',
#   '프랑스',
#   '영화',
#   '다운',
#   '은은한',
#   '감동',
#   '이',
#   '묻어',
#   '나온다',
#   '.'],
#  ['제니',
#   '라이트',
#   '존나',
#   '이쁘다',
#   '....',
#   '제니',
#   '라이트',
#   '때매',
#   '10',
#   '점',
#   '내',
#   '손가락',
#   '도',
#   '주고싶다',
#   'ㅠㅠ'],
#  ['불꽃',
#   '같은',
#   '인생',
#   '을',
#   '사시다가',
#   '한',
#   '줌',
#   '의',
#   '재',
#   '가',
#   '되어',
#   '저',
#   '멀리',
#   '하늘',
#   '로',
#   '날아갔네'],
#  ['재밌다', '.'],
#  ['너희', '가', '이', '영화', '를', '봤느뇨', '?'],
#  ['이', '게', '뭐', '지', '싶은', '영화', '기억', '에', '남지', '않을'],
#  ['지루함',
#   '그리고',
#   '드류',
#   '베리',
#   '모어',
#   '역',
#   '꼴사납다',
#   '이',
#   '기적',
#   '이고',
#   '앞뒤',
#   '생각',
#   '없이',
#   '누가',
#   '피해',
#   '를',
#   '보건',
#   '말건',
#   '고래',
#   '만',
#   '살리면',
#   '돼',
#   'ㅡㅡ',
#   '짜증남'],
#  ['영화',
#   '정말',
#   '감동',
#   '적임',
#   '.',
#   '내용',
#   '이',
#   '뻔하다는',
#   '것',
#   '때문',
#   '에',
#   '1',
#   '점',
#   '뺐는데',
#   '나머지',
#   '는',
#   '다',
#   '~',
#   '좋음'],
#  ['배우',
#   '들',
#   '연기',
#   '도',
#   '잘',
#   '하고',
#   '재미있어요',
#   '!!!',
#   'ㅋㅋ',
#   '만',
#   '보때',
#   '가',
#   '제일',
#   '재미있었구요',
#   '^^'],
#  ['이야기', '자체', '가', '탄탄한데다가', '연출', '과', '연기', '가', '조화', '를', '이루는군'],
#  ['꿀잼', '근데', '아나킨', '은', '언제'],
#  ['유리',
#   '랑',
#   '헤어졌으면',
#   '좋겠어요',
#   '유리',
#   '랑',
#   '안',
#   '어울림',
#   '가면',
#   '갈수록',
#   '유리',
#   '연기',
#   '이상함'],
#  ['여러',
#   '말',
#   '필요없는',
#   '드라마',
#   '.',
#   '특히',
#   '이준기',
#   '의',
#   '연기',
#   '는',
#   'best',
#   'of',
#   'best'],
#  ['되게', '재밌게', '봤다', '.', '우디', '해', '럴슨', '의', '연기', '가', '인상', '깊다', '!'],
#  ['이건', '그냥', '야동', '임'],
#  ['인간',
#   '의',
#   '본성',
#   '을',
#   '송어',
#   '에',
#   '빗대어',
#   '냉소',
#   '적',
#   '으로',
#   '바라본',
#   '박종원',
#   '감독',
#   '의',
#   '수작'],
#  ['요즘',
#   '은',
#   '함께',
#   '하는거',
#   '본다',
#   '옴니버스',
#   '식',
#   '이',
#   '던데',
#   '그러',
#   '기',
#   '엔',
#   '.',
#   '가족',
#   '이',
#   '넘',
#   '많아요',
#   '머좀',
#   '빠져들려면',
#   '바뀌고',
#   '바뀌고',
#   '전',
#   '시즌',
#   '1',
#   '부터',
#   '오로지',
#   '윤후',
#   '보려고',
#   '보는데',
#   '점점',
#   '산만해지는',
#   '느낌',
#   '이',
#   '예요',
#   '~~^^',
#   '우리',
#   '윤후',
#   '분량',
#   '좀',
#   '많이',
#   '많이',
#   '늘려주세요',
#   '~',
#   '^^',
#   '너',
#   '무착',
#   '하고',
#   '예쁜',
#   '후',
#   '~~^^'],
#  ['산만해서', '못', '봐주겠는', '영화'],
#  ['미국',
#   '이',
#   '진짜',
#   '선진국',
#   '인',
#   '이유',
#   '가',
#   '있구나',
#   '진짜',
#   '멋',
#   '지드',
#   '라',
#   '...',
#   '최고다'],
#  ['정말', '웃기', '다', 'ㅋㅋ', '1', '편도', '재밌지만', '2', '편이', '더', '재밌다', 'ㅋㅋ'],
#  ['아름다운', '영화'],
#  ['빨리',
#   '종영',
#   '돼길',
#   '여주',
#   '진짜',
#   '못',
#   '생겼다',
#   '머리스타일',
#   '은',
#   '수지',
#   '인데',
#   '이경실',
#   '닮았다',
#   '연',
#   '기도',
#   '짱',
#   '못',
#   '하고',
#   '연기자',
#   '하지마라',
#   '니나',
#   '오는',
#   '드라마',
#   '안',
#   '볼거니까'],
#  ['극장', '에서', '봤어용', '~', '잔잔한', '감동', '좋았습니다', '....'],
#  ['그', '때', '는', '어렸으니까', '재미있게', '봤지만', '지금', '보면', '...', 'ㅋ'],
#  ['스토리', '가', '좀', '뜬금', '없지만', '액션', '은', '역시', '화끈하다'],
#  ['진심', '이', '게', '재밌냐', '?', '분투', '하는', '청춘', '...', '기', '가', '찬다', '..'],
#  ['이',
#   '기적',
#   '인',
#   '남자',
#   '가',
#   '조그만',
#   '마을',
#   '에서',
#   '반복',
#   '된',
#   '일상',
#   '을',
#   '경험',
#   '하면서',
#   '착함을',
#   '얻는다는',
#   '내용',
#   '인데',
#   '다시',
#   '도시',
#   '로',
#   '돌아가면',
#   '경쟁',
#   '이라는',
#   '치열함',
#   '속',
#   '에서',
#   '다시',
#   '이',
#   '기적',
#   '인',
#   '본성',
#   '이',
#   '나올거',
#   '같음',
#   '.',
#   '너무',
#   '영',
#   '화구',
#   '성',
#   '이',
#   '작위',
#   '적',
#   '이고',
#   '단순하다',
#   '.',
#   '작은',
#   '시골',
#   '마을',
#   '에서나',
#   '통',
#   '할',
#   '이야기',
#   '.'],
#  ['3', '류', '영화', '베드', '신', '하나', '믿고', '봤는데', '캐', '실망', '~'],
#  ['처음',
#   '으로',
#   '영화관',
#   '가서',
#   '잠잤던',
#   '영화',
#   '내용',
#   '하',
#   '나',
#   '도기',
#   '억',
#   '안나',
#   '-_-'],
#  ['파트너',
#   '간',
#   '의',
#   '호흡',
#   '도',
#   '전혀',
#   '없고',
#   ',',
#   '아놀드',
#   '는',
#   '러시아어',
#   '쓰는',
#   '터미네이터',
#   '같았다',
#   '.'],
#  ['이', '영화', '엔딩', '곡', '노래', '제목', '아시나요'],
#  ['몇몇', '탁월한', '이미지', '와', '웅장', '한', '음악', '.', '단지', '그것', '뿐'],
#  ['안녕하세요',
#   '.',
#   '저',
#   '는',
#   '이',
#   '영화',
#   '속',
#   '삶',
#   '과',
#   '아주',
#   '흡사한',
#   '삶',
#   '을',
#   '살',
#   '고',
#   '있는',
#   '사람',
#   '입니다',
#   '.',
#   '하지만',
#   '이',
#   '영화',
#   '속',
#   '주인공',
#   '처럼',
#   '아이',
#   '를',
#   '낳진',
#   '않은것',
#   '만',
#   '배제',
#   '한다면',
#   '제',
#   '삶',
#   '이라고',
#   '해도',
#   '무방',
#   '하',
#   '군',
#   '요',
#   '.',
#   '이',
#   '영화',
#   '를',
#   '보게',
#   '된',
#   '계기',
#   '는',
#   '제',
#   '가',
#   '영화',
#   '를',
#   '좋아',
#   '하기',
#   '때문',
#   '입니다',
#   '.'],
#  ['시즌', '3', '까지', '본', '상태', '..', '잼네요', 'ㅋㅋ', '5', '까지', '달리는거다', '~~'],
#  ['기득권',
#   '에',
#   '취해',
#   '너무',
#   '썩은',
#   ',',
#   'but',
#   '썩은',
#   '지도',
#   '모르는',
#   '민주당',
#   '을',
#   '볼수',
#   '있다'],
#  ['개꿀잼', 'ㅋ', '개꿀잼', 'ㅋ', '10', '자'],
#  ['오프라인', '에', '나오셨던', '분신', '의', '선물', '보고', '이제야', '알았다', '.'],
#  ['생각',
#   '없이',
#   '봤는데',
#   '.',
#   '정말',
#   '생각',
#   '이',
#   '없었다',
#   '.',
#   '무슨',
#   '내용',
#   '을',
#   '전달',
#   '하려는',
#   '건지'],
#  ['어렸지만',
#   '정말',
#   '재밌게',
#   '봤던',
#   '외화',
#   '.',
#   '이',
#   '자료',
#   '가',
#   '있다니',
#   '너무',
#   '반갑다',
#   '.',
#   '좋은',
#   '세상',
#   '이야',
#   '.',
#   '특히',
#   '나',
#   '아들',
#   '스',
#   '코트',
#   '헤',
#   '이든',
#   '역',
#   '의',
#   '반즈',
#   '가',
#   '아직도',
#   '기억',
#   '생생',
#   '..',
#   '이름',
#   '까지',
#   '기억나네',
#   '..'],
#  ['정말', '괜찮은', '영화', '.', '행복', '이', '뭍', '어', '나', '는', '^^'],
#  ['한번', '봐서', '결과', '알', '고', '다시', '봐도', '재미', '있음'],
#  ['참', '저', '질', '스런', '영화', '내', '평가', '에', '내', '가', '놀란다', '!!'],
#  ['정말', '기발한', '생각', '이', '담긴', '영화', '였다', '.'],
#  ['저', '예산', '이지만', '개인', '적', '으로', '괜찮았음', '.'],
#  ['다방면', '으로', '만족', '...', '역시', '애니', '는', '판타지'],
#  ['"""""""',
#   '뽜',
#   '와',
#   '알리',
#   '뽜',
#   '아',
#   '아릴',
#   '""""',
#   '한국어',
#   '발음',
#   '에',
#   '개',
#   '빵터짐',
#   '"""'],
#  ['평점', '개', '사기', '다', ';', '이래서', '네이버', '평점', '못', '믿겠어', '..'],
#  ['그냥', '최고', '의', '드라마', '...', '그냥', '보세요', '.', 'ㅠㅠ'],
#  ['한예슬',
#   '진짜',
#   '너무',
#   '이쁘당',
#   'ㅋㅋㅋ',
#   '짱',
#   '인듯',
#   '원래',
#   '도',
#   '이쁜데',
#   '미',
#   '탄에서',
#   '이쁨',
#   '터짐',
#   'ㅋㅋㅋ',
#   '옷',
#   '입는것도',
#   '헤어',
#   '도',
#   '메이크업',
#   '도',
#   '이쁨',
#   '이쁨',
#   '이쁨',
#   '드라마',
#   '내용',
#   '도',
#   '괜찮고',
#   '잘',
#   '될듯',
#   'ㅋㅋㅋ'],
#  ['간만', '에', '웃는다', '!', '아하', '하하', '!!!'],
#  ['초반',
#   '부분',
#   '엔',
#   '좋았는데',
#   '점점',
#   '지루하고',
#   '소설',
#   '내',
#   '용이',
#   '쌩뚱맞다',
#   '..',
#   'ost',
#   '는',
#   '좋음'],
#  ['완벽하다', '!'],
#  ['아베',
#   '히로시',
#   '도',
#   ',',
#   '키',
#   '타무라',
#   '카',
#   '즈',
#   '키도',
#   '좋아하지만',
#   '...',
#   '너무',
#   '기대했나보다',
#   '.',
#   '보면서',
#   '나중',
#   '에는',
#   "'",
#   '온돌',
#   "'",
#   '도',
#   '지네',
#   '꺼',
#   '라',
#   '우기',
#   '면',
#   '어쩌나',
#   '...',
#   '하는',
#   '생각',
#   '도',
#   '들었다',
#   '.'],
#  ['ㅎ',
#   '애',
#   '들',
#   '이랑',
#   '넘',
#   '재미나',
#   '게',
#   '봤어요',
#   '하하호호',
#   '하면서',
#   '계속',
#   '웃음',
#   '이',
#   '나면서',
#   '가족',
#   '애',
#   '를',
#   '다시',
#   '한번',
#   '느꼈답니다'],
#  ['어렵게',
#   '사는',
#   '우리네',
#   '인생',
#   '이야기',
#   '답답하면서',
#   '현실',
#   '을',
#   '직시',
#   '한',
#   '내용',
#   '들',
#   '을',
#   '무겁게',
#   '잘',
#   '표현',
#   '하셨네요'],
#  ['시나리오', '연기', '연출', '모든', '면', '에서', '좋았다'],
#  ['그냥', '쓰레기', '지', '쓰레기', '~'],
#  ['나오',
#   '코',
#   '가',
#   '죽으니까',
#   '원래',
#   '귀신',
#   '보다',
#   '훨씬',
#   '더',
#   '무서움',
#   '.',
#   '나오',
#   '코',
#   '를',
#   '진작',
#   '죽일것이지',
#   'ㅋㅋ'],
#  ['한동안',
#   '댓글',
#   '안',
#   '썼었는데',
#   '..',
#   '댓글',
#   '이',
#   '너무해서',
#   '씁니다',
#   '.',
#   '1',
#   '점',
#   '까진',
#   '아닌데',
#   '평점',
#   '이',
#   '너무',
#   '높아',
#   '1',
#   '점',
#   '드리고요',
#   '..',
#   '한',
#   '3',
#   ',',
#   '4',
#   '점',
#   '짜리',
#   '영화인',
#   '듯',
#   '..',
#   '좋은',
#   '가족영화',
#   '라고',
#   '해서',
#   '개',
#   '를',
#   '훔치는',
#   '완벽한',
#   '방법',
#   '같은',
#   '영화로',
#   '상상',
#   '하고',
#   '봤는데',
#   '정말',
#   '뭐라',
#   '말',
#   '이',
#   '안',
#   '나오네요',
#   '..'],
#  ['말',
#   '에게도',
#   '사랑',
#   '이',
#   '있고',
#   '우정',
#   '이',
#   '있음',
#   '.',
#   '전쟁',
#   '이',
#   '무서운',
#   '걸',
#   '새삼',
#   '알',
#   '게',
#   '됬다하하하',
#   'ㅏ'],
#  ['유니크', '하고', '매력', '적', '인', '영화', '^^'],
#  ['최고', '의', '드라마', '..'],
#  ['또', '보고싶은'],
#  ['본', '영화', '들', '중', '가장', '...'],
#  ['이나영', '넘', '귀여워', 'ㅋㅋ', '귀여운', '영화', '인거', '같다', '.'],
#  ['이건', '무슨', '내용', '이', '없어', '...'],
#  ['이',
#   '드라마',
#   '의',
#   '시청률',
#   '이',
#   '한',
#   '팬',
#   '으로써',
#   '마음',
#   '이',
#   '안좋았지만',
#   '나',
#   '는',
#   '깨',
#   '달았어',
#   '..',
#   '시청률',
#   '이',
#   '낮을수록',
#   '재밌고',
#   '마음',
#   '이',
#   '깊이',
#   '느낄수있는',
#   '드라마',
#   '라',
#   '는걸'],
#  ['OOO', '기'],
#  ['미', '확인', '동영상', ':', '영화', '절대', '클릭', '금지'],
#  ['우선',
#   '평점',
#   '1',
#   '점',
#   '의',
#   '이유',
#   '는',
#   '현재',
#   '평점',
#   '이',
#   '너무나',
#   '높기',
#   '때문',
#   '이다',
#   '간략해서',
#   '영',
#   '화보',
#   '는',
#   '내내',
#   '엄청나게',
#   '불편',
#   '햇',
#   '다',
#   '서울시장',
#   '후보',
#   '아내',
#   '엄정화',
#   '가',
#   '나와서',
#   '서른',
#   '도',
#   '넘은',
#   '섹시',
#   '가수',
#   '몸',
#   '에',
#   '착',
#   '달라붙고',
#   '가슴',
#   '이',
#   '거의',
#   '다',
#   '보이는',
#   '의상',
#   '을',
#   '입고',
#   '춤',
#   '을',
#   '출',
#   '때',
#   '불쾌함을',
#   '넘어',
#   '상당히',
#   '안좋은',
#   '기분',
#   '을',
#   '느끼게',
#   '해준다'],
#  ['원작',
#   '이',
#   '너무',
#   '좋았다',
#   '..',
#   '일본',
#   '은',
#   '영화',
#   '리메이크',
#   '가',
#   '늘',
#   '한심하다',
#   '..'],
#  ['어차피', '우승', '은', '송민호', '~'],
#  ['10만',
#   '표로',
#   '무슨',
#   '대국민',
#   '투표',
#   '라고',
#   '사기',
#   '를',
#   '치고',
#   '어휴',
#   '...',
#   '박시환',
#   'MAMA',
#   '가는거',
#   '생각',
#   '만',
#   '해도',
#   '끔찍하다'],
#  ['이건',
#   '진짜',
#   '6',
#   '점',
#   '이',
#   '적당함',
#   '평점',
#   '내려야',
#   '됨',
#   '화끈한',
#   '액션',
#   '이',
#   '있는것도',
#   '아니고',
#   '반전',
#   '이',
#   '엄청난것도',
#   '아니고',
#   '노',
#   '출신',
#   '이',
#   '있는것도',
#   '아니고',
#   '보다가',
#   '살짝',
#   '잠들었음'],
#  ['쓰레기', '중', '의', '쓰레기', '영화', '모든', '것', '이', '쓰레기', '다', '.'],
#  ['이', '젠', '측은해', '지기', '까지', '하는', '니콜라스', '케이', '지'],
#  ['전개',
#   '억지스럽고',
#   '연출',
#   '도',
#   '조금',
#   '산만한듯',
#   '소품',
#   '들',
#   '도',
#   '좀',
#   '어색합니다',
#   '비행기',
#   '씬',
#   '은',
#   '어쩔',
#   '수',
#   '없다지만',
#   '..'],
#  ['이', '것', '도', '진짜', '재밌게', '본듯'],
#  ['별',
#   '반개',
#   '도',
#   '아까운',
#   '영화',
#   '.',
#   '멀쩡한',
#   '배우',
#   '들',
#   '을',
#   '3',
#   '류',
#   '배우',
#   '로',
#   '추락',
#   '시킴',
#   '.',
#   '각본',
#   ',',
#   '연출',
#   ',',
#   '영상',
#   '모두',
#   '수준',
#   '이하'],
#  ['완전', '찝찝한', '영화', '...'],
#  ['정은채', '...', '연기', '드럽게', '못', '하네', 'ㅉㅉㅉ'],
#  ['천국', '보다', '아름다운', '것', '은', '사랑', '?'],
#  ['1',
#   '.',
#   '감독',
#   '이',
#   '씨발',
#   '바쁜게',
#   '아니라면',
#   '이따위',
#   '로',
#   '찍',
#   '을',
#   '이유',
#   '가',
#   '없다',
#   '.',
#   '직선',
#   '으로',
#   '가는',
#   '길',
#   '놔두고',
#   '돌아가는걸',
#   '두고',
#   '획기',
#   '적',
#   '이라고는',
#   '하지',
#   '않는다',
#   '.',
#   '2',
#   '.',
#   '영화인',
#   '들',
#   '의',
#   '특권',
#   '의식',
#   '과',
#   '그',
#   '들',
#   '의',
#   '촬영',
#   '하는',
#   '행위',
#   '에',
#   '대한',
#   '미화',
#   '가',
#   '듬뿍',
#   '담겨져있',
#   '따',
#   '.',
#   '그리고',
#   '전체',
#   '적',
#   '인',
#   '내용',
#   '재미',
#   '도',
#   '없고',
#   '의미'],
#  ['어이없게',
#   '웃기',
#   '고',
#   '지기',
#   '의',
#   '아빠',
#   '가왜',
#   '나왔는지',
#   '아직도',
#   '의문',
#   ',,',
#   '날',
#   '패닉',
#   '상태',
#   '로만',
#   '든',
#   '최악',
#   '의',
#   '영화'],
#  ['와', '...', 'ㅋㅋ', '언', '제', '쩍', '스티븐', '시', '걸이', '냐', 'ㅋㅋ'],
#  ['솔직히',
#   '베드',
#   '신',
#   '보려고',
#   ',',
#   '보게',
#   '된',
#   '영화',
#   '인데',
#   '중간',
#   '중간',
#   '대사',
#   '에',
#   '몰입',
#   '되면서',
#   '처음',
#   '부터',
#   '끝',
#   '가지',
#   '풀',
#   '로',
#   '보게',
#   '되었습니다',
#   '.',
#   '원작',
#   '책',
#   '으로는',
#   '읽어',
#   '보진',
#   '못',
#   '하였지만',
#   '책',
#   '도',
#   '한번',
#   '봐야겠군요',
#   '감명',
#   '깊게',
#   '잘',
#   '보았습니다',
#   '.'],
#  ['오늘',
#   '도',
#   '대학로',
#   '에서',
#   '방송국',
#   '에서',
#   '열심히',
#   '기회',
#   '를',
#   '찾는',
#   '분들',
#   ',',
#   '힘내시길',
#   '!'],
#  ['으', '~~', '최악', '이다'],
#  ['재미',
#   '잏',
#   '긴한데',
#   '맨',
#   '마지막',
#   '부분',
#   '이',
#   '너',
#   '무산',
#   '으로가',
#   '버렸어요',
#   '.',
#   '갑자기',
#   '가족',
#   '이다',
#   '만나고',
#   '해피엔딩',
#   '이지만',
#   '맨',
#   '마지막',
#   '부분',
#   '이',
#   '좀',
#   '그러네요'],
#  ['한번', '보면', '빠져들어', '버리는', '...', '재미있는', '사신', '드라마', '.'],
#  ['퀄리티', ':', '주원', '김아중', '나오는', '뽀로로'],
#  ['그냥', '별', '생각', '없이', '보고나서', '생각', '해보니', '감탄사', '가', '터지는', '영화'],
#  ['아오', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'ㅅㅂ', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['인생',
#   '은',
#   '아직도',
#   '보고',
#   '배울',
#   '것',
#   '이',
#   '많겠지',
#   ',,',
#   '하지만',
#   '난',
#   '왜',
#   '이렇게',
#   '움',
#   '추리',
#   '고',
#   '있을까',
#   ',,,'],
#  ['나', '잤다', '그냥', '영화관', '에', '팝콘', '이나', '먹자'],
#  ['난', '재미있는데', 'ㅋ', '?'],
#  ['좋다'],
#  ['정말', '재밋', '게', '본', '작품', '이다', '..', '왜', '이제', '서야', '봤을까'],
#  ['왜', '한국인', '간', '들이', '배', '낀거있지', '?', '말', '않', '해도', '알꺼라'],
#  ['이',
#   '영화',
#   '는',
#   '재미',
#   '보다는',
#   '메세지',
#   '를',
#   '전',
#   '하는것',
#   '같네요',
#   '잔잔하면서도',
#   '그다음',
#   '장면',
#   '이',
#   '궁금하게',
#   '만드는',
#   '영화',
#   '.'],
#  ['Gooooooooood', '민세', '연', '박영린', '넘', '이쁘다'],
#  ['딱히',
#   '노래',
#   '말고는',
#   '건질게',
#   '없는',
#   '..',
#   '남녀',
#   '캐릭터',
#   '가',
#   '매력',
#   '적',
#   '이지',
#   '않다는',
#   '게',
#   '가장',
#   '큰',
#   '문제',
#   '고',
#   ',',
#   '내용',
#   '도',
#   '너무',
#   '유치하게',
#   '흘러간다는',
#   '것',
#   '.'],
#  ['추천', '할만', '한', '경', '제', '영화', '였음'],
#  ['시나리오', '는', '별로', '인데', '배우', '들', '이', '살린', '영화', '..'],
#  ['세영', '어느', '정도', '것', '해야지', '욕', '나오도록', '천', '사표', '..', 'OO'],
#  ['보지',
#   '도',
#   '못',
#   '한',
#   '사람',
#   '들',
#   '이',
#   '왜',
#   '.',
#   '평점',
#   '달',
#   '지',
#   '?',
#   '그나저나',
#   '이',
#   '게',
#   '있다는게',
#   '신기하',
#   '넹',
#   'ㅋ',
#   '30분',
#   '짜리영화',
#   '돈',
#   '다주',
#   '고',
#   '봤었는데',
#   'ㅋㅋ'],
#  ['완존', '재밌어'],
#  ['차가',
#   '아니고',
#   '괴물',
#   '이면',
#   '괴물',
#   '이지',
#   '문',
#   '은',
#   '왜',
#   '잠기냐',
#   'ㅋㅋ',
#   '괴물',
#   '이',
#   '초능력',
#   '도',
#   '쓰냐',
#   '?'],
#  ['I', 'wonder', 'this', 'movie', '.'],
#  ['호프만',
#   '과',
#   '핵',
#   '크만을',
#   '동시',
#   '에',
#   '볼',
#   '수',
#   '있다는',
#   '것',
#   '만으로',
#   '10',
#   '점',
#   '이다',
#   '.',
#   '개연',
#   '성',
#   '에는',
#   '다소',
#   '무리',
#   '가',
#   '있었지만',
#   '색다른',
#   '시도',
#   '가',
#   '좋았다',
#   '.'],
#  ['이건', '또', '뭐임', '이', '거뭐', '중국영화', '임', '?'],
#  ['리얼리티', '감동'],
#  ['자각', '과', '깨달음', '의', '무서움', '!!'],
#  ['재미있네요', '커플', '들', '끼리', '보면', '좋을거', '같네요', '^^'],
#  ['원주율', '좀', '만들어', '보자', '.,.,'],
#  ['아주', '썩어', '빠진', '영화'],
#  ['료코', '짱'],
#  ['결국', '종', '을', '울리는', '구나', '...'],
#  ['헐', '...', '죄송합니다', '이건', '아니', '네', '여'],
#  ['옼', '케이', '앟', '~', '드르륵', '손', '으로', '싹', '싹', '~', '킁', '~'],
#  ['재미있고', '흥미진진', '함', '강', '추합니다', '!'],
#  ['보면서', '상당히', '당황', '했던', '....'],
#  ['뼈채', '먹을', '코', '메디'],
#  ['난', '진짜', '재밌게', '봤어요', '신세경', '연기', '가', '약간', '좀', '그랬지만'],
#  ['무엇', '보다도', '발연기', '가', '영화', '집중', '하는데', '큰', '방해', '요소', '였다', '-_-'],
#  ['섬세함을', '요하', '는', '영화', '인데', '섬세함이', '없는', '영화', ';;'],
#  ['얍얍', '콩', '나와라', '뚝딱', '!!!'],
#  ['이렇게',
#   '단순한',
#   '이야기',
#   '를',
#   '지루하게',
#   '2시간',
#   '이나',
#   '넘게',
#   '찍은',
#   '것',
#   '도',
#   '참',
#   '한심함',
#   '.',
#   '사무라이',
#   '를',
#   '욕먹이는',
#   '영화'],
#  ['남매',
#   '는',
#   '그런게',
#   '아닐까',
#   '?',
#   '때로는',
#   '엄마',
#   '같은',
#   '누나',
#   ',',
#   '때로는',
#   '오빠',
#   '같은',
#   '동생',
#   ',',
#   '잔잔함',
#   '그리고',
#   '일본',
#   '특',
#   '유의',
#   '소박함이',
#   '묻어나는',
#   '따스한',
#   '영화',
#   '.'],
#  ['마지막', '윌', '이', '아들', '을', '향', '해', '소리치는건', '정말', '기억', '에', '남습니다', '.'],
#  ['아', '진짜', '재밌게', '봤습니다', '♥♥'],
#  ['개인',
#   '적',
#   '평점',
#   '은',
#   '6',
#   '점',
#   '이지만',
#   '좋은',
#   '원작',
#   '과',
#   '배우',
#   '들',
#   '로',
#   '영화',
#   '를',
#   '이따위',
#   '로',
#   '만든',
#   '죄',
#   '가',
#   '더',
#   '크다',
#   '결정',
#   '적',
#   '인',
#   '건',
#   '벨아미',
#   '란',
#   '제목',
#   '처',
#   '첨',
#   '로버트패틴슨',
#   '이',
#   '아름다운',
#   '남자',
#   '로',
#   '보이지',
#   '도',
#   '않았다'],
#  ['흠',
#   '...',
#   '관객',
#   '들',
#   '가지',
#   '고',
#   '노',
#   '는',
#   '건가',
#   '?',
#   '상영',
#   '도',
#   '안',
#   '하는데',
#   '..'],
#  ['황추생',
#   '이랑',
#   '오진우',
#   '의',
#   '엄청난',
#   '악역',
#   '연기',
#   '가',
#   '막장',
#   '스토리',
#   '에',
#   '묻혀',
#   '버려서',
#   '아쉬운',
#   '작품',
#   '..'],
#  ['일본인',
#   '팼다',
#   '뭐',
#   '그런',
#   '걸',
#   '떠나서',
#   '웬만하면',
#   '중국영화',
#   '는',
#   '평점',
#   '높게',
#   '안',
#   '주는데',
#   '괜찮은',
#   '영화인',
#   '듯'],
#  ['나도', '다큐', '나', '찍어', '볼까'],
#  ['이딴', '걸', '방송', '이라고', '쳐', '만들', '엇', '나', 'ㅋ', '욕', '만', '나오네', 'ㅗ'],
#  ['보는',
#   '내내',
#   '가슴',
#   '이',
#   '아팠지만',
#   '이',
#   '게',
#   '현실',
#   '이라는',
#   '게',
#   '참으로',
#   '속상했습니다',
#   '.'],
#  ['기대', '된디'],
#  ['정준', '용씨', '연기', '넘', '멋져용', '!!!'],
#  ['캐롤',
#   '의',
#   '첫사랑',
#   '이라는',
#   '제목',
#   '으로',
#   '일본',
#   '에서',
#   '개봉',
#   '했죠',
#   '...',
#   '괜찮은',
#   '영화',
#   '입니다',
#   '..'],
#  ['디카프리오', '는', '진리', '다', '미친', '연기력', '에', '빠져들었다'],
#  ['감독', '을', '마파도', '로', '보내고', '싶다', '.'],
#  ['잔잔하고',
#   '짧지만',
#   '감동',
#   '은',
#   '확실하네요',
#   '.',
#   '엄마',
#   '에',
#   '대해',
#   '생각',
#   '할',
#   '수',
#   '있는',
#   '기회',
#   '였어요',
#   '.'],
#  ['저희',
#   '엄마',
#   '도',
#   '재밌다고',
#   '하고',
#   '곰',
#   '도',
#   '귀엽고',
#   '웃기면서',
#   '감동',
#   '적이네요',
#   '추천',
#   '합니다'],
#  ['진심', '핵', '노잼', '감독', '의', '역량', '을', '따져', '볼', '필요성', '을', '느끼는', '영화'],
#  ['이건', '정말', '명작', '이네', '요'],
#  ['6월', '6일', '현충일', '.', '감사합니다', '.'],
#  ['다람쥐', '들', '이', '귀', '여울', '뿐', '아무', '것', '도', '없다'],
#  ['저',
#   '한테',
#   '황금',
#   '시간',
#   '인',
#   '밤',
#   '10시',
#   '에',
#   '지상파',
#   '가',
#   '아니',
#   '케이블',
#   '보게',
#   '만들었어요',
#   '..',
#   '정말',
#   '대단함',
#   'ㅎㅎ',
#   '그녀',
#   '의',
#   '신화',
#   '너무',
#   '재밌',
#   'ㅇ',
#   '어요',
#   '..',
#   '한',
#   '회',
#   '한',
#   '회볼때',
#   '마다',
#   '지루하지',
#   '않고',
#   '시간',
#   '가는줄',
#   '모르겠어요',
#   '~',
#   '지상파',
#   '면',
#   '완전',
#   '대박',
#   '인데',
#   '아쉽네요',
#   '..',
#   'ㅠㅠㅠ'],
#  ['역시', '명작', '~', '최고', '입니다'],
#  ['농담', '따먹기', '수준', '도', '안', '된다'],
#  ['진짜',
#   '한번',
#   '더보',
#   '고',
#   '싶은',
#   '영화',
#   '입니다',
#   '콩코드기',
#   '가',
#   '나오는',
#   '영화',
#   '인데',
#   '....',
#   '끝',
#   '장면',
#   '이',
#   '참',
#   '안타까운',
#   '영화',
#   '이지',
#   '요'],
#  ['그', '시', '대', '그', '시절', '의', '청춘', '상', '.', '아련하고', '우습고', '짠하다'],
#  ['못', '해도', '8', '점', '은', '되야지', '7', '점', '은', '아닌듯'],
#  ['이', '영화', '를', '보기', '전', '으로', '돌아가고', '싶어요'],
#  ['꿀잼', '허니', '잼', '포도', '잼', '딸기', '잼'],
#  ['생각나서', '들렀는데', '평점', '왜', '이렇지', '....'],
#  ['청리',
#   '중국사람',
#   '입니다',
#   '.',
#   '청리',
#   '를',
#   '보조',
#   '하는',
#   '애가',
#   '한국',
#   '마크',
#   '달',
#   '고',
#   '잇',
#   '엇',
#   '지'],
#  ['이렇게', '멋진', '영화', '를', '이제', '서', '보다니', '..'],
#  ['교육',
#   '이',
#   '무너진',
#   '근본',
#   '적',
#   '인',
#   '원인',
#   '에',
#   '대해',
#   '잘',
#   '보여준',
#   '영화',
#   '...',
#   '어른',
#   '들',
#   '의',
#   '과오',
#   ',',
#   '부모',
#   '와',
#   '사회',
#   '의',
#   '몰락',
#   '이',
#   '순수한',
#   '아이',
#   '들',
#   '의',
#   '행동',
#   '들',
#   '로',
#   '보여지는',
#   '것'],
#  ['좀더', '재미있게', '만들면', '..'],
#  ['혼자',
#   '보기',
#   '에는',
#   '정말',
#   '좋은',
#   '영화',
#   '임',
#   '^^',
#   '나름',
#   '작품',
#   '이해',
#   '하려',
#   '노력',
#   '하고',
#   '심취',
#   '하니',
#   '재밌더라고요'],
#  ['이상하다', '나카타', '감독', '링', '은', '잘', '만들었는데', '이건', '왠지', '...;;.'],
#  ['재미', '만', '있구만', 'ㅋ', '뭔', '작품', '성', '따지고', '보냐', 'ㅋㅋ'],
#  ['존내', '멋', '잇어', 'ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ'],
#  ['이',
#   '영화',
#   '는',
#   '진짜',
#   '아름다운',
#   '영화',
#   '다',
#   '이렇게',
#   '아름다운',
#   '영화',
#   '를',
#   '만들수',
#   '있다는것에',
#   '놀랐다'],
#  ['슈퍼맨', '死', '-', '최악', '의', '편', '.'],
#  ['공유', '보려고', '보는', '영화'],
#  ['약간',
#   '아쉬운면도',
#   '없지',
#   '않았지만',
#   '제',
#   '기',
#   '대',
#   '이상',
#   '이었습니다',
#   '배우',
#   '들',
#   '의',
#   '연기',
#   '가',
#   '너무',
#   '좋아서',
#   '특히',
#   '마이',
#   '한테',
#   '감정이입',
#   '이',
#   '저절로',
#   '되드라구',
#   '요',
#   '잘',
#   '봤습니다',
#   '!'],
#  ['어렸을',
#   '때',
#   '봤을',
#   '때',
#   '영화',
#   '속',
#   '인어',
#   '속',
#   '꼬리',
#   '가',
#   '너무나',
#   '신비롭게',
#   '보였던',
#   '.'],
#  ['여기', '나오는', '아줌마', '들', '다', '귀', '여', '움', '^^..', '끝', '까지', '..'],
#  ['깡패',
#   '같은',
#   '세상',
#   '깡',
#   '으로',
#   '뭘',
#   '버텨',
#   '?',
#   '연출',
#   '이',
#   '깡패',
#   '다',
#   '갈래',
#   '가',
#   '뭐',
#   '냐',
#   '삼계탕',
#   '조금',
#   '먹고',
#   '후라이드',
#   '한',
#   '입',
#   '먹고',
#   '삼겹살',
#   '먹는',
#   '식이',
#   '다'],
#  ['진짜', '소름', '이', '돋는다'],
#  ['이도영', '오빠', '화이팅', '!', '힝', '상응', '원해요'],
#  ['지하실',
#   '에',
#   '갖혀서',
#   '속',
#   '고사',
#   '는',
#   '건',
#   '어쩌면',
#   ',',
#   '우리',
#   '일지',
#   '도',
#   '몰라',
#   '.'],
#  ['간만', '에', '쓰레기', '영', '화보', '네', '요', 'ㅋ'],
#  ['완전',
#   '잼있네요',
#   'ㅋㅋ',
#   '근데',
#   '이',
#   '거',
#   '2',
#   '편',
#   '을',
#   '계획',
#   '하고',
#   '끝낸거',
#   '같은데',
#   '....',
#   '2',
#   '편',
#   '은',
#   '어찌',
#   '...?;;',
#   'ㅜㅡ'],
#  ['이건', '1', '점도', '아까운', '영화', '.'],
#  ['밀양',
#   '성폭행',
#   '가해자',
#   '들',
#   '이',
#   '부디',
#   '지옥',
#   '깊숙히',
#   '떨어지',
#   '기를',
#   '기원',
#   '합니다',
#   '^^'],
#  ['뭥미', '?', '헐', '~'],
#  ['Wow',
#   '~!',
#   '멋진',
#   '반전',
#   '!!!!',
#   '온',
#   '몸',
#   '에',
#   '전율',
#   '이',
#   '흐르는',
#   '영화',
#   '!!!!'],
#  ['너무',
#   ',,,',
#   '당황',
#   ',',
#   '비',
#   '때문',
#   '에',
#   '봤지만',
#   '너무',
#   '몰상식해서',
#   '다',
#   '안',
#   '봤다',
#   '.'],
#  ['최고', '의', '사랑', '을', '느끼게', '해준', '영화'],
#  ['리암',
#   '니',
#   '슨',
#   '형',
#   '엄청',
#   '고생',
#   '하면서',
#   '찍었는데',
#   '영화',
#   '자체',
#   '는',
#   '드럽게',
#   '잼없드',
#   '라',
#   '.'],
#  ['너무', '재밌게', '봤어요', '...'],
#  ['학생',
#   '(',
#   '중',
#   '~',
#   '대',
#   ')',
#   '절때',
#   '로',
#   '보지말',
#   '껏',
#   ',',
#   '어린',
#   '아들',
#   '캐',
#   '초딩',
#   '들',
#   '만',
#   '관람',
#   '할',
#   '껏'],
#  ['영화', '내공', '향상', '을', '위해', '이를', '악물고', '..', '감내해', '야할', '성', '장통'],
#  ['쓰레기', 'ㅡㅡ'],
#  ['맨', '땅', '에', '시청률'],
#  ['개인',
#   '적',
#   '점수',
#   '는',
#   '9',
#   '점',
#   '.',
#   '김희선',
#   '의',
#   '재',
#   '발견',
#   '에',
#   '+',
#   '1',
#   '점',
#   '.',
#   '합',
#   '이',
#   '10',
#   '점',
#   '.',
#   '취향',
#   '을',
#   '탈거',
#   '같으면서도',
#   '의외로',
#   '누구',
#   '나',
#   '빠져드는',
#   '영화',
#   '.'],
#  ['로버트',
#   '드니',
#   '로',
#   '+',
#   '알파',
#   '치노',
#   '=',
#   '명화',
#   '.',
#   'bacause',
#   'she',
#   'got',
#   'a',
#   'great',
#   'ass',
#   '!!',
#   'ㅋㅋㅋㅋ'],
#  ['짜고치는', '고스톱', '에', '마지막', '장면', '진짜', '허무함', '.', 'ㅡㅡ'],
#  ['코믹', '호러', '용치', '고', '수작', '인데', '평점', '너무', '낮다'],
#  ['영화',
#   '대박',
#   '!!!!!!',
#   '노래',
#   '도',
#   '너무',
#   '좋고',
#   '무엇',
#   '보다',
#   '항상',
#   '열심히',
#   '하는',
#   '모습',
#   '이',
#   '너무',
#   '좋아요',
#   '.'],
#  ['지루하다가',
#   '결말',
#   '은',
#   '어이없이',
#   '허무하게',
#   '끝남',
#   ',,',
#   '극장',
#   '에서',
#   '안',
#   '봐도',
#   '될',
#   '영화',
#   ',',
#   '그리고',
#   '굳이',
#   '안',
#   '봐도',
#   '될',
#   '영화'],
#  ['킹오파', '영화', '랑', '이', '거', '랑', '비교', '해봐라', '이', '게', '훨씬', '명작', '이다'],
#  ['등장인물', '외오고', '봐야', '할', '영화', '지만', '스토리', '는', '완벽합니다', '.'],
#  ['세상', '에는', '보이는것보다', '보이지', '않는것이', '더', '많다'],
#  ['정말',
#   '역사',
#   '에',
#   '남',
#   '을',
#   '만',
#   '한',
#   '소름끼치는',
#   '작품',
#   '인데',
#   '평점',
#   '은',
#   '양',
#   '아치',
#   '조폭',
#   '형사',
#   '살인',
#   '범',
#   '쳐',
#   '나오는',
#   '몇몇',
#   '한국영',
#   '화',
#   '따위',
#   '보다도',
#   '낮네',
#   '?',
#   '안타깝다',
#   '안타까워',
#   '!!'],
#  ['중학교',
#   '시절',
#   '재',
#   '밋게봣',
#   '엇',
#   '는데',
#   '요',
#   '새',
#   '다시',
#   '생각',
#   '이나',
#   '서',
#   '찾아보니',
#   '감회',
#   '가',
#   '새',
#   '롭고',
#   '또',
#   '재밌네요',
#   '조금',
#   '만',
#   '더있음',
#   '10년',
#   '전',
#   '영화',
#   '임',
#   '에도',
#   '촌스럽다는',
#   '느낌',
#   '이적',
#   '네',
#   '요',
#   '궁',
#   '2',
#   '가',
#   '나오길',
#   '그렇게',
#   '바랫',
#   '건만',
#   '갑자기',
#   '또',
#   '아쉬운',
#   '생각',
#   '이드',
#   '네',
#   '요'],
#  ['액션',
#   '이',
#   '대단했습니다',
#   '..',
#   '몰입',
#   '감도',
#   '좋았구요',
#   '..',
#   '개인',
#   '적',
#   '으로',
#   '아저씨',
#   '의',
#   '원빈',
#   '보다',
#   '멋있었네요',
#   ';;',
#   '더',
#   '고생',
#   '한',
#   '거',
#   '같구요',
#   '..'],
#  ['에이', '모야'],
#  ['아름다운', '감동', '.', '실화', '에', '기초', '했다니', '놀라', '움'],
#  ['진짜',
#   '머',
#   '하자는거냐',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '좀비',
#   '영화',
#   '보고',
#   '악플',
#   '처음',
#   'ㄱ',
#   'ㅐ',
#   '재미',
#   '업다',
#   '진짜',
#   '로'],
#  ['가족', '과', '같은', '느낌', '을', '주는', '영화', '^^'],
#  ['이', '시리즈', '가', '3', '까지', '나오넥', '기적', '이다'],
#  ['그렇게', '대단하지', '않다'],
#  ['씁쓸한',
#   '것',
#   '같지만',
#   '뭔가',
#   '깊은',
#   '여운',
#   '이',
#   '남았다',
#   '.',
#   '물론',
#   '스웨덴',
#   '의',
#   '분위기',
#   '는',
#   '쫓아가지',
#   '못',
#   '했지만',
#   '재밌게',
#   '봤다',
#   '.',
#   '클로이',
#   '사랑',
#   '함',
#   '흐헬'],
#  ['얼굴', '시꺼먼게', '먼', '죄', '냥', '....'],
#  ['<',
#   '진심',
#   '>',
#   '이란',
#   '게',
#   '어떤',
#   '건지',
#   '제대로',
#   '보여주는',
#   '영화',
#   '.',
#   '98%',
#   '가',
#   '이슬람교',
#   '인',
#   '<',
#   '이란',
#   '>',
#   '이기',
#   '에',
#   '더',
#   '절묘해진',
#   '영화',
#   '.'],
#  ['감독', '은', '원작', '을', '보았는지', '의문', '스럽다'],
#  ['4000원', '보다', '아까운건', '120분', '의', '시간', '이다'],
#  ['아래', '평점', '에', '속', '았', '다', '...'],
# ...
#   '희망',
#   '가족',
#   '과',
#   '함께',
#   '지금',
#   '현재',
#   '우리',
#   '의',
#   '삶',
#   '의',
#   '감사함을',
#   '느끼게',
#   '한다',
#   '.',
#   '잊혀져',
#   '가는',
#   '기',
#   '부문',
#   '화',
#   '가',
#   '다시',
#   '회복',
#   '되길',
#   '바랍니다',
#   '.~'],
#  ['클레멘타인', '7', '광구', '그리고', 'r', '2', 'b'],
#  ['Hugh',
#   'Grant',
#   '-',
#   'Don',
#   "'",
#   't',
#   'Write',
#   'Me',
#   'Off',
#   ',',
#   'Hugh',
#   'Grant',
#   '&',
#   'Haley',
#   'Bennett',
#   '-',
#   'Way',
#   'Back',
#   'Into',
#   'Love',
#   '....',
#   '乃'],
#  ['별로', '같은', '뎅', '..'],
#  ['매', '순간', '최선', '을', '.', '그런다면', '내게도', '최상', '의', '결과', '가', '생길지도', '!'],
#  ['역시', '충분히', '재밌음', '.'],
#  ['정말',
#   '무서운',
#   '영화',
#   '다',
#   '감독',
#   '이',
#   '무섭고',
#   '진짜',
#   '무서운',
#   '반전',
#   '은',
#   '2',
#   '편이',
#   '나올까봐',
#   '무섭다',
#   '오',
#   '인천',
#   '감독',
#   '은',
#   '세계',
#   '적',
#   '거장',
#   '우베',
#   '볼',
#   '을',
#   '잇는',
#   '진정',
#   '한국',
#   '의',
#   '우베',
#   '볼',
#   '이다'],
#  ['사랑',
#   '하는',
#   '사람과',
#   '함께',
#   '늙을수',
#   '없는것',
#   '그것',
#   '이',
#   '주인공',
#   '에게',
#   '내려진',
#   '저주',
#   '이다'],
#  ['재밌는데', '평점', '이', '과소', '하여', '10', '점'],
#  ['말로', '표현', '못', '함', 'ㄷㄷ', '진짜'],
#  ['뭔가',
#   '역',
#   '동',
#   '적',
#   '인',
#   '씬',
#   '없이',
#   '잔잔하게',
#   '흘러가도',
#   '묵직한',
#   '분위기',
#   '로',
#   '보는',
#   '이를',
#   '장악',
#   '함',
#   '.',
#   '김기덕',
#   '감독',
#   '영화',
#   '처음',
#   '보는데',
#   '잘',
#   '만들었다는',
#   '생각',
#   '이',
#   '절로',
#   '들었다',
#   '.'],
#  ['마음', '이', '따뜻해', '지는', '영화', '.'],
#  ['성유리', ',', '정겨운', ',', '김민준', '등', '정말', '재밌게', '연기', '잘하네요', '..'],
#  ['정말',
#   '막장',
#   '...',
#   '그렇게',
#   '당',
#   '하고도',
#   '지네',
#   '작업실',
#   '문',
#   '절대',
#   '안',
#   '잠그고',
#   '맨날',
#   '도난',
#   '당',
#   '하고',
#   '..',
#   '초등학생',
#   '애',
#   '들',
#   '도',
#   '이러게',
#   '망청',
#   '한',
#   '짓',
#   '들',
#   '은',
#   '안',
#   '하겠다',
#   '.',
#   '짜증나서',
#   '다시는',
#   '안',
#   '볼꺼',
#   '임',
#   '..'],
#  ['정신',
#   '줄',
#   '놓고',
#   '만들',
#   '엇',
#   '나',
#   '?',
#   '줄거리',
#   '에',
#   '수꼴',
#   '이란',
#   '말',
#   '이',
#   '나오네',
#   '거기',
#   '다',
#   '할아버지',
#   '를',
#   '죽여',
#   '?',
#   '좌빨',
#   '들',
#   '의',
#   '인민재판',
#   '엔',
#   '가족',
#   '도',
#   '나이',
#   '도',
#   '없다는거',
#   '광고',
#   '하는',
#   '영',
#   '화구',
#   '나',
#   '북한',
#   '에',
#   '보내라',
#   '.',
#   '김정은',
#   '좋아하겟다'],
#  ['시리즈', '물', '영화', '중', '최고', '캐리비안', '의', '해적', '~'],
#  ['어수선하고',
#   '뭘',
#   '말',
#   '하고자',
#   '하는지',
#   '모르겠고',
#   ',',
#   '그냥',
#   '감옥',
#   '에서',
#   '일어나는',
#   '오',
#   '바',
#   '소동',
#   '들',
#   '오렌지',
#   '이즈',
#   '더',
#   '뉴',
#   '블랙',
#   '하고',
#   '비슷하지만',
#   ',',
#   '재미',
#   '는',
#   '반도',
#   '못',
#   '따라감'],
#  ['뚱보흑', '인', '사무라이', '라', '...', '-_-;;', '말', '이', '안', '나왔다', '.'],
#  ['지루한', '앞', '부분', '허무한', '뒷', '부분'],
#  ['취향', '의', '차이', '를', '확인', '하다', '.'],
#  ['대학',
#   '등록금',
#   '이랑',
#   '몸',
#   '파는',
#   '거',
#   '랑',
#   '무슨',
#   '의미',
#   '가',
#   '있다는',
#   '건지',
#   '?',
#   '돈',
#   '이',
#   '없으면',
#   '대학',
#   '안',
#   '가면',
#   '되는',
#   '거고',
#   '꼭',
#   '가고싶으면',
#   '노동',
#   '을',
#   '해서',
#   '정당하게',
#   '돈',
#   '을',
#   '벌면',
#   '되는거지',
#   '몸',
#   '파는걸',
#   '정당화',
#   '시킬려고',
#   '하네',
#   'ㅋㅋ',
#   '저런',
#   '인간',
#   '들',
#   '이',
#   '지',
#   '능력',
#   '은',
#   '인정',
#   '못',
#   '하고',
#   '주변',
#   '환경',
#   '탓',
#   '하',
#   '거나',
#   '신',
#   '세',
#   '타령',
#   '만',
#   '늘어놓지'],
#  ['평점',
#   '4',
#   '점',
#   '대',
#   '감안',
#   '해봐서',
#   '기',
#   '대안',
#   '하고',
#   '봤는데',
#   '기대',
#   '이하',
#   '를',
#   '보여주는',
#   '영화',
#   '..',
#   'ㅅㅅ',
#   '씬',
#   '은',
#   '필요없어',
#   '보이는데',
#   '왜',
#   '넣',
#   '엇',
#   '지'],
#  ['강', '시숙', '숙', '(', '강시선생', '4', ')', '이', '제일', '재미', '잇음'],
#  ['너무', '잘', '봤음', '....', '눈물', '이', 'ㅠ'],
#  ['양심', '없는', '서', '퉁', '의', '울', '궈', '먹기', '는', '이제', '그만'],
#  ['영화',
#   '라고',
#   '쓴',
#   '분',
#   '들',
#   '옆',
#   '에',
#   '다큐멘터리',
#   '라',
#   '쓰인건',
#   '안',
#   '보이시나',
#   '봐요',
#   '^^;'],
#  ['너무',
#   '저',
#   '평가',
#   '된',
#   '영화',
#   '.',
#   '뭘',
#   '더',
#   '바라는가',
#   '?',
#   '정말',
#   '잘빠졌다',
#   '.',
#   '보는',
#   '내내',
#   '황홀하고',
#   '우아한',
#   '에스',
#   '피오',
#   '나지',
#   '영화',
#   '의',
#   '모범',
#   '!'],
#  ['주연',
#   '여배우',
#   '..',
#   '연기',
#   '를',
#   '보면',
#   '겁',
#   '을',
#   '먹은',
#   '건지',
#   '그냥',
#   '아무',
#   '생각',
#   '이',
#   '없는',
#   '건지'],
#  ['마지막',
#   '에',
#   '!',
#   '이제껏',
#   '엮',
#   '인',
#   '실',
#   '타레가',
#   '시원하게',
#   '풀리는것',
#   '같은',
#   '느낌',
#   '!!'],
#  ['명작',
#   '...',
#   '액션',
#   '이',
#   '면서',
#   '가볍지',
#   '안아서',
#   '좋다',
#   '..',
#   '액션',
#   '도',
#   '좋고',
#   '..'],
#  ['♥'],
#  ['미루다', '미루다가', '이제', '봤네요', '볼', '만', '합니다', '.'],
#  ['로버트',
#   '다우니',
#   '주니어',
#   '의',
#   '연기',
#   '에',
#   '다시',
#   '한번',
#   '놀란',
#   '작품',
#   '이었고',
#   '오랜',
#   '만',
#   '에',
#   '깊은',
#   '여운',
#   '이',
#   '남는듯',
#   '한',
#   '작품',
#   '을',
#   '만난거',
#   '같아',
#   '반가웠다'],
#  ['팔레스타인', '의', '고뇌', '하지만', '좀', '이념', '영화', '같은면'],
#  ['보다가',
#   '열',
#   '받아서',
#   '죽',
#   '을',
#   '가능성',
#   '이',
#   '매우',
#   '높으니',
#   '심장',
#   '이',
#   '안',
#   '좋으면',
#   '삼',
#   '가할',
#   '것',
#   '.'],
#  ['징그럽게',
#   '꾸준히도',
#   '나오는',
#   '파라',
#   '노말',
#   '시리즈',
#   '...',
#   '허',
#   '접',
#   '한',
#   '스토리',
#   '에',
#   '어색한',
#   '연기',
#   '...',
#   '패러디',
#   '물',
#   '로',
#   '만들었으면',
#   '그나마',
#   '나았을',
#   '것',
#   '을',
#   '...'],
#  ['결말',
#   '이',
#   '예상',
#   '되는',
#   '영화',
#   '지만',
#   '재밌네요',
#   '!',
#   '웃음',
#   '도',
#   '났다가',
#   '울음',
#   '도',
#   '났다가',
#   '합니다'],
#  ['멋지다', '조문탁', '!'],
#  ['놀라운건',
#   '감독',
#   ',',
#   '음악',
#   ',',
#   '연출',
#   '모두',
#   '주걸륜',
#   '이',
#   '만들었다는거',
#   '..',
#   '헐',
#   '천재',
#   '였네'],
#  ['비',
#   '이',
#   '성적',
#   '신념',
#   '의',
#   '광기',
#   '.',
#   '권위',
#   '에',
#   '대한',
#   '집착',
#   '.',
#   '자신',
#   '의',
#   '결정',
#   '으로',
#   '인해',
#   '발생',
#   '한',
#   '포',
#   '클',
#   '랜드',
#   '사건',
#   '을',
#   '자신',
#   '의',
#   '재정',
#   '축소',
#   '정책',
#   '을',
#   '뒤집으며',
#   '처리',
#   '하는',
#   '집착',
#   '.',
#   '영국',
#   '의',
#   '스탈린',
#   '이군',
#   '.'],
#  ['장혁', '진짜', '...', '개', '소름', '..', '여운', '이', '너무', '길었음'],
#  ['소문',
#   '만',
#   '듣다가',
#   '직접',
#   '보니',
#   '이정',
#   '도일',
#   '줄',
#   '은',
#   '...',
#   '극장',
#   '서',
#   '본',
#   '분들',
#   '내',
#   '상이',
#   '심할',
#   '듯'],
#  ['좋은', '소재', '와', '탄탄하지', '못', '한', '스토리'],
#  ['심혜진', '은', '이제', '역사', '의', '뒤안길', '로', '사라지고', '있다', '.'],
#  ['아니',
#   '이딴',
#   '걸',
#   '...',
#   '영화',
#   '채널',
#   '에선',
#   '왜',
#   '자꾸',
#   '틀어주지',
#   '...',
#   '암',
#   '걸리게',
#   '할려고',
#   '작정',
#   '했나',
#   '...'],
#  ['유료',
#   '보기',
#   '로',
#   '사천원',
#   '내고',
#   '봤지만',
#   ',',
#   '어지간한',
#   '영화',
#   '만원',
#   '짜리',
#   '보다',
#   'ㅎ',
#   '훨씬',
#   '유익한',
#   '시간',
#   '이었다',
#   '.'],
#  ['좋다'],
#  ['별', '시리', '감동', '은', '없는데', '..', '전도연', '아직', '예쁘단', '생각', '뿐', 'ㅋㅋ'],
#  ['아무', '생각', '없이', '막', '찍어', '대고', '편집', '으로', '이야기', '만들어내는', '감독'],
#  ['정말',
#   '이런',
#   '영화',
#   '만들지',
#   '마세요',
#   '...',
#   '감동',
#   '을',
#   '주든',
#   ',',
#   '재미',
#   '를',
#   '주든',
#   ',',
#   '교훈',
#   '을',
#   '주든',
#   ',',
#   '감정',
#   '을',
#   '주든',
#   '...',
#   '영화',
#   '의',
#   '목적',
#   '이',
#   '전혀',
#   '없는',
#   '그냥',
#   '싸이코',
#   '영화로',
#   '봤습니다',
#   '.',
#   '이글',
#   '보고',
#   '감독',
#   '님',
#   '이',
#   '상처',
#   '받을',
#   '수도',
#   '있을까',
#   '도',
#   '생각',
#   '하는데',
#   '감독',
#   '님',
#   '상처',
#   '좀',
#   '받아야',
#   '합니다',
#   '...'],
#  ['평점', '이', '누가', '보면', '초', '걸작', '인', '줄', '알겠다', '..', '재밌기는', '재밌었음'],
#  ['어찌', '보면', '단순한', '러브스토리', '기도', '하지만', ',', '감동', '이', '있네요', '~'],
#  ['아버지', '의', '사랑', '..', '멋지다', '..'],
#  ['이건', '뭘', '까요', '?'],
#  ['어른',
#   '들',
#   '모',
#   '다',
#   '아이',
#   '들',
#   '이',
#   '더',
#   '많이',
#   '등장',
#   '해서',
#   '더',
#   '재밌는것',
#   '같다',
#   '.'],
#  ['어설픈', '택시', '드라이버', '아', '류', '영화', '.'],
#  ['정말',
#   '뻔한',
#   '반전',
#   '아닌가',
#   '?',
#   '송윤아',
#   '의',
#   '영화',
#   '불운',
#   '은',
#   '어디',
#   '까지',
#   '일까',
#   '?'],
#  ['진짜', '사랑', '이란', '건', '이런', '것', '일테지', '.'],
#  ['삶',
#   '의',
#   '이유',
#   '라는',
#   '너무나',
#   '큰',
#   '주제',
#   '를',
#   '다루려고',
#   '했는데',
#   '영화',
#   '가',
#   '전혀',
#   '이를',
#   '따라가지',
#   '못',
#   '합니다',
#   '.',
#   '즉',
#   ',',
#   '전혀',
#   '영화',
#   '에',
#   '공감',
#   '이',
#   '안되더군요',
#   '.',
#   '대사',
#   ',',
#   '주인공',
#   '들',
#   '각자',
#   '의',
#   '개',
#   '인사',
#   '들',
#   '을',
#   '보여주는데',
#   '있어',
#   '모두',
#   '겉',
#   '돌고',
#   '있고',
#   '자연',
#   '스럽게',
#   '인도',
#   '에',
#   '녹',
#   '아들',
#   '지',
#   '못',
#   '합니다',
#   '.',
#   '아쉽고',
#   '안타깝습니다',
#   '.'],
#  ['기대했던', '만큼', '재밍', '있었습니다'],
#  ['염정', '화', '억지로', '벗게', '했는다는', '영화', '군', '..', '감독', '이', '변탠', '가'],
#  ['어이', '없어요', '.', '내용', '이', '너무', '하네요'],
#  ['저', '평가', '된', '007'],
#  ['다큐',
#   '형식',
#   '이지만',
#   '끝',
#   '까지',
#   '지루하지',
#   '않고',
#   '재미있다',
#   '.',
#   '마음',
#   '은',
#   '쓸쓸하지만',
#   '.',
#   '인생',
#   '이',
#   '꼭',
#   '해피앤드',
#   '란',
#   '보장',
#   '은',
#   '없으니까',
#   '.'],
#  ['tv', '전', '기세', '가', '아깝다', '!!!'],
#  ['뭐', '냐', '이', '게'],
#  ['월리스',
#   '와',
#   '그루밋때',
#   '부터',
#   '팬',
#   '이',
#   '여서',
#   '...',
#   '시리즈',
#   '라',
#   '생각',
#   '해',
#   '보았으나',
#   '난',
#   '이',
#   '스토리',
#   '를',
#   '즐',
#   '기기',
#   '엔',
#   '너무',
#   '늙어',
#   '버렸다',
#   '.',
#   '명절',
#   '날',
#   '조카',
#   '가',
#   '틀어놓으면',
#   '전부',
#   '치',
#   '며',
#   '볼듯',
#   '!',
#   '성인',
#   '들',
#   '이',
#   '볼',
#   '극',
#   '장용',
#   '무비',
#   '는',
#   '아님'],
#  ['재난영화', '길래', '봤더니', '자동차', '광고', '영화', '인줄', ',,,'],
#  ['이건', '좀', '심했다', '겁나', '재미없음', 'ㅡㅡ'],
#  ['최고', '.', '영화', '를', '안', '본', '사람', '은', '절대', '이해', '못', '할', '감격', '.'],
#  ['만',
#   '개',
#   '한',
#   '꽃',
#   '보다는',
#   '피어나려는',
#   '꽃봉오리',
#   '를',
#   ',',
#   '분별',
#   '있는',
#   '성인',
#   '보다는',
#   '청소년',
#   '이',
#   '멋있을',
#   '수',
#   '있다'],
#  ['토끼', '귀여워요', '!!!'],
#  ['각각',
#   '의',
#   '삶',
#   '속',
#   '에',
#   '흐르는',
#   '시간',
#   '에',
#   '대한',
#   ',',
#   '머리',
#   '로는',
#   '이해',
#   '못',
#   '할',
#   '독특한',
#   '이야기',
#   '.'],
#  ['오죽하면',
#   '이',
#   '시대',
#   '에',
#   '이',
#   '영화',
#   'DVD',
#   '조차',
#   '안',
#   '나왔다면',
#   '할',
#   '말',
#   '다',
#   '했지',
#   '.'],
#  ['그냥', '친구', '가', '되는', '줄', '알았는데', '반전', '있는', '결말', ';;;'],
#  ['조', '쉬', '하트넷', '너무', '귀엽다', '..', 'ㅋㅋ', '계속', '웃으면서', '본', '영화'],
#  ['이서진', '의', '최악', '의', '영화', '랄', '까', 'ㅋㅋㅋ'],
#  ['마음', '이', '정화', '되는', '느낌', '이다', '.', '최고'],
#  ['인생', '을', '살아가는데', '지표', '가', '될만', '한', '메시지', '를', '전', '해준다', '.'],
#  ['바이러스', '성', '연쇄살인범', '이라는', '소재', '를', '진부하게', '이끌어', '나갔음'],
#  ['어덜트', '비디오', '용'],
#  ['보는',
#   '순간',
#   '마다',
#   '푹',
#   '빠져서',
#   '재밌게',
#   '봤습니다',
#   '.',
#   '감사합니다',
#   '.',
#   '영화',
#   '를',
#   '다',
#   '보고',
#   '철수',
#   '가',
#   '불쌍하단',
#   '생각',
#   '이',
#   '들었지만',
#   '철수',
#   '가',
#   '행복해',
#   '보이니',
#   '그',
#   '걸',
#   '로',
#   '된거',
#   '겠죠',
#   '.'],
#  ['시작', '은', '있으나', '끝', '이', '없다', '.'],
#  ['쓰레기', '는', '쓰레기통', '으로'],
#  ['이런', '소름끼치는', '명작', '을', '이제', '서야', '보다니', '이제', '까지', '영화', '헛봤다', '!'],
#  ['음악', '영', '상미', '둘다', '최고', '감동', '까지', 'ㅠ', '.', 'ㅠ'],
#  ['자기', '색깔', '을', '내려는', '시도', '는', '있으나', '방향성', '이', '없다'],
#  ['이', '흥행', '보증', '배우', '로', '망한', '영화', '.'],
#  ['진짜', '재미없는', '드라마', '!'],
#  ['sf', '가', '지루한면도', '있는거지', '그러면', '니', '들', '이', '영화', '를', '만들던가'],
#  ['이', '게', '어떻게', '6', '점', '이', '넘는지', '이해', '가', '...'],
#  ['난이',
#   '드라마',
#   '세번',
#   '봤음',
#   '내',
#   '생애',
#   '최고',
#   '의',
#   '드라마',
#   '.',
#   '짱',
#   '임',
#   '!!',
#   '이런',
#   '드라마',
#   '또',
#   '나왔음',
#   '좋겠다',
#   '.'],
#  ['니', '네', '문학', '반', '만', '따라가', '봐라'],
#  ['나름', '재미있네요', 'ㅎ'],
#  ['재미있어요'],
#  ['무거우면서도',
#   '유쾌하게',
#   '인상',
#   '깊은',
#   '영화',
#   '입니다',
#   '.',
#   '전수진',
#   ',',
#   '이은우',
#   '두',
#   '배우',
#   '연기',
#   '가',
#   '대단합니다'],
#  ['3.5',
#   '/',
#   '줄거리',
#   '는',
#   '3',
#   '류',
#   '에',
#   ',',
#   '개연',
#   '성도',
#   '없고',
#   ',',
#   '감동',
#   '도',
#   '없고',
#   '...',
#   '가장',
#   '문제',
#   '는',
#   '지루하다는',
#   '것',
#   '...'],
#  ['밤', '에', '잠', '않', '올', '때', '보는', '영화로', '추천', '합니다'],
#  ['디카프리오', ',', '끝'],
#  ['MMORPG',
#   '즐기지',
#   '않는',
#   '사람',
#   '에게는',
#   '주석',
#   '을',
#   '달',
#   '아',
#   '달란',
#   '말',
#   '이다',
#   '.'],
#  ['그렇게', '나', '는', '시간', '을', '낭비했다', '...-_=;'],
#  ['베네딕트', '컴버배치', '는', '목소리', '만으로', '압도', '함', '!!'],
#  ['지루하고', '선정', '적', '이고', '당황', '스럽다'],
#  ['지루하고',
#   '따분하고',
#   '특별한',
#   '느낌',
#   '도',
#   '없고',
#   '.',
#   '괜히',
#   '목',
#   '에',
#   '힘',
#   '만',
#   '준',
#   '영화',
#   '.',
#   '나도',
#   '영화광',
#   '이지만',
#   '이',
#   '영화',
#   '에',
#   '대한',
#   '평론가',
#   '들',
#   '높은',
#   '평점',
#   '은',
#   '공감',
#   '이',
#   '전혀',
#   '안된다',
#   '.'],
#  ['김동완',
#   '은',
#   '보이지',
#   '않고',
#   '이육사만',
#   '보였다',
#   ';',
#   '누구',
#   '나오는지',
#   '안보',
#   '고',
#   '봤더니',
#   '김동완',
#   '인',
#   '줄',
#   '도',
#   '모르고',
#   '봤음',
#   ';;',
#   '완전',
#   '딴사람',
#   '인',
#   '줄',
#   ';',
#   '진짜',
#   '이육사',
#   '같았음',
#   '..'],
#  ['최근',
#   '에',
#   '심심해서',
#   '지식인',
#   '돌아보다가',
#   '우연',
#   '하게',
#   '알',
#   '게',
#   '되서',
#   '봤습니다',
#   '.',
#   '재밌네요'],
#  ['타짜',
#   '는',
#   '10',
#   '점',
#   '받아',
#   '마땅하다',
#   '.',
#   '영화',
#   '의',
#   '모든',
#   '부분',
#   '이다',
#   '재밌었다',
#   '.',
#   '캐릭터',
#   '들',
#   '은',
#   '원작',
#   '보다',
#   '훨씬',
#   '더',
#   '매력',
#   '적',
#   '으로',
#   '재현',
#   '됐고',
#   ',',
#   '단역',
#   '까지',
#   '모든',
#   '캐릭터',
#   '가',
#   '제',
#   '몫',
#   '을',
#   '했다',
#   '.',
#   '긴이야',
#   '기를아주',
#   '딱',
#   '맞게',
#   '압축',
#   '했다',
#   '.',
#   '전국',
#   '중',
#   '고딩',
#   '에게',
#   '섯다',
#   '열풍',
#   '을',
#   '몰',
#   '고온',
#   ',',
#   '막판',
#   '고니',
#   '와',
#   '아귀',
#   '의',
#   '설전',
#   '을',
#   '전',
#   '국민',
#   '이',
#   '외우게',
#   '만든',
#   '작품',
#   '.',
#   '영화사',
#   '에',
#   '남',
#   '을',
#   '장면',
#   '들',
#   '이',
#   '가득',
#   '담겨있는',
#   '선물',
#   '세트'],
#  ['대놓고', '코미디', '가', '아닌', '은근', '히', '웃기는게', '재밌었어요', 'ㅋㅋ'],
#  ['더', '이상', '자세한', '설명', '은', '생략', '한다', '.'],
#  ['시간', '잘', '때웠', '습', '니당'],
#  ['악당',
#   '삼',
#   '인',
#   '방',
#   '에서',
#   '조',
#   '드',
#   '장군',
#   '하고',
#   '여자',
#   '가',
#   '매력',
#   '적',
#   '..',
#   '찾아보니',
#   '브이',
#   '에도',
#   '나왔었네'],
#  ['왜',
#   '이런',
#   '감동',
#   '적이면서도',
#   '쩌',
#   '는',
#   '명품',
#   '애니',
#   '가',
#   "'",
#   '8',
#   "'",
#   '점',
#   '대',
#   '??'],
#  ['내',
#   '가',
#   '본',
#   '성룡',
#   '영화',
#   '중',
#   '최고',
#   '였지만',
#   '주연',
#   '은',
#   '홍금보',
#   '외',
#   '5',
#   '명',
#   '이었다',
#   '.'],
#  ['러브', '라인', '은', '이', '제', '그만', '내용', '팍팍', '나가자구', '용', '지루해져요'],
#  ['명작', '이', '될', '수도', '있었던', '영화'],
#  ['정말', '재미있어요', 'ㅇㅇㅇ', '굿'],
#  ['왜캐', '평점', '높음', '쓰레기', '임'],
#  ['이지현', '의', '육체', '에', '뿅', '간', '여균동', '..', 'ㅋ'],
#  ['원래',
#   '10',
#   '점',
#   '잘안주는데',
#   '너무',
#   '뭉클하고',
#   '감동',
#   '적',
#   '인',
#   '스토리',
#   '에',
#   '엄청',
#   '울었습니다',
#   '꼭',
#   '봐',
#   '야하는',
#   '영화',
#   '!!',
#   '★'],
#  ['50년',
#   '대에',
#   '이런',
#   '연출',
#   '이',
#   '가능하다니',
#   '어떤',
#   '경지',
#   '를',
#   '보는',
#   '것',
#   '같다',
#   '.',
#   '시대',
#   '를',
#   '역행',
#   '한',
#   '작품'],
#  ['역사',
#   '적',
#   '인',
#   '부분',
#   '도',
#   '굉장히',
#   '중요하지만',
#   '정치',
#   '적',
#   '인',
#   '부분',
#   '싫으신',
#   '분',
#   '들',
#   '도',
#   '가족',
#   '애',
#   '라는',
#   '큰',
#   '주제가',
#   '있기',
#   '때문',
#   '에',
#   '그',
#   '누구',
#   '든지',
#   '보셔도',
#   '좋은',
#   '영화',
#   '입니다',
#   '.'],
#  ['정말', '마음', '이', '따뜻해지는', '영화', '네', '요', '재미있었어요', '진', '이씨', '멋있었어요', 'ㅋ'],
#  ['모든', '모습', '은', '이', '안', '에', '일부', '가', '스며들어있다', '.'],
#  ['감독',
#   '리들리',
#   '스콧',
#   '과',
#   '주연',
#   '러셀',
#   '크로우',
#   '는',
#   '각각',
#   '의',
#   '역할',
#   '에',
#   '미스',
#   '캐스팅',
#   '이고',
#   ',',
#   '허세',
#   '가득하고',
#   '공감',
#   '되지',
#   '않는',
#   '이야기',
#   '는',
#   '처음',
#   '부터',
#   '끝',
#   '까지',
#   '진부해서',
#   '지루하다',
#   '.'],
#  ['진짜진짜',
#   '보다보다',
#   '이렇게',
#   '지겨운',
#   '만화',
#   '첨',
#   '입니다',
#   '딸램',
#   '보여주려',
#   '갔',
#   '더',
#   '만',
#   '헉',
#   '포스터',
#   '사기',
#   '입니다',
#   '포스터',
#   '색감',
#   '이라도',
#   '되면',
#   '좋으려',
#   '만시',
#   '커',
#   '한',
#   '바다',
#   '우울한',
#   '대',
#   '사',
#   '더빙',
#   '엉망',
#   '임',
#   '이렇게',
#   '재미없을수있나요',
#   '극장',
#   '서',
#   '중간',
#   '애',
#   '들',
#   '이',
#   '졸리다고',
#   '난리',
#   'ㅡㅡ'],
#  ['총',
#   '을',
#   '쏘았다는데',
#   '총알',
#   '이',
#   '없어',
#   '.',
#   '탄피',
#   '도',
#   '없어',
#   '.',
#   '다쳤는데',
#   '왜',
#   '다쳤는지를',
#   '모르겠네',
#   '.',
#   '개',
#   '법부',
#   '를',
#   '엎',
#   '어',
#   '버려야지',
#   '원'],
#  ['오',
#   ',',
#   '의외로',
#   '스토리',
#   '가',
#   '탄탄한데요',
#   '?',
#   '저',
#   '도',
#   '통',
#   '크게',
#   '10',
#   '점',
#   '드립니다',
#   '^^'],
#  ['창작', '의', '괴로움', '이', '이리', '돋보이리', '랴', '!'],
#  ['오래전', '에', '본', '영화', '인데', '도', '지금', '도', '유효한', '놀라운', '메시지', '!!!'],
#  ['물론', '만화', '같기는', '했지만', '첫', '번째', '액션씬', '이', '계속', '머리', '에', '남는다'],
#  ['흠', '...', '테이큰', '보다', '이', '거', '보니', '드럽게', '재미없네', '.'],
#  ['복수',
#   '라는',
#   '타이틀',
#   '을',
#   '달지말던가',
#   '.',
#   '복수',
#   '영화',
#   '.',
#   '느와르',
#   '영화',
#   '에서는',
#   '최소한',
#   '의',
#   '규칙',
#   '이',
#   '있어',
#   '.',
#   '전개',
#   '스타일',
#   '.',
#   '슬로우',
#   '느낌',
#   '.',
#   '다',
#   '좋다고',
#   '근데',
#   '말',
#   '야',
#   '복수',
#   '가',
#   '복수',
#   '다',
#   '워',
#   '야',
#   '지',
#   '.',
#   '뭐',
#   '냐',
#   '고',
#   '원숭이',
#   '같이',
#   '생긴',
#   '싸이코패스',
#   '경찰서',
#   '장이',
#   '주인공',
#   '이네',
#   '.',
#   '복수',
#   '를',
#   '해야',
#   '할',
#   '라이언',
#   '고',
#   '슬링',
#   '은',
#   '허',
#   '접때',
#   '기',
#   '로나',
#   '오네'],
#  ['진국', '시나리오'],
#  ['킬링타임', '용', '으론', '상당한', '수작'],
#  ['일본', '가', '이런', '말', '할', '자격', '이', '잇나', '?'],
#  ['잼있구만',
#   '~',
#   '여배우',
#   '이쁘구',
#   '~',
#   '평점',
#   '보고',
#   '안',
#   '봤으면',
#   '후회',
#   '했겠다',
#   '..',
#   '네이버',
#   '평점',
#   '은',
#   '믿을게',
#   '안데'],
#  ['세',
#   '아들',
#   '의',
#   '비참한',
#   '결과',
#   '의',
#   '근본',
#   '은',
#   '아버지',
#   '의',
#   '악',
#   '(',
#   '정욕',
#   '등',
#   ')',
#   '으로',
#   '인했다',
#   '.',
#   '그러나',
#   '세',
#   '아들',
#   '과',
#   '중국인',
#   '조차도',
#   '각자',
#   '마다',
#   '이',
#   '악한',
#   '세상',
#   '가운데',
#   '쉼을',
#   '얻을',
#   '수',
#   '있는',
#   '엄마',
#   '의',
#   '품',
#   '을',
#   '가장',
#   '그리워',
#   '할',
#   '것',
#   '이다',
#   '.'],
#  ['정말', '감동', '받았어요', 'ㅠㅠㅠ', '이건', '꼭', '봐야되', '요', '!!!'],
#  ['와우', '저', '펜'],
#  ['1시간',
#   '30분',
#   '정도의',
#   '시간',
#   '을',
#   '버린',
#   '기분',
#   '로버트',
#   '패틴슨',
#   '의',
#   '연기력',
#   '만은',
#   '훌륭하다',
#   '.'],
#  ['소재', '빼고', '전부', '엉망', '진창', '.'],
#  ['야웅', '~', '잼있겠다', '옹', '~~'],
#  ['재미있게', '봤어', '~', '어렸지만', '사랑', '에', '희생', '정신', '이', '좋았어', '~~'],
#  ['이', '정도', '면', '봐줄만', '하다'],
#  ['샘', '라일', '리', '.', '아름답다', '.'],
#  ['스토리',
#   '도',
#   '좋고',
#   ',',
#   '캐스팅',
#   '도',
#   '괜찮았고',
#   '..',
#   '정말',
#   '좋은',
#   '드라마',
#   '^^',
#   '이승기',
#   '한효주',
#   '씨',
#   '최고',
#   '였음'],
#  ...]

# %%
#토근화된 데이터를 저장
with open('tokenized_data.pkl','wb') as f:
    pickle.dump(tokenized_data,f)

# %%
#토큰화된 데이터 불러오기
with open('tokenized_data.pkl','rb') as f:
    loaded_tokenized_data = pickle.load(f)

loaded_tokenized_data
# Out:
# [['아', '더빙', '..', '진짜', '짜증나네요', '목소리'],
#  ['원작', '의', '긴장감', '을', '제대로', '살려내지못', '했다', '.'],
#  ['울면',
#   '서',
#   '손',
#   '들',
#   '고',
#   '횡단보도',
#   '건널',
#   '때',
#   '뛰',
#   '쳐나',
#   '올',
#   '뻔',
#   '이범수',
#   '연기',
#   '드럽게',
#   '못',
#   '해'],
#  ['이건',
#   '정말',
#   '깨알',
#   '캐스팅',
#   '과',
#   '질퍽',
#   '하',
#   '지',
#   '않은',
#   '산뜻한',
#   '내',
#   '용구성',
#   '이',
#   '잘',
#   '버무러진',
#   '깨알',
#   '일드',
#   '!!',
#   '♥'],
#  ['주제', '는', '좋은데', '중반', '부터', '지루하다'],
#  ['엄포스',
#   '의',
#   '위력',
#   '을',
#   '다시',
#   '한번',
#   '깨닫게',
#   '해준',
#   '적',
#   '.',
#   '남',
#   '꽃',
#   '검사',
#   '님',
#   '도',
#   '연기',
#   '정말',
#   '좋았어요',
#   '!',
#   '완전',
#   '명품',
#   '드라마',
#   '!'],
#  ['키이라', '나이틀리', '가', '연기', '하고자', '했던건', '대체', '정신장애', '일까', '틱장애', '일까'],
#  ['오게', '두어라', '!', '서리', '한', '이', '굶주렸다', '!'],
#  ['난', '우리', '영화', '를', '사랑', '합니다', '....^^;'],
#  ['재미있어요'],
#  ['보는내내', '그대로', '들어맞는', '예측', '카리스마', '없는', '악역'],
#  ['예전',
#   '작품',
#   '캐릭터',
#   ',',
#   '에피소드',
#   '재탕',
#   '삼',
#   '탕',
#   '사골',
#   '우려',
#   '먹듯',
#   '우리',
#   '고',
#   '내용',
#   '은',
#   '산',
#   '으로',
#   '가고',
#   '시청률',
#   '은',
#   '아예',
#   '안',
#   '나오고',
#   '이제',
#   '70회',
#   '중반인데',
#   '120',
#   '부작',
#   '이라니',
#   '...'],
#  ['졸작'],
#  ['한국영',
#   '화',
#   '흥행',
#   '코드',
#   ':',
#   '갈등',
#   '-',
#   '갈등',
#   '-',
#   '계',
#   '~',
#   '에',
#   '속',
#   '갈등',
#   '-',
#   '화해',
#   '-',
#   '감동',
#   '-',
#   '평점',
#   '10',
#   '점',
#   '남발',
#   '-',
#   '흥행',
#   '뻔하지',
#   '뭐',
#   '...'],
#  ['정말', '쓰레기', '영화', '입니다'],
#  ['성룡', '영화', '중', '최악', '인', '듯', 'ㅋㅋ'],
#  ['재미있는', '영화', '입니다', '.'],
#  ['잔잔한게', '생각', '보다', '볼', '만', '한', '영화', '인거', '같습니다', 'ㅋ'],
#  ['재미있게',
#   '봤습니다',
#   '.',
#   '매력',
#   '적',
#   '인',
#   '행복',
#   '이네',
#   '요',
#   ',',
#   "'-'",
#   'ㅎㅎㅎ',
#   '.'],
#  ['시청률',
#   '기준',
#   '이',
#   '되는',
#   '패널',
#   '가구',
#   '들',
#   '머',
#   '하는거지',
#   '명작',
#   '드라마',
#   '다',
#   '망치',
#   '네',
#   'ㅡㅡ',
#   '내',
#   '가',
#   '다',
#   '서운하다',
#   '...'],
#  ['중국인',
#   '특유',
#   '의',
#   '과장',
#   ',',
#   '허풍',
#   '...',
#   '있어',
#   '보이려고',
#   '안간힘',
#   '쓴',
#   '노력',
#   '은',
#   '가상하나',
#   ',',
#   '고증',
#   '과',
#   '현',
#   '실감',
#   '떨어지는',
#   '설정',
#   '이',
#   '거북',
#   '스럽다',
#   '...',
#   '도대체',
#   '그',
#   '들',
#   '은',
#   '왜',
#   '이렇게',
#   '까지',
#   '스스로',
#   '를',
#   '과대',
#   '포장',
#   '하',
#   '는',
#   '것',
#   '인지',
#   '...'],
#  ['아니', '이', '게', '왜', '9', '점', '대', '일까', '...;;;'],
#  ['아주', '모자라진', '않다', '.'],
#  ['다르덴',
#   ',',
#   '이냐리',
#   '투',
#   ',',
#   '차이밍량',
#   '이',
#   '하나',
#   '도',
#   '안',
#   '섞인',
#   '채',
#   '짬뽕',
#   '그릇',
#   '에',
#   '담겨있다',
#   '.'],
#  ['재미있다고', '허풍', '떨지', '마세요'],
#  ['그만', '좀', '끌', '고', '이제', '끝내', '라', '.', '지겹다', '지겨워', '.'],
#  ['배우',
#   '들',
#   '은',
#   '지네',
#   '들',
#   '안',
#   '뜨니까',
#   '이런',
#   '영화',
#   '찍을껀데',
#   '???',
#   '왜',
#   '안',
#   '뜨는지',
#   '진짜',
#   '모르는거야',
#   '?',
#   '면상',
#   '딱',
#   '보면',
#   '알겠구만',
#   '...',
#   '왜',
#   '지네',
#   '자신',
#   '들',
#   '은',
#   '모를까',
#   '?'],
#  ['오랜', '만', '에', '재밋', '는', '영화', '봤네요'],
#  ['소파', '에', '죽', '치고', '앉아', '지켜', '볼', '이유', '가', '없는', '작품', '.'],
#  ['알바', '는', '꺼', '저', '라'],
#  ['정말',
#   '짜증',
#   '의',
#   '극치',
#   '를',
#   '보여주는',
#   '영화',
#   '.',
#   '굉장히',
#   '언밸러스',
#   '한',
#   '느낌',
#   '.',
#   '뚱뚱하고',
#   '못',
#   '생긴',
#   '남자',
#   '애',
#   '의',
#   '발연기',
#   '를',
#   '시종일관',
#   '봐야하는게',
#   '고역',
#   '인',
#   '듯',
#   '.',
#   '간간히',
#   '흘러나오는',
#   '잔잔한',
#   '클래식',
#   '풍',
#   '의',
#   '음악',
#   '조차도',
#   '듣기',
#   '싫어',
#   '짜증날',
#   '정도',
#   '로',
#   '상당히',
#   '싫은',
#   '영화',
#   '.'],
#  ['유치하고', '지루하고', '잠', '이', '왔다'],
#  ['기존',
#   '멜로영화',
#   '형식',
#   '을',
#   '탈피',
#   '하려고',
#   '하였으나',
#   '감정',
#   '의',
#   '절제',
#   '가',
#   '지나쳐',
#   '너무',
#   '담백한',
#   '영화'],
#  ['넘',
#   '사랑스러운',
#   '영화',
#   '다',
#   'ㅠㅠ',
#   '1',
#   '보고',
#   '2',
#   '연',
#   '이',
#   '어',
#   '봤다',
#   '~!!',
#   '넘',
#   '귀여워',
#   'ㅠㅠ',
#   '♥♥'],
#  ['새벽',
#   '시간',
#   '에',
#   '하는',
#   '일본',
#   '영화',
#   '들',
#   '은',
#   '전부',
#   '개',
#   '졸작',
#   '이다',
#   '.',
#   '일',
#   '본',
#   '영화',
#   '원',
#   '래',
#   '다',
#   '이래',
#   '??'],
#  ['감동', '적', '인', '영화'],
#  ['아',
#   '너무',
#   '웃기',
#   '고',
#   '배꼽',
#   '빠질',
#   '뻔했네',
#   '^^',
#   '내',
#   '컴',
#   '에',
#   '이',
#   '영화',
#   '있는데',
#   '^^'],
#  ['더럽게',
#   '재미없다',
#   '어떤',
#   '형태',
#   '로',
#   '도',
#   '와',
#   '닿지',
#   '않는',
#   '허무하고',
#   '완벽히',
#   '지루한',
#   '영화',
#   '고',
#   '영양가',
#   '하나',
#   '도',
#   '없는',
#   '영화',
#   '다'],
#  ['영화',
#   '를',
#   '보는것만으로도',
#   '마음',
#   '의',
#   '휴가',
#   '를',
#   '다녀온',
#   '느낌',
#   '.',
#   '소박하지고',
#   '잔잔하지만',
#   '지루하지',
#   '않은',
#   '..',
#   '그래서',
#   '다시',
#   '보고싶은',
#   '영화',
#   '.',
#   '햇살',
#   '가득한',
#   '비',
#   '이의',
#   '부엌',
#   '과',
#   '요리',
#   '도',
#   '인상',
#   '적'],
#  ['정치인', '의', '모순', '인가', ',', '정치범', '의', '모순', '인가', '....'],
#  ['푸하하하', '이', '거', '기대', '안', '했지만', '..', '역시', '나', '구만', '..', 'ㅋ'],
#  ['드럽게', '재미없네', '시간', '이', '돈', '이다', '?', '내', '시간', '은', '어쩔', '건데'],
#  ['아', '진짜', '너무', '좋아요', 'ㅜㅜ', '짱짱', '!!!'],
#  ['액션영화',
#   '가',
#   '아니다',
#   '.',
#   '범죄',
#   '느와르',
#   '영화',
#   '다',
#   '.',
#   '허나',
#   '범죄',
#   '느와르',
#   '영화로서도',
#   '실패',
#   '작',
#   '.......'],
#  ['또', '보고', '싶은데', '어디서', '보죠', '???'],
#  ['좋은', '영화'],
#  ['정은지',
#   '언니',
#   '!!',
#   '연기',
#   '잘',
#   '하구',
#   '..',
#   '노래',
#   '도',
#   '잘',
#   '부르시고',
#   '!',
#   '마지막',
#   '회',
#   '웃으면서',
#   '즐겁게',
#   '!',
#   '봤습니다',
#   '!',
#   '트로트',
#   '의',
#   '연인',
#   '!',
#   '♥'],
#  ['여',
#   '주인공',
#   '인터뷰',
#   '할',
#   '때',
#   '지루해',
#   '죽는줄',
#   '알았음',
#   'ㅡㅡ',
#   '그냥',
#   '저',
#   '냥',
#   '킬링타임',
#   '용',
#   '스릴러'],
#  ['스토리',
#   '도',
#   '말',
#   '이',
#   '안되고',
#   '개막',
#   '장',
#   '사랑',
#   '이야기',
#   '도',
#   '아니예요',
#   '이',
#   '걸',
#   '보고',
#   '계신다면',
#   '당신',
#   '의',
#   '시간',
#   '과',
#   '돈',
#   '을',
#   '아낀거예요',
#   '^.^',
#   '휴',
#   '그래도',
#   '본다면',
#   '호구'],
#  ['나이', '들', '수록', '이해', '가', '가는', '영화'],
#  ['일본',
#   '영화',
#   '수입',
#   '금지',
#   '시절',
#   '에도',
#   '비디오',
#   '테이프',
#   '로',
#   '돌려',
#   '봤던',
#   '불후',
#   '의',
#   '명작',
#   '아',
#   '그립다'],
#  ['지금', '이', '거', '티비', '로', '돈', '내고', '보고있는', '내', '가', '한심하다'],
#  ['잊을', '수', '없는', '안개', '낀', '워터', '루', '다리', '와', '마스코트', '.'],
#  ['비디오',
#   '가',
#   '있어서',
#   '봤는데',
#   '1997년',
#   '도인줄모를정도로',
#   '잘',
#   '만들었습니다',
#   '긴장감',
#   '도',
#   '있고'],
#  ['고', '다미', '괜찮음'],
#  ['줄리아', '로버츠', '귀여운', '연인', '은', '이', '거', '보다', '5년', '전꺼다', '...'],
#  ['여자애',
#   '한',
#   '명',
#   '이',
#   '잘',
#   '못',
#   '해서',
#   '몇',
#   '명',
#   '이',
#   '죽는거야',
#   'ㅋㅋ',
#   '답',
#   '도',
#   '없다',
#   'ㅋ'],
#  ['국산',
#   '코미디',
#   '영화',
#   '중',
#   '에서',
#   '난',
#   '신라',
#   '의',
#   '달밤',
#   '이',
#   '제일',
#   '좋았음',
#   '뭔가',
#   '푸근하고',
#   '따뜻함',
#   '..'],
#  ['대한민국',
#   '영화',
#   '수준',
#   '의',
#   '평균',
#   '치를',
#   '하락',
#   '시키기에',
#   '충분한',
#   'C',
#   '급',
#   '영상',
#   '물'],
#  ['네러티브',
#   '는',
#   '하나',
#   '도',
#   '없는',
#   '예쁜',
#   '음악',
#   '동영상',
#   '.',
#   '취미',
#   '로',
#   '영화',
#   '만드는',
#   '것',
#   '은',
#   '이',
#   '걸',
#   '로',
#   '끝나길',
#   '.',
#   '잘',
#   '하는',
#   '음악',
#   '에',
#   '올인',
#   '하길',
#   '.'],
#  ['무섭지도', '않고', '기분', '만', '나쁘고', '쩝'],
#  ['왜',
#   '극',
#   '을',
#   '끌어가는',
#   '중심',
#   '있는',
#   '캐릭터',
#   '가',
#   '있어야',
#   '하는지',
#   '알',
#   '게',
#   '된',
#   '영화',
#   '살인마',
#   '와',
#   '대적',
#   '하는',
#   '그리고',
#   '사건',
#   '을',
#   '해결',
#   '하는',
#   '인물',
#   '이',
#   '없고',
#   '그리고',
#   '왜',
#   '마지막',
#   '에',
#   '다',
#   '탈출',
#   '해놓고',
#   '나서',
#   '잡히고',
#   '죽임을',
#   '당하는지',
#   '이해',
#   '할수가',
#   '없다',
#   '.',
#   '대체',
#   '조달환',
#   '정유미',
#   '는',
#   '왜',
#   '나옴',
#   '?'],
#  ['영화',
#   '진짜',
#   '보고',
#   '..',
#   '펑펑',
#   '울었습니다',
#   ',',
#   '너무',
#   '슬픈거',
#   '같아요',
#   '..',
#   'ㅜㅜㅜ',
#   '!'],
#  ['절망',
#   '과',
#   '슬픔',
#   '속',
#   '에서도',
#   '자신',
#   '을',
#   '챙겨야만하는',
#   '삶',
#   '의',
#   '잔인함',
#   '을',
#   '거부',
#   '한',
#   '비참함에',
#   '대하',
#   '여'],
#  ['잼'],
#  ['흥미롭게', '봤어요', '.', '여배우', '들', '이쁘네요', '.', '반했음'],
#  ['영화평론가',
#   '는',
#   '아니지만',
#   ',',
#   '좋았다',
#   ',',
#   '한번',
#   '보고',
#   '마는',
#   '영화',
#   '가',
#   '아닌',
#   ',',
#   '울림이있는',
#   '영화'],
#  ['슬프다', 'ㅠㅠ'],
#  ['굿', '10', '자', '이상', '.', '가나다라'],
#  ['최고', '의', '영화'],
#  ['오랜', '만', '에', '동화', '다운', '동화', '를', '본', '기분', '이다', '.'],
#  ['니노', '의', '이중인격', '연기', '두근거리네요', '♥'],
#  ['신화', '화이팅', '에릭', '화이팅', '><', '모두', '힘내요', '!'],
#  ['잘', '봤습니다'],
#  ['책', '과는', '분명히', '다른', '시선', '.', '괜찮네요'],
#  ['개답답',
#   '먼',
#   '주인공',
#   '이',
#   '지',
#   '혼자',
#   '복수',
#   '도',
#   '못',
#   '함',
#   '?',
#   '주변',
#   '에서',
#   '해주길',
#   '바라는',
#   '민폐',
#   '녀',
#   '?',
#   '아직도',
#   '끌려다니고',
#   'ㅡㅡ'],
#  ['억지스러운',
#   '시나리오',
#   '..',
#   '지루한',
#   '전개',
#   '..',
#   '1',
#   '편',
#   '보다',
#   '못',
#   '한',
#   '구성',
#   '등',
#   '..',
#   '2',
#   '편',
#   '은',
#   '안',
#   '나오는게',
#   '나았다',
#   '..',
#   '망작',
#   '..',
#   '배우',
#   '들',
#   '이',
#   '영',
#   '화보',
#   '는',
#   '눈',
#   '이',
#   '없어서',
#   '안타깝다',
#   '.'],
#  ['진짜',
#   '재미',
#   '없는',
#   '영화',
#   '공통점',
#   '....',
#   '스포츠영화',
#   ',',
#   '군대',
#   '영화',
#   ',',
#   '자막',
#   '나오는',
#   '영화'],
#  ['정말', '최고', '의', '영화', '...'],
#  ['졸면서',
#   '봤다',
#   '왜',
#   '이리',
#   '평정',
#   '이',
#   '높은',
#   '겨',
#   '내용',
#   '도',
#   '별거',
#   '없고',
#   '아오',
#   '감수성',
#   '영화',
#   '냐',
#   '이',
#   '거'],
#  ['인종차별', '과', '유괴', '라는', '두', '주제', '의', '불협화음'],
#  ['좋아', '상술', '최고', '..', '아니', '선거', '술', '최고', '...'],
#  ['내', '가', '본', '일드', '중', '쵝오', '~!!!!!>', '0', '<'],
#  ['스킨헤드', '성', '님', '들이', '이', '영화', '를', '싫어합니다', '.'],
#  ['재밌음', '귀엽고', '신남'],
#  ['이', '게', '어떻게', '평점', '이', '낮을수가', '있지', '?'],
#  ['안',
#   '봐도',
#   '별',
#   '점',
#   '한개',
#   '주고싶은',
#   '10',
#   '류',
#   '영화',
#   '같다',
#   '...',
#   'ㅋㅋ',
#   '심형래',
#   '아저씨',
#   '와',
#   '동',
#   '급',
#   '감독',
#   '인',
#   '듯',
#   'ㅋㅋㅋ'],
#  ['중심', '이', '약하니', '언', '저리', '가지', '고', '무리한', '승부', '수', '를', '띄운다'],
#  ['불',
#   '은',
#   '잘',
#   '보이지',
#   '도',
#   '않고',
#   '사람',
#   '죽어',
#   '나갈',
#   '때',
#   '는',
#   '엄청난',
#   '웅장',
#   '한',
#   '음악',
#   '만',
#   '나오고',
#   '전혀',
#   '마음',
#   '에',
#   '와',
#   '닿지',
#   '않는',
#   '설정',
#   '들'],
#  ['후속', '지금', '이라도', '나와라', '한국', '애니', '좀', '살려', '보자'],
#  ['전작', '보다', '100', '재밌다', '.', '배우', ',', '내용', '모두', '세련됨'],
#  ['말',
#   '이',
#   '필요',
#   '없다',
#   '.',
#   '로맨스',
#   '싫어하는',
#   '내',
#   '가',
#   '봤을',
#   '때',
#   '기절',
#   '할',
#   '것',
#   '같았어',
#   'ㅜㅜㅜㅜ'],
#  ['요즘', '재밌음', '!'],
#  ['극',
#   '장가',
#   '서',
#   '안',
#   '본',
#   '내',
#   '머리',
#   '를',
#   '깨',
#   '버리고싶네요',
#   '.',
#   '제',
#   '인생',
#   '최고',
#   '의',
#   '영홥니',
#   '다',
#   '.',
#   '키이라',
#   '작품',
#   '중',
#   '에서도',
#   '최고',
#   '일듯',
#   '.',
#   '알럽키',
#   '이라',
#   '♡♡'],
#  ['2%',
#   '부족한',
#   '영화',
#   '가',
#   '아닌',
#   '98%',
#   '부족한',
#   '영화',
#   '감동',
#   '이',
#   '있다길래',
#   '참고',
#   '끝',
#   '까지',
#   '다',
#   '봤는데',
#   '...;;',
#   '진심',
#   '으로',
#   '이렇게',
#   '재미없다고',
#   '느끼는건',
#   '처음',
#   ';;'],
#  ['심혜진', '이', '나와서', '겨우', '저', '정도', '라니', '실망', '이다'],
#  ['너무나', '따뜻하고', '감동', '적', '인', '영화'],
#  ['전',
#   '주',
#   '영화제',
#   '에서',
#   '봤었는',
#   '데넘',
#   '늦게',
#   '개봉',
#   '한',
#   '듯',
#   '...',
#   '종교',
#   '와',
#   '업',
#   '에',
#   '대해',
#   '한번',
#   '더',
#   '생각',
#   '할수있게만',
#   '든',
#   '영화',
#   '.',
#   '저',
#   '예산',
#   '으로만',
#   '들었으나',
#   '감독',
#   '의',
#   '노력',
#   '이',
#   '느껴져',
#   '큰',
#   '박수',
#   '를',
#   '보내고싶다',
#   '.',
#   '화이팅',
#   '!'],
#  ['자신', '의', '삶', '에', '대해', '다시', '한번', '생각', '하게하는', '영화', '...'],
#  ['이',
#   '영활',
#   '보고나면',
#   '흐뭇해진다',
#   '..',
#   '영화',
#   '는',
#   '한국',
#   '이',
#   '더',
#   '잘',
#   '만든다는',
#   '걸',
#   '느끼게',
#   '되니까',
#   '..'],
#  ['수많은', '최루성', '멜로', '는', '여기', '에서', '...'],
#  ['참', '재밌는', '영화', 'ㅎㅎ'],
#  ['진짜', '신기하다', '...', '라는', '말', '밖에', '안나', '와'],
#  ['2.2', '고고', '하자', 'ㅋㅋㅋ'],
#  ['감독', 'ㅡㅡ', '다신', '영화', '찍지마라'],
#  ['할', '말', '이', '없다'],
#  ['에린',
#   '이',
#   '초반',
#   '에',
#   '타던',
#   '차',
#   '현대',
#   '자동차',
#   '프레스토',
#   '네요',
#   '.',
#   '보면서',
#   '추억',
#   '이',
#   '세록',
#   '세록'],
#  ['일본', '영화', '좋아한다면', '꼭', '봐', '야할', '영화', '!'],
#  ['진짜',
#   '재미없다',
#   '..',
#   '영화관',
#   '에',
#   '삼십분',
#   '정도',
#   '늦게',
#   '들어갔는데',
#   '사람',
#   '이',
#   '한',
#   '명도',
#   '없고',
#   '..',
#   '그',
#   '이유',
#   '를',
#   '왠지',
#   '알것',
#   '같네',
#   '..^^',
#   '완전',
#   '비추요'],
#  ['아니',
#   '찍어놓고',
#   '모니터링',
#   '한번',
#   '안',
#   '하나',
#   '어떻게',
#   '염치',
#   '업',
#   '이',
#   '이런',
#   '걸',
#   '극장',
#   '에',
#   '걸수가',
#   '있지',
#   '?'],
#  ["'",
#   '디',
#   '워',
#   "'",
#   '랑',
#   '같은',
#   '부류',
#   '..',
#   '저',
#   '예산',
#   '+',
#   '저렴한',
#   'CG',
#   '+',
#   '마구잡이',
#   '연출'],
#  ['보면서', '어이없어서', '헛웃음', '만', '나던', '....'],
#  ['기쁨',
#   ',',
#   '슬픔',
#   ',',
#   '생명',
#   '그리고',
#   '죽음',
#   '.',
#   '인간',
#   '의',
#   '역사',
#   '속',
#   '에',
#   '거대한',
#   '하나님',
#   '의',
#   '우주',
#   '적',
#   '섭리',
#   '가',
#   '느껴지는',
#   '영화',
#   '.',
#   '특별히',
#   '어머니',
#   '의',
#   '역',
#   '을',
#   '맡은',
#   '여배우',
#   '의',
#   '여',
#   '성미',
#   '와',
#   '자애',
#   '로움',
#   '이',
#   '인상',
#   '적',
#   '이다',
#   '.',
#   '인생',
#   '을',
#   '살면서',
#   '그런',
#   '존재',
#   '가',
#   '된다면',
#   '.',
#   '영',
#   '상미',
#   '예술',
#   '이다',
#   '!'],
#  ['정말', '광해', '와', '비슷한가', '?'],
#  ['콜린', '파렐', '.', '123412341234'],
#  ['엄청나게', '기대', '를', '하고', '본게', '아니라', '괜찮았던듯', '?'],
#  ['정말', '식상하다못해', '촌스럽기까지', '~~~~~~~~~~'],
#  ['돈',
#   '에',
#   '미친',
#   '남편',
#   '과',
#   '..',
#   '아기',
#   '에',
#   '미친',
#   '돈',
#   '있는',
#   '남자',
#   '그',
#   '속',
#   '에서',
#   '갈등',
#   '하는',
#   '여자',
#   '18'],
#  ['공격',
#   '적',
#   '인',
#   '재미',
#   ',',
#   '유순한',
#   '여성성',
#   ',',
#   '일기토',
#   ',',
#   '지략',
#   '삼국지',
#   '의',
#   '그것',
#   '과',
#   '맞짱',
#   '!'],
#  ['평점', '조절', '...'],
#  ['배우', '가', '아깝다', ',,'],
#  ['감독',
#   '이',
#   '밥',
#   '은',
#   '먹고',
#   '다니는지',
#   '궁금하다',
#   '.',
#   '배틀로얄',
#   '2',
#   '이후',
#   '로',
#   '최고',
#   '쓰래',
#   '기',
#   '.'],
#  ['좋은', '영화', '~'],
#  ['무슨', '생각', '으로', '만든', '걸까', '.'],
#  ['625',
#   '를',
#   '직접',
#   '겪은',
#   '어르신',
#   '들',
#   '얘길',
#   '들어',
#   '보면',
#   '그',
#   '당시',
#   '잔인한',
#   '학살',
#   '은',
#   '대부분',
#   '주민',
#   '들',
#   '서',
#   '로간',
#   '에',
#   '(',
#   '주로',
#   '하층',
#   '민',
#   '들',
#   '의',
#   '복수심',
#   '에서',
#   '비롯',
#   '된',
#   ')',
#   '또는',
#   '군',
#   '/',
#   '경이',
#   '빨치산',
#   '학살',
#   '한다며',
#   '벌인',
#   '살인',
#   '이었지',
#   '정작',
#   '북한',
#   '군',
#   '은',
#   '민간인',
#   '들',
#   '한테',
#   '는',
#   '잘',
#   '해줬다고',
#   '하던데',
#   '?'],
#  ['네이버',
#   '별',
#   '점',
#   ',',
#   '꽤',
#   '신뢰',
#   '도',
#   '가',
#   '높네요',
#   '.',
#   '5',
#   '점',
#   '이하',
#   '는',
#   '안',
#   '보는게',
#   '좋을듯',
#   '..'],
#  ['이', '거', '시청률', '이', '너무', '낮은대', '명작', '이', '고만'],
#  ['해군', '출신', '이라', '관심', '있게', '본', '영화', '~'],
#  ['내', '가본', '영화', '중', '베스트', '5', '안', '에', '듬', '진짜', '꼭', '보세요'],
#  ['예고편',
#   '을',
#   '왜',
#   '하는',
#   '건지',
#   '모르겠음',
#   '..',
#   '예고편',
#   '에',
#   '나오는건',
#   '하나',
#   '도',
#   '안',
#   '나오고',
#   '..',
#   '예고편',
#   '은',
#   '대판',
#   '쌈질',
#   '하는것',
#   '마냥',
#   '나오더니',
#   '하하호호',
#   '하고',
#   '끝남',
#   '..',
#   '예고편',
#   '이',
#   '무슨',
#   '뜻',
#   '인지',
#   '를',
#   '모르는',
#   '건지',
#   '..',
#   '시청자',
#   '들',
#   '을',
#   '호구',
#   '로',
#   '보는',
#   '건지',
#   '..',
#   '낚시질',
#   '좀',
#   '그만하시고',
#   '차라리',
#   '시청률',
#   '걱정',
#   '되면',
#   '폐지',
#   '해'],
#  ['설득', '력', '없는', '꼴통', '페미니즘', '.', '페미나치', '적', '인', '마인드', '.'],
#  ['진짜',
#   '언제',
#   '90분',
#   '이',
#   '지나갔는지',
#   '모를',
#   '정도',
#   '로',
#   '몰입',
#   '해서',
#   '보고',
#   '정말',
#   '너무',
#   '재미있게',
#   '봄',
#   '...',
#   '너무',
#   '아련해서',
#   '영화',
#   '평',
#   '정말',
#   '처음',
#   '남겨',
#   '봄',
#   '..',
#   '진짜',
#   '내',
#   '가',
#   '이',
#   '나이',
#   '에',
#   '애니',
#   '를',
#   '보며',
#   '이',
#   '밤중',
#   '에',
#   '이렇게',
#   '울줄이야',
#   '..',
#   '에몽',
#   '아',
#   'ㅠㅠ'],
#  ['오글거리고', '유치하고', '완전', '최악', '이었음', '...'],
#  ['자꾸',
#   '뭘',
#   '설득',
#   '할',
#   '려',
#   '하고',
#   '설교',
#   '할려고',
#   '하는게',
#   '보기',
#   '거북하다',
#   '.',
#   '그리고',
#   '결혼반지',
#   '를',
#   '위해',
#   '범죄',
#   '가',
#   '담하다니',
#   '무슨',
#   '개역',
#   '지',
#   '설정',
#   '이냐',
#   '.'],
#  ['존내', '재밋습', '네', '다'],
#  ['순수함이',
#   '두근거려',
#   '좋았다',
#   '감독',
#   '님',
#   '은',
#   '관객',
#   '들',
#   '이',
#   '뭘',
#   '원하는지',
#   '잘아는듯',
#   '..',
#   '여운',
#   '이',
#   '많이',
#   '남는다'],
#  ['천녀유혼',
#   '1',
#   ',',
#   '2',
#   '에',
#   '비',
#   '하면',
#   ',',
#   '뭐라',
#   '표현',
#   '하기',
#   '힘든',
#   '퀭',
#   '한',
#   '영화'],
#  ['솔직히', '산만', '하기만', '했다'],
#  ['기억',
#   '은',
#   '조작',
#   '되기',
#   '마련',
#   '..',
#   '그',
#   '사람',
#   '이',
#   '아니고서는',
#   '함',
#   '부러',
#   '말',
#   '하지',
#   '말',
#   '자'],
#  ['정말', '사랑', '에', '대해', '다시', '생각', '한', '거', '같습니다', '감동', '이에요'],
#  ['진짜', '쓰레기', '영화', '..', '돈', '아까워', '죽는줄', '알았다', '..', '여러분', '보지', '마세요'],
#  ['독립영화',
#   '실력',
#   '자',
#   '들',
#   '의',
#   '스타',
#   '리그',
#   ',',
#   '옴니버스',
#   '라는',
#   '피로',
#   '감',
#   '이',
#   '극복',
#   '되는',
#   '수준',
#   '이다',
#   '.',
#   "'",
#   '얼음',
#   '강',
#   "'",
#   '은',
#   '단독',
#   '장편',
#   '으로',
#   '만들었어도',
#   '좋았을',
#   '듯',
#   '.',
#   '주인공',
#   '이',
#   '혹',
#   '여',
#   '-',
#   '평소',
#   '라면',
#   '1%',
#   '도',
#   '공감',
#   '안되는',
#   '-',
#   '여호와',
#   '의',
#   '증인',
#   '이라도',
#   '납득',
#   '이',
#   '될',
#   '정도',
#   '로',
#   '감정',
#   '을',
#   '설득',
#   '하는',
#   '솜씨',
#   '가',
#   '탁월하다',
#   '.'],
#  ['서스펜스', '도', '없고', '스릴', '도', '없다', '.'],
#  ['너무', '너무', '귀여운', '영화'],
#  ['아이', '들', '과', '함께', '보기', '좋았지만', ',', '그냥', '그래요', '.'],
#  ['보',
#   '니까',
#   '선정',
#   '성',
#   '이',
#   '좀',
#   '15',
#   '세',
#   '같음',
#   '::::',
#   '그래도',
#   '액션',
#   '은',
#   '좋음'],
#  ['답', '을', '알려고', '하지마라', '.'],
#  ['이',
#   '거',
#   '참',
#   '...',
#   '소재',
#   '는',
#   '참',
#   '좋은데',
#   '내용',
#   '전개',
#   '가',
#   '개판',
#   '...',
#   '사람',
#   '수도',
#   '많고',
#   '총',
#   '도',
#   '있는데',
#   '그걸',
#   '지',
#   '들',
#   '끼리',
#   '서로',
#   '다',
#   '흩어져서',
#   '일방',
#   '적',
#   '으로',
#   '밀리',
#   '네',
#   '..',
#   '거기',
#   '다',
#   '식인종',
#   '이라',
#   '면서',
#   '표현',
#   '을',
#   '좀비',
#   '로',
#   '해놓으면',
#   '어쩌잔거',
#   '야',
#   '..',
#   '식인',
#   '으로',
#   '인해',
#   '인성',
#   '이',
#   '말살',
#   '되고',
#   '짐승',
#   '화',
#   '되었다는',
#   '표현',
#   '이라도',
#   '있던가'],
#  ['8',
#   '점',
#   '대',
#   '는',
#   '나와야지',
#   '.',
#   '그냥',
#   '단순한',
#   '액션',
#   '공포물',
#   '이',
#   '아닌데도',
#   '긴장감',
#   '공포',
#   '감',
#   '연출',
#   '쩔고',
#   '음악',
#   '도',
#   '좋고',
#   '..',
#   '몇',
#   '년',
#   '이',
#   '지나도',
#   '기억나는',
#   '인상',
#   '적',
#   '인',
#   '좀비',
#   '물',
#   '인데',
#   '.',
#   '평점',
#   '너무',
#   '짜서',
#   '10',
#   '줌'],
#  ['ufo', '를', '믿으려는', '자', '들', '.'],
#  ['유투브', '동영상', '을', '돈', '내고', '보는게', '낫다', '는', '생각', '이', '들게', '한', '영화'],
#  ['구', '우우', '웃', '~~!!!!'],
#  ['이', '것', '도', '재밌는데', '...', 'ㅋㅋ'],
#  ['괜찮은',
#   '영화',
#   ',,',
#   '영화',
#   '도',
#   '괜찮았지만',
#   '나영',
#   '언니',
#   '완전',
#   '머싯',
#   '고',
#   '예뻤음',
#   'ㅠㅠ'],
#  ['슬픈', '맑음', '.', '파문', '에', '주목', '하', '라', '.'],
#  ['완전',
#   '역겨운',
#   '쓰레기',
#   '영화',
#   '다',
#   '기술',
#   '적',
#   '수준',
#   '을',
#   '떠나',
#   '각본',
#   '이',
#   '무',
#   '개념'],
#  ['유럽',
#   '영화',
#   '가',
#   '이번',
#   '정부',
#   '에',
#   '많이',
#   '들어와',
#   '즐겁긴',
#   '하다만',
#   '그',
#   '내용',
#   '들',
#   '이',
#   '왜',
#   '이리',
#   '진부한',
#   '걸까',
#   ',,,,,,,,,,,,,,,,,,,,,,,,,,,',
#   '유럽',
#   '영화',
#   '를',
#   '욕',
#   '되게',
#   '하고있단',
#   '소리',
#   '다',
#   ',,'],
#  ['정말', '재밌게', '봤고', '빈센트', '도', '꼬마', '도', '연기', '너무', '잘', '하네요', '.', 'ㅎ'],
#  ['야경', '꾼', '보다', '엉망', '지루함'],
#  ['야', '세르게이', '!!!', '작은', '고추', '의', '매운', '맛', '을', '보여주마'],
#  ['자식', '을', '그렇게', '때리냐', '?'],
#  ['의도', '는', '좋지만', '너무', '몰입', '이', '안되는걸', '어떡해'],
#  ['ㅇㅇ'],
#  ['샷',
#   '의',
#   '연결',
#   '이',
#   '아닌',
#   '충돌',
#   '만큼이나',
#   '거룩한',
#   '제목',
#   '또한',
#   '인상',
#   '적',
#   '이',
#   '구려'],
#  ['영',
#   '상미',
#   '예쁘고',
#   '좋지만',
#   '러닝',
#   '타임',
#   '이',
#   '2시간',
#   '이',
#   '넘는데',
#   '초반',
#   '30분',
#   '에',
#   '줄거리',
#   '다',
#   '나갔고',
#   '엄청',
#   '지루한',
#   '화보',
#   '집',
#   '보는',
#   '기분',
#   '일본',
#   '영화',
#   '특유',
#   '의',
#   '그',
#   '이해',
#   '못',
#   '할',
#   '희한함이',
#   '있음'],
#  ['마지막', '이', '좀', '황당했지만', '좋은', '영화'],
#  ['파괴', '된', '관객', '들', '.'],
#  ['울컥', '하는', '사회', '현실', 'ㅠㅠ'],
#  ['와', '..', '이건', '진짜', '으리', '으리', '한', '데', '..?'],
#  ['1', '점', '주기도', '아까운', '쓰레기'],
#  ['내',
#   '아까운',
#   '시간',
#   '을',
#   '버리게',
#   '한',
#   '쓰레기',
#   '재미없다',
#   '..',
#   '2',
#   '점',
#   '부터',
#   '점',
#   '수준',
#   '것',
#   '들',
#   'M',
#   '창'],
#  ['킬링타임', '용', '??', '정말', '시간', '아깝다', '!'],
#  ['퀸틴', '타란티노', '의', '포룸', '을', '어줍잖게', '패러디', '한', '졸작'],
#  ['이런게', '말', '그대로', '재미있는', '영화'],
#  ['기존',
#   '의',
#   '매력',
#   '에',
#   '화끈한',
#   '액션',
#   '까지',
#   '즐길',
#   '수',
#   '있는',
#   '건',
#   '극장판',
#   '만의',
#   '매력'],
#  ['민감한', '소재', '를', '어떻게', '이렇게', '뻔', '뻔하게', '만들', '수', '있는지', '...?'],
#  ['제발',
#   '다른',
#   '인간',
#   '들',
#   '보고',
#   '욕좀',
#   '해줘라',
#   'ㅋㅋ',
#   '시간',
#   ',',
#   '배우',
#   '정말',
#   '아깝다',
#   '.'],
#  ['장선우', '여전히', '쓰레기'],
#  ['.', '정말', '최고', '의', '드라마', '..', '외국', '드라마', '첨으로', '깊게', '빠져듬', '.'],
#  ['그럭저럭', '볼', '만', '한', '장면', '들', '.', '그런데', '좀', '늘어짐'],
#  ['의리', '로', '도', '채울수', '없는', '허전함', '...'],
#  ['구식',
#   '촬영',
#   '기법',
#   '이',
#   '그나마',
#   '있던',
#   '액션',
#   '의',
#   '격',
#   '을',
#   '떨어뜨리고',
#   ',',
#   '이해',
#   '가지',
#   '않는',
#   '인물',
#   '의',
#   '행동',
#   '은',
#   '답답하다',
#   '.'],
#  ['2005년',
#   '이면',
#   '좋은',
#   '영화',
#   '많이',
#   '나올',
#   '때',
#   '인데',
#   '...',
#   '요런',
#   'OOO',
#   '가',
#   '~~~',
#   'ㅋㅋㅋ'],
#  ['(',
#   '구',
#   ')',
#   '성',
#   '이나',
#   '연출',
#   '이',
#   '매우',
#   '(',
#   '미',
#   ')',
#   '진한',
#   '(',
#   '호',
#   ')',
#   '러물',
#   '...'],
#  ['작품', '성', '있는', '영화', '는', '10', '점', '이다', '.'],
#  ['주', 'x', '서민', '들', '돈', '빨아서', '잘', '하는', '짓', '이다'],
#  ['TV',
#   '판',
#   '8',
#   '점',
#   '을',
#   '주겠지만',
#   ',',
#   '다른',
#   '것',
#   '이',
#   '있을것이란',
#   '말',
#   '과',
#   '달리',
#   '거',
#   '시기',
#   '밖에',
#   '없다',
#   '.',
#   '실망',
#   '이다',
#   '.'],
#  ['스타트랙', '보다', '100', '배', '재미있음'],
#  ['B',
#   '급',
#   '영화',
#   '의',
#   '찬사',
#   '를',
#   '...',
#   '타란티노',
#   '와',
#   '로드리게즈',
#   '에게',
#   '찬사',
#   '를',
#   '...'],
#  ['이딴',
#   '것',
#   '도',
#   '영화',
#   '라고',
#   '...',
#   '속편',
#   '낼',
#   '생각',
#   '하고',
#   '있었다니',
#   '미쳤지',
#   '//'],
#  ['이런건', '보는거', '아니야', 'ㅡㅡ', '^'],
#  ['완전', '재밋음', '역시', '짱구', '가', '최고', '!!'],
#  ['완전', '짱', '박대동', '길', '홍도', '쾌', '!!!!'],
#  ['목포', '..', '붹'],
#  ['같은',
#   '동족',
#   '이라는',
#   '걸',
#   '떠나서',
#   '같은',
#   '인간',
#   '으로써',
#   '도울',
#   '수',
#   '없다는게',
#   '안타깝네요',
#   '.',
#   '장성택',
#   '사건',
#   '도',
#   '그렇고',
#   '머',
#   '지',
#   '않아',
#   '북한',
#   '체제',
#   '가',
#   '자멸',
#   '할',
#   '날',
#   '도',
#   '멀지',
#   '않은거',
#   '같은데',
#   '...',
#   '중국',
#   '이',
#   '호시탐탐',
#   '노리',
#   '고',
#   '있고',
#   ',',
#   '결국',
#   '엔',
#   '북한',
#   '땅',
#   '을',
#   '중국',
#   '에게',
#   '또',
#   '빼앗길',
#   '것',
#   '같네요',
#   '.'],
#  ['OOO',
#   '기',
#   '영화',
#   '...',
#   '특히',
#   '이정우',
#   '.',
#   '고',
#   '다미',
#   '.',
#   '김푸른',
#   '이',
#   '것',
#   '들',
#   '제일',
#   '심하네'],
#  ['평점', '에', '오류', '가', '있는', '영화', '다'],
#  ['언론',
#   '의',
#   '맹점',
#   '과',
#   '군중심리',
#   '.',
#   '개인',
#   '의',
#   '심리',
#   '까지',
#   '파헤치면서도',
#   '재미',
#   '까지',
#   '균형',
#   '을',
#   '잘',
#   '맞춘',
#   '멋',
#   '진영화'],
#  ['나', '의', '캣우먼', '은', '이렇지', '않아', '!!'],
#  ['시즌',
#   '4',
#   '도',
#   '만들어주세요',
#   '!!',
#   '꼭',
#   '시리즈',
#   '중',
#   '에는',
#   '3',
#   '가',
#   '젤',
#   '재밌었',
#   '찌',
#   '만',
#   '하윤',
#   '이',
#   '가',
#   '없어',
#   ',,',
#   'ㅜㅜ'],
#  ['특수', '효과', '없이도', '관객', '을', '납득', '시키던', '능력', '.'],
#  ['존쿠삭', '같은', '남자', '와', '결혼', '하고', '싶음', '.', 'ㅋㅋ'],
#  ['데이빗',
#   '린치',
#   '를',
#   '좋아하는',
#   '사람',
#   '에겐',
#   '필추',
#   '.',
#   '물론',
#   'TV',
#   '드라마',
#   '를',
#   '먼저',
#   '보고',
#   '봐야',
#   '..'],
#  ['기분', '종', '게', '웃겨주는', '영화', '...'],
#  ['그레이',
#   '아',
#   '나',
#   '토미',
#   '같은',
#   '의학',
#   '인척',
#   '하는',
#   '로맨스',
#   '가',
#   '아니라',
#   '진짜',
#   '의학',
#   '드라마',
#   'ㅋㅋ'],
#  ['예능',
#   '이라고',
#   '하기에는',
#   '서로',
#   '싸우고',
#   '갈등',
#   '생기',
#   '고',
#   '이런',
#   '거',
#   '를',
#   '보여주니까',
#   '괜히',
#   '보는',
#   '사람',
#   '도',
#   '짜증나네요',
#   ';'],
#  ['말', '이', '필요없다', '.', '보다가', '자려고', '마음', '먹엇다'],
#  ['종훈', '이형', '가오', '상하', '게', '왜', '이런데', '나와요'],
#  ['최고'],
#  ['보지마'],
#  ['재미', '있었어요', '~', '아이', '도', '재미있었데요'],
#  ['빨간',
#   '풍선',
#   '을',
#   '따라가는',
#   '아이',
#   ',',
#   '아이',
#   '를',
#   '통해',
#   '행복해지는',
#   '이',
#   '들',
#   '..',
#   '아름답다',
#   '..'],
#  ['나',
#   '이',
#   '거',
#   '중학교',
#   '때',
#   '퍼펙트',
#   '월드',
#   '랑',
#   '동시',
#   '상',
#   '열으',
#   '루',
#   '봤는데',
#   'ㅋㅋㅋ',
#   '잼있었음',
#   '!!'],
#  ['깜찍하고', '귀여운', '엄지', '왕자', ',', '사악한', '마녀', '로부터', '마을', '을', '지켜라'],
#  ['별루'],
#  ['왜', '만', '든지', '모르겟다', '.'],
#  ['실질',
#   '적',
#   '인',
#   '점수',
#   '..',
#   '미국인',
#   '친구',
#   '란',
#   '제목',
#   '은',
#   '왜',
#   '붙인',
#   '건지',
#   '..',
#   'ㅜ'],
#  ['제시카알바', '정도', '의', '배우', '가', '이따위', '쓰레기', '나온', '이유', '를', '모르겠다'],
#  ['감독',
#   '대',
#   '실망',
#   '이다',
#   '.',
#   '호화',
#   '배역',
#   '진',
#   '이',
#   '아깝다',
#   '.',
#   '죽도',
#   '밥',
#   '도',
#   '안된',
#   '엉',
#   '성함'],
#  ['감성', '팔이', '애국', '주의', '는', '그만', '~!!'],
#  ['강철중', '시리즈', '완전', '잼남'],
#  ['그냥', '별루', '다', '...', '극장', '에서', '안', '보길', '다행', '인', '듯', '...'],
#  ['별',
#   '점',
#   'ㅇ',
#   '점',
#   '옛날',
#   '미이라',
#   '생각',
#   '하고',
#   '10,000원',
#   '이나',
#   '주고',
#   '뵜는데',
#   '돈',
#   ',',
#   '시간',
#   '만',
#   '날렸음',
#   '도대체',
#   '영화',
#   '를',
#   '통해',
#   '말',
#   '하려는게',
#   '뭔',
#   '지',
#   '도통',
#   '????',
#   '재미',
#   '도',
#   '감동',
#   '도',
#   '꽝',
#   '....',
#   '다른',
#   '사람',
#   '평점',
#   '봤으면',
#   '안',
#   '봤을텐데',
#   '어휴',
#   '아까워',
#   'ㅠㅜ'],
#  ['미학', '적', '완성', '도', '가', '한국영', '화', '중', '최상급', '이다', '.'],
#  ['내용', '기대', '없이', '훈훈한', '주인공', '오빠', '보기', '엔', '굿'],
#  ['감독', '자질', '문제', '라고', '밖엔'],
#  ['어렸을',
#   '때',
#   '영화',
#   '보면서',
#   '저',
#   '쥐',
#   '가지고싶단',
#   '생각',
#   '만',
#   '했었다',
#   '-_',
#   '-',
#   'ㅋㅋ'],
#  ['영화',
#   '든',
#   '애니',
#   '든',
#   '일단',
#   '브랜드',
#   '하고',
#   '광고',
#   '로',
#   '먹어준다',
#   '.',
#   '이런',
#   '숨은',
#   '명작',
#   '은',
#   '많은',
#   '이',
#   '가',
#   '보고',
#   '감동',
#   '을',
#   '받아야',
#   '함',
#   '.',
#   '본',
#   '건',
#   '5년',
#   '전',
#   '인데',
#   '...',
#   '다시',
#   '보고',
#   '또',
#   '감동',
#   '받아서',
#   '평',
#   '씀',
#   '.'],
#  ['제목',
#   '만',
#   '보고',
#   '왠지',
#   '장르',
#   '가',
#   '공포',
#   '인',
#   '듯',
#   '한',
#   '느낌',
#   '이',
#   'ㄷㄷ',
#   '...'],
#  ['봐주기', '아까운', '영화'],
#  ['왜',
#   '이',
#   '게',
#   '이렇게',
#   '평점',
#   '이',
#   '높은지',
#   '영화',
#   '를',
#   '다',
#   '보고',
#   '나서도',
#   '잘',
#   '모르겠다',
#   '.'],
#  ['영화',
#   '보고',
#   '울어야',
#   '될',
#   '것',
#   '같아서',
#   '운',
#   '게',
#   '아니라',
#   '진짜',
#   '감동',
#   '해서',
#   '운',
#   '적',
#   '은',
#   '처음',
#   '이다',
#   '...',
#   'ㅠㅠ'],
#  ['박시후',
#   '때문',
#   '에',
#   '참고',
#   '또',
#   '참고',
#   '봐',
#   '줬다',
#   '.',
#   '15회',
#   '까지',
#   '...',
#   '야',
#   '.....',
#   '시간',
#   '이',
#   '아깝구나',
#   '.....',
#   '박시후',
#   '는',
#   '완전',
#   '한',
#   '세',
#   '경의',
#   '꼭두각시',
#   '가',
#   '되어',
#   '같은',
#   '캐릭터',
#   '로',
#   '전락',
#   '.',
#   '.....',
#   'ㅜㅠ',
#   '....',
#   '한',
#   '세',
#   '경',
#   '같은',
#   '여자',
#   '만날까봐',
#   '세상',
#   '이',
#   '무서워진다',
#   '.',
#   '정말',
#   '작가',
#   '들',
#   '이',
#   '초등생',
#   '수준',
#   '!'],
#  ['역시', '줄리엣', '비노', '쉬는', '이뻣다', '.^^', '보면', '따뜻해지는', '영화'],
#  ['짱짱한', '배우', '진임', '에도', '불구', '하고', '심심하기', '그', '지', '없는', '스릴'],
#  ['아', '재밌', '당', '아', '재밌당', '아', '재밌당', '아', '재밌당', '아', '재밌당'],
#  ['볼', '만', '합니다', '강추', '!!', 'ㅋㅋ'],
#  ['재미없다', '...'],
#  ['요즘',
#   '에도',
#   '매번',
#   '지식인',
#   '에',
#   '물어본다',
#   '.',
#   "'",
#   '프리즌브레이크',
#   '만',
#   '한',
#   '미드',
#   '없어요',
#   "?'",
#   '라고'],
#  ['보내는', '내내', '궁금증', '은', '유발', '하', '지만', '지루하게', '끝나', '버림', '.'],
#  ['화면',
#   '좋고',
#   '배우',
#   '좋고',
#   '스릴',
#   '감',
#   '있는',
#   '그리고',
#   '재미있고',
#   '...',
#   '훌륭한',
#   '드라마',
#   '라고',
#   '생각',
#   '합니다',
#   '.'],
#  ['완벽한',
#   '형태',
#   '를',
#   '가진',
#   '완벽한',
#   '날카로',
#   '움',
#   '을',
#   '가진',
#   '형이상학적',
#   '가시',
#   '로',
#   '찔린',
#   '기분',
#   '이다',
#   '.',
#   '무',
#   '지각',
#   '적',
#   '순수',
#   '가',
#   '얼마나',
#   '무서운지',
#   '공기',
#   '까지',
#   '전해진다',
#   '.'],
#  ['진짜',
#   '그지같은',
#   '영화',
#   '_',
#   '와나',
#   '_',
#   '어릴',
#   '적',
#   '에',
#   '본거라',
#   '내용',
#   '은',
#   '기억',
#   '도',
#   '안나는데',
#   '그지같았다는',
#   '느낌',
#   '만',
#   '기억',
#   '에',
#   '남아있네요',
#   '_',
#   '내',
#   '평생',
#   '에',
#   '가장',
#   '돈',
#   '아까운',
#   '영화',
#   '넘버원',
#   '임',
#   '-_-',
#   '0',
#   '점',
#   '짜리',
#   '영화'],
#  ['TV', '시리즈', '는', '못', '봤지만', '영화', '는', '볼', '만', '했다'],
#  ['짱',
#   '재밌다',
#   '!!!',
#   '김지수',
#   ',',
#   '이하나',
#   ',',
#   '한재석',
#   ',',
#   '정겨운',
#   ',',
#   '최정희',
#   '교수',
#   '님',
#   ',',
#   '장',
#   '태문',
#   '회장',
#   '님',
#   ','],
#  ['알',
#   '행',
#   '님',
#   '의',
#   '연기',
#   '쩔었음',
#   '.',
#   '특히',
#   '매니',
#   '가',
#   '문',
#   '을',
#   '열어주고',
#   '2',
#   '층',
#   '에서',
#   '여동생',
#   '을',
#   '본',
#   '후',
#   '다시',
#   '매니',
#   '를',
#   '쳐다볼',
#   '때',
#   '에그',
#   '분노',
#   '에',
#   '찬',
#   '얼굴',
#   '.',
#   '잊혀지지가',
#   '않는다',
#   '.',
#   '이번',
#   '이',
#   '이영화',
#   '3',
#   '번',
#   '째',
#   '라는',
#   '.',
#   '계속',
#   '봐도',
#   '질리',
#   '지',
#   '않는',
#   '영화',
#   '..',
#   '알',
#   '형님',
#   '의',
#   '카리스마',
#   '가',
#   '대단한',
#   '영화',
#   '였음',
#   '그리고',
#   '리즈시절',
#   '의',
#   '미쉘',
#   '누님',
#   '의'],
#  ['꼭', '보세요', '후회', '안', '합니다', '?'],
#  ['캐스팅', '도', '스토리', '도'],
#  ['이런', '영화', '를', '느와르', '라고', '하는', '것', '이다', '!!!'],
#  ['아이스크림', '이', '길', '을', '가다', '죽었다', '이유', '는', '?', '차가와', '서'],
#  ['스파이더맨',
#   '을',
#   '가장',
#   '좋아하는',
#   '1',
#   '人',
#   '~',
#   '스파이더맨',
#   '완전',
#   '사랑',
#   '합니다',
#   '.',
#   '영원했으면',
#   '좋겠네요',
#   '!!'],
#  ['고현정', '어제', '진행', '도', '좋고', '너무', '이뻤어요', '~!!'],
#  ['어려운', '영화', '여운', '이', '많이', '남는', '영화'],
#  ['내',
#   '가',
#   '영화',
#   '를',
#   '잘',
#   '몰라서',
#   '그러는데',
#   '이런',
#   '걸',
#   '컬트',
#   '영화',
#   '라고',
#   '하는',
#   '건가',
#   '?'],
#  ['막',
#   '설레고',
#   '그런게',
#   '없어서',
#   '쫌',
#   '아쉽고',
#   '알렉스',
#   '오로린',
#   '은',
#   '멋진데',
#   '스탠',
#   '은',
#   '쫌',
#   '심심',
#   '...',
#   '미묘',
#   '?',
#   '남주',
#   '여주',
#   '둘다',
#   '캐릭터',
#   '가',
#   '그닥',
#   '매력',
#   '적',
#   '이지',
#   '가',
#   '않음',
#   '.'],
#  ['한', '승려', '의', '지옥', '으로', '가게', '된', '일대기'],
#  ['몇번', '째', '보는지', '모르겠다', '..'],
#  ['믿고', '보는', '배우', '들', '의', '환상', '연기', '호흡', '!'],
#  ['내',
#   '생애',
#   '최고',
#   '의',
#   '영화인',
#   '것',
#   '같습니다',
#   '.',
#   '정말',
#   '강',
#   '추강',
#   '추',
#   '입니다',
#   '.'],
#  ['와',
#   '감상',
#   '평땜',
#   '에',
#   '진짜',
#   '눈물나게',
#   '웃네',
#   '돈',
#   '아까워',
#   '환불',
#   '해줘',
#   'ㅠ',
#   '무의미한',
#   '자음',
#   '입력',
#   '은',
#   '못',
#   '한다니',
#   '더',
#   '짜증나네'],
#  ['[', '볼륨', '을', '높여라', ']', '의', '재치', '는', '어디', '에', '..'],
#  ['뭔가',
#   '미흡하다',
#   '.',
#   '하지만',
#   '프랑스',
#   '영화',
#   '다운',
#   '은은한',
#   '감동',
#   '이',
#   '묻어',
#   '나온다',
#   '.'],
#  ['제니',
#   '라이트',
#   '존나',
#   '이쁘다',
#   '....',
#   '제니',
#   '라이트',
#   '때매',
#   '10',
#   '점',
#   '내',
#   '손가락',
#   '도',
#   '주고싶다',
#   'ㅠㅠ'],
#  ['불꽃',
#   '같은',
#   '인생',
#   '을',
#   '사시다가',
#   '한',
#   '줌',
#   '의',
#   '재',
#   '가',
#   '되어',
#   '저',
#   '멀리',
#   '하늘',
#   '로',
#   '날아갔네'],
#  ['재밌다', '.'],
#  ['너희', '가', '이', '영화', '를', '봤느뇨', '?'],
#  ['이', '게', '뭐', '지', '싶은', '영화', '기억', '에', '남지', '않을'],
#  ['지루함',
#   '그리고',
#   '드류',
#   '베리',
#   '모어',
#   '역',
#   '꼴사납다',
#   '이',
#   '기적',
#   '이고',
#   '앞뒤',
#   '생각',
#   '없이',
#   '누가',
#   '피해',
#   '를',
#   '보건',
#   '말건',
#   '고래',
#   '만',
#   '살리면',
#   '돼',
#   'ㅡㅡ',
#   '짜증남'],
#  ['영화',
#   '정말',
#   '감동',
#   '적임',
#   '.',
#   '내용',
#   '이',
#   '뻔하다는',
#   '것',
#   '때문',
#   '에',
#   '1',
#   '점',
#   '뺐는데',
#   '나머지',
#   '는',
#   '다',
#   '~',
#   '좋음'],
#  ['배우',
#   '들',
#   '연기',
#   '도',
#   '잘',
#   '하고',
#   '재미있어요',
#   '!!!',
#   'ㅋㅋ',
#   '만',
#   '보때',
#   '가',
#   '제일',
#   '재미있었구요',
#   '^^'],
#  ['이야기', '자체', '가', '탄탄한데다가', '연출', '과', '연기', '가', '조화', '를', '이루는군'],
#  ['꿀잼', '근데', '아나킨', '은', '언제'],
#  ['유리',
#   '랑',
#   '헤어졌으면',
#   '좋겠어요',
#   '유리',
#   '랑',
#   '안',
#   '어울림',
#   '가면',
#   '갈수록',
#   '유리',
#   '연기',
#   '이상함'],
#  ['여러',
#   '말',
#   '필요없는',
#   '드라마',
#   '.',
#   '특히',
#   '이준기',
#   '의',
#   '연기',
#   '는',
#   'best',
#   'of',
#   'best'],
#  ['되게', '재밌게', '봤다', '.', '우디', '해', '럴슨', '의', '연기', '가', '인상', '깊다', '!'],
#  ['이건', '그냥', '야동', '임'],
#  ['인간',
#   '의',
#   '본성',
#   '을',
#   '송어',
#   '에',
#   '빗대어',
#   '냉소',
#   '적',
#   '으로',
#   '바라본',
#   '박종원',
#   '감독',
#   '의',
#   '수작'],
#  ['요즘',
#   '은',
#   '함께',
#   '하는거',
#   '본다',
#   '옴니버스',
#   '식',
#   '이',
#   '던데',
#   '그러',
#   '기',
#   '엔',
#   '.',
#   '가족',
#   '이',
#   '넘',
#   '많아요',
#   '머좀',
#   '빠져들려면',
#   '바뀌고',
#   '바뀌고',
#   '전',
#   '시즌',
#   '1',
#   '부터',
#   '오로지',
#   '윤후',
#   '보려고',
#   '보는데',
#   '점점',
#   '산만해지는',
#   '느낌',
#   '이',
#   '예요',
#   '~~^^',
#   '우리',
#   '윤후',
#   '분량',
#   '좀',
#   '많이',
#   '많이',
#   '늘려주세요',
#   '~',
#   '^^',
#   '너',
#   '무착',
#   '하고',
#   '예쁜',
#   '후',
#   '~~^^'],
#  ['산만해서', '못', '봐주겠는', '영화'],
#  ['미국',
#   '이',
#   '진짜',
#   '선진국',
#   '인',
#   '이유',
#   '가',
#   '있구나',
#   '진짜',
#   '멋',
#   '지드',
#   '라',
#   '...',
#   '최고다'],
#  ['정말', '웃기', '다', 'ㅋㅋ', '1', '편도', '재밌지만', '2', '편이', '더', '재밌다', 'ㅋㅋ'],
#  ['아름다운', '영화'],
#  ['빨리',
#   '종영',
#   '돼길',
#   '여주',
#   '진짜',
#   '못',
#   '생겼다',
#   '머리스타일',
#   '은',
#   '수지',
#   '인데',
#   '이경실',
#   '닮았다',
#   '연',
#   '기도',
#   '짱',
#   '못',
#   '하고',
#   '연기자',
#   '하지마라',
#   '니나',
#   '오는',
#   '드라마',
#   '안',
#   '볼거니까'],
#  ['극장', '에서', '봤어용', '~', '잔잔한', '감동', '좋았습니다', '....'],
#  ['그', '때', '는', '어렸으니까', '재미있게', '봤지만', '지금', '보면', '...', 'ㅋ'],
#  ['스토리', '가', '좀', '뜬금', '없지만', '액션', '은', '역시', '화끈하다'],
#  ['진심', '이', '게', '재밌냐', '?', '분투', '하는', '청춘', '...', '기', '가', '찬다', '..'],
#  ['이',
#   '기적',
#   '인',
#   '남자',
#   '가',
#   '조그만',
#   '마을',
#   '에서',
#   '반복',
#   '된',
#   '일상',
#   '을',
#   '경험',
#   '하면서',
#   '착함을',
#   '얻는다는',
#   '내용',
#   '인데',
#   '다시',
#   '도시',
#   '로',
#   '돌아가면',
#   '경쟁',
#   '이라는',
#   '치열함',
#   '속',
#   '에서',
#   '다시',
#   '이',
#   '기적',
#   '인',
#   '본성',
#   '이',
#   '나올거',
#   '같음',
#   '.',
#   '너무',
#   '영',
#   '화구',
#   '성',
#   '이',
#   '작위',
#   '적',
#   '이고',
#   '단순하다',
#   '.',
#   '작은',
#   '시골',
#   '마을',
#   '에서나',
#   '통',
#   '할',
#   '이야기',
#   '.'],
#  ['3', '류', '영화', '베드', '신', '하나', '믿고', '봤는데', '캐', '실망', '~'],
#  ['처음',
#   '으로',
#   '영화관',
#   '가서',
#   '잠잤던',
#   '영화',
#   '내용',
#   '하',
#   '나',
#   '도기',
#   '억',
#   '안나',
#   '-_-'],
#  ['파트너',
#   '간',
#   '의',
#   '호흡',
#   '도',
#   '전혀',
#   '없고',
#   ',',
#   '아놀드',
#   '는',
#   '러시아어',
#   '쓰는',
#   '터미네이터',
#   '같았다',
#   '.'],
#  ['이', '영화', '엔딩', '곡', '노래', '제목', '아시나요'],
#  ['몇몇', '탁월한', '이미지', '와', '웅장', '한', '음악', '.', '단지', '그것', '뿐'],
#  ['안녕하세요',
#   '.',
#   '저',
#   '는',
#   '이',
#   '영화',
#   '속',
#   '삶',
#   '과',
#   '아주',
#   '흡사한',
#   '삶',
#   '을',
#   '살',
#   '고',
#   '있는',
#   '사람',
#   '입니다',
#   '.',
#   '하지만',
#   '이',
#   '영화',
#   '속',
#   '주인공',
#   '처럼',
#   '아이',
#   '를',
#   '낳진',
#   '않은것',
#   '만',
#   '배제',
#   '한다면',
#   '제',
#   '삶',
#   '이라고',
#   '해도',
#   '무방',
#   '하',
#   '군',
#   '요',
#   '.',
#   '이',
#   '영화',
#   '를',
#   '보게',
#   '된',
#   '계기',
#   '는',
#   '제',
#   '가',
#   '영화',
#   '를',
#   '좋아',
#   '하기',
#   '때문',
#   '입니다',
#   '.'],
#  ['시즌', '3', '까지', '본', '상태', '..', '잼네요', 'ㅋㅋ', '5', '까지', '달리는거다', '~~'],
#  ['기득권',
#   '에',
#   '취해',
#   '너무',
#   '썩은',
#   ',',
#   'but',
#   '썩은',
#   '지도',
#   '모르는',
#   '민주당',
#   '을',
#   '볼수',
#   '있다'],
#  ['개꿀잼', 'ㅋ', '개꿀잼', 'ㅋ', '10', '자'],
#  ['오프라인', '에', '나오셨던', '분신', '의', '선물', '보고', '이제야', '알았다', '.'],
#  ['생각',
#   '없이',
#   '봤는데',
#   '.',
#   '정말',
#   '생각',
#   '이',
#   '없었다',
#   '.',
#   '무슨',
#   '내용',
#   '을',
#   '전달',
#   '하려는',
#   '건지'],
#  ['어렸지만',
#   '정말',
#   '재밌게',
#   '봤던',
#   '외화',
#   '.',
#   '이',
#   '자료',
#   '가',
#   '있다니',
#   '너무',
#   '반갑다',
#   '.',
#   '좋은',
#   '세상',
#   '이야',
#   '.',
#   '특히',
#   '나',
#   '아들',
#   '스',
#   '코트',
#   '헤',
#   '이든',
#   '역',
#   '의',
#   '반즈',
#   '가',
#   '아직도',
#   '기억',
#   '생생',
#   '..',
#   '이름',
#   '까지',
#   '기억나네',
#   '..'],
#  ['정말', '괜찮은', '영화', '.', '행복', '이', '뭍', '어', '나', '는', '^^'],
#  ['한번', '봐서', '결과', '알', '고', '다시', '봐도', '재미', '있음'],
#  ['참', '저', '질', '스런', '영화', '내', '평가', '에', '내', '가', '놀란다', '!!'],
#  ['정말', '기발한', '생각', '이', '담긴', '영화', '였다', '.'],
#  ['저', '예산', '이지만', '개인', '적', '으로', '괜찮았음', '.'],
#  ['다방면', '으로', '만족', '...', '역시', '애니', '는', '판타지'],
#  ['"""""""',
#   '뽜',
#   '와',
#   '알리',
#   '뽜',
#   '아',
#   '아릴',
#   '""""',
#   '한국어',
#   '발음',
#   '에',
#   '개',
#   '빵터짐',
#   '"""'],
#  ['평점', '개', '사기', '다', ';', '이래서', '네이버', '평점', '못', '믿겠어', '..'],
#  ['그냥', '최고', '의', '드라마', '...', '그냥', '보세요', '.', 'ㅠㅠ'],
#  ['한예슬',
#   '진짜',
#   '너무',
#   '이쁘당',
#   'ㅋㅋㅋ',
#   '짱',
#   '인듯',
#   '원래',
#   '도',
#   '이쁜데',
#   '미',
#   '탄에서',
#   '이쁨',
#   '터짐',
#   'ㅋㅋㅋ',
#   '옷',
#   '입는것도',
#   '헤어',
#   '도',
#   '메이크업',
#   '도',
#   '이쁨',
#   '이쁨',
#   '이쁨',
#   '드라마',
#   '내용',
#   '도',
#   '괜찮고',
#   '잘',
#   '될듯',
#   'ㅋㅋㅋ'],
#  ['간만', '에', '웃는다', '!', '아하', '하하', '!!!'],
#  ['초반',
#   '부분',
#   '엔',
#   '좋았는데',
#   '점점',
#   '지루하고',
#   '소설',
#   '내',
#   '용이',
#   '쌩뚱맞다',
#   '..',
#   'ost',
#   '는',
#   '좋음'],
#  ['완벽하다', '!'],
#  ['아베',
#   '히로시',
#   '도',
#   ',',
#   '키',
#   '타무라',
#   '카',
#   '즈',
#   '키도',
#   '좋아하지만',
#   '...',
#   '너무',
#   '기대했나보다',
#   '.',
#   '보면서',
#   '나중',
#   '에는',
#   "'",
#   '온돌',
#   "'",
#   '도',
#   '지네',
#   '꺼',
#   '라',
#   '우기',
#   '면',
#   '어쩌나',
#   '...',
#   '하는',
#   '생각',
#   '도',
#   '들었다',
#   '.'],
#  ['ㅎ',
#   '애',
#   '들',
#   '이랑',
#   '넘',
#   '재미나',
#   '게',
#   '봤어요',
#   '하하호호',
#   '하면서',
#   '계속',
#   '웃음',
#   '이',
#   '나면서',
#   '가족',
#   '애',
#   '를',
#   '다시',
#   '한번',
#   '느꼈답니다'],
#  ['어렵게',
#   '사는',
#   '우리네',
#   '인생',
#   '이야기',
#   '답답하면서',
#   '현실',
#   '을',
#   '직시',
#   '한',
#   '내용',
#   '들',
#   '을',
#   '무겁게',
#   '잘',
#   '표현',
#   '하셨네요'],
#  ['시나리오', '연기', '연출', '모든', '면', '에서', '좋았다'],
#  ['그냥', '쓰레기', '지', '쓰레기', '~'],
#  ['나오',
#   '코',
#   '가',
#   '죽으니까',
#   '원래',
#   '귀신',
#   '보다',
#   '훨씬',
#   '더',
#   '무서움',
#   '.',
#   '나오',
#   '코',
#   '를',
#   '진작',
#   '죽일것이지',
#   'ㅋㅋ'],
#  ['한동안',
#   '댓글',
#   '안',
#   '썼었는데',
#   '..',
#   '댓글',
#   '이',
#   '너무해서',
#   '씁니다',
#   '.',
#   '1',
#   '점',
#   '까진',
#   '아닌데',
#   '평점',
#   '이',
#   '너무',
#   '높아',
#   '1',
#   '점',
#   '드리고요',
#   '..',
#   '한',
#   '3',
#   ',',
#   '4',
#   '점',
#   '짜리',
#   '영화인',
#   '듯',
#   '..',
#   '좋은',
#   '가족영화',
#   '라고',
#   '해서',
#   '개',
#   '를',
#   '훔치는',
#   '완벽한',
#   '방법',
#   '같은',
#   '영화로',
#   '상상',
#   '하고',
#   '봤는데',
#   '정말',
#   '뭐라',
#   '말',
#   '이',
#   '안',
#   '나오네요',
#   '..'],
#  ['말',
#   '에게도',
#   '사랑',
#   '이',
#   '있고',
#   '우정',
#   '이',
#   '있음',
#   '.',
#   '전쟁',
#   '이',
#   '무서운',
#   '걸',
#   '새삼',
#   '알',
#   '게',
#   '됬다하하하',
#   'ㅏ'],
#  ['유니크', '하고', '매력', '적', '인', '영화', '^^'],
#  ['최고', '의', '드라마', '..'],
#  ['또', '보고싶은'],
#  ['본', '영화', '들', '중', '가장', '...'],
#  ['이나영', '넘', '귀여워', 'ㅋㅋ', '귀여운', '영화', '인거', '같다', '.'],
#  ['이건', '무슨', '내용', '이', '없어', '...'],
#  ['이',
#   '드라마',
#   '의',
#   '시청률',
#   '이',
#   '한',
#   '팬',
#   '으로써',
#   '마음',
#   '이',
#   '안좋았지만',
#   '나',
#   '는',
#   '깨',
#   '달았어',
#   '..',
#   '시청률',
#   '이',
#   '낮을수록',
#   '재밌고',
#   '마음',
#   '이',
#   '깊이',
#   '느낄수있는',
#   '드라마',
#   '라',
#   '는걸'],
#  ['OOO', '기'],
#  ['미', '확인', '동영상', ':', '영화', '절대', '클릭', '금지'],
#  ['우선',
#   '평점',
#   '1',
#   '점',
#   '의',
#   '이유',
#   '는',
#   '현재',
#   '평점',
#   '이',
#   '너무나',
#   '높기',
#   '때문',
#   '이다',
#   '간략해서',
#   '영',
#   '화보',
#   '는',
#   '내내',
#   '엄청나게',
#   '불편',
#   '햇',
#   '다',
#   '서울시장',
#   '후보',
#   '아내',
#   '엄정화',
#   '가',
#   '나와서',
#   '서른',
#   '도',
#   '넘은',
#   '섹시',
#   '가수',
#   '몸',
#   '에',
#   '착',
#   '달라붙고',
#   '가슴',
#   '이',
#   '거의',
#   '다',
#   '보이는',
#   '의상',
#   '을',
#   '입고',
#   '춤',
#   '을',
#   '출',
#   '때',
#   '불쾌함을',
#   '넘어',
#   '상당히',
#   '안좋은',
#   '기분',
#   '을',
#   '느끼게',
#   '해준다'],
#  ['원작',
#   '이',
#   '너무',
#   '좋았다',
#   '..',
#   '일본',
#   '은',
#   '영화',
#   '리메이크',
#   '가',
#   '늘',
#   '한심하다',
#   '..'],
#  ['어차피', '우승', '은', '송민호', '~'],
#  ['10만',
#   '표로',
#   '무슨',
#   '대국민',
#   '투표',
#   '라고',
#   '사기',
#   '를',
#   '치고',
#   '어휴',
#   '...',
#   '박시환',
#   'MAMA',
#   '가는거',
#   '생각',
#   '만',
#   '해도',
#   '끔찍하다'],
#  ['이건',
#   '진짜',
#   '6',
#   '점',
#   '이',
#   '적당함',
#   '평점',
#   '내려야',
#   '됨',
#   '화끈한',
#   '액션',
#   '이',
#   '있는것도',
#   '아니고',
#   '반전',
#   '이',
#   '엄청난것도',
#   '아니고',
#   '노',
#   '출신',
#   '이',
#   '있는것도',
#   '아니고',
#   '보다가',
#   '살짝',
#   '잠들었음'],
#  ['쓰레기', '중', '의', '쓰레기', '영화', '모든', '것', '이', '쓰레기', '다', '.'],
#  ['이', '젠', '측은해', '지기', '까지', '하는', '니콜라스', '케이', '지'],
#  ['전개',
#   '억지스럽고',
#   '연출',
#   '도',
#   '조금',
#   '산만한듯',
#   '소품',
#   '들',
#   '도',
#   '좀',
#   '어색합니다',
#   '비행기',
#   '씬',
#   '은',
#   '어쩔',
#   '수',
#   '없다지만',
#   '..'],
#  ['이', '것', '도', '진짜', '재밌게', '본듯'],
#  ['별',
#   '반개',
#   '도',
#   '아까운',
#   '영화',
#   '.',
#   '멀쩡한',
#   '배우',
#   '들',
#   '을',
#   '3',
#   '류',
#   '배우',
#   '로',
#   '추락',
#   '시킴',
#   '.',
#   '각본',
#   ',',
#   '연출',
#   ',',
#   '영상',
#   '모두',
#   '수준',
#   '이하'],
#  ['완전', '찝찝한', '영화', '...'],
#  ['정은채', '...', '연기', '드럽게', '못', '하네', 'ㅉㅉㅉ'],
#  ['천국', '보다', '아름다운', '것', '은', '사랑', '?'],
#  ['1',
#   '.',
#   '감독',
#   '이',
#   '씨발',
#   '바쁜게',
#   '아니라면',
#   '이따위',
#   '로',
#   '찍',
#   '을',
#   '이유',
#   '가',
#   '없다',
#   '.',
#   '직선',
#   '으로',
#   '가는',
#   '길',
#   '놔두고',
#   '돌아가는걸',
#   '두고',
#   '획기',
#   '적',
#   '이라고는',
#   '하지',
#   '않는다',
#   '.',
#   '2',
#   '.',
#   '영화인',
#   '들',
#   '의',
#   '특권',
#   '의식',
#   '과',
#   '그',
#   '들',
#   '의',
#   '촬영',
#   '하는',
#   '행위',
#   '에',
#   '대한',
#   '미화',
#   '가',
#   '듬뿍',
#   '담겨져있',
#   '따',
#   '.',
#   '그리고',
#   '전체',
#   '적',
#   '인',
#   '내용',
#   '재미',
#   '도',
#   '없고',
#   '의미'],
#  ['어이없게',
#   '웃기',
#   '고',
#   '지기',
#   '의',
#   '아빠',
#   '가왜',
#   '나왔는지',
#   '아직도',
#   '의문',
#   ',,',
#   '날',
#   '패닉',
#   '상태',
#   '로만',
#   '든',
#   '최악',
#   '의',
#   '영화'],
#  ['와', '...', 'ㅋㅋ', '언', '제', '쩍', '스티븐', '시', '걸이', '냐', 'ㅋㅋ'],
#  ['솔직히',
#   '베드',
#   '신',
#   '보려고',
#   ',',
#   '보게',
#   '된',
#   '영화',
#   '인데',
#   '중간',
#   '중간',
#   '대사',
#   '에',
#   '몰입',
#   '되면서',
#   '처음',
#   '부터',
#   '끝',
#   '가지',
#   '풀',
#   '로',
#   '보게',
#   '되었습니다',
#   '.',
#   '원작',
#   '책',
#   '으로는',
#   '읽어',
#   '보진',
#   '못',
#   '하였지만',
#   '책',
#   '도',
#   '한번',
#   '봐야겠군요',
#   '감명',
#   '깊게',
#   '잘',
#   '보았습니다',
#   '.'],
#  ['오늘',
#   '도',
#   '대학로',
#   '에서',
#   '방송국',
#   '에서',
#   '열심히',
#   '기회',
#   '를',
#   '찾는',
#   '분들',
#   ',',
#   '힘내시길',
#   '!'],
#  ['으', '~~', '최악', '이다'],
#  ['재미',
#   '잏',
#   '긴한데',
#   '맨',
#   '마지막',
#   '부분',
#   '이',
#   '너',
#   '무산',
#   '으로가',
#   '버렸어요',
#   '.',
#   '갑자기',
#   '가족',
#   '이다',
#   '만나고',
#   '해피엔딩',
#   '이지만',
#   '맨',
#   '마지막',
#   '부분',
#   '이',
#   '좀',
#   '그러네요'],
#  ['한번', '보면', '빠져들어', '버리는', '...', '재미있는', '사신', '드라마', '.'],
#  ['퀄리티', ':', '주원', '김아중', '나오는', '뽀로로'],
#  ['그냥', '별', '생각', '없이', '보고나서', '생각', '해보니', '감탄사', '가', '터지는', '영화'],
#  ['아오', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'ㅅㅂ', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['인생',
#   '은',
#   '아직도',
#   '보고',
#   '배울',
#   '것',
#   '이',
#   '많겠지',
#   ',,',
#   '하지만',
#   '난',
#   '왜',
#   '이렇게',
#   '움',
#   '추리',
#   '고',
#   '있을까',
#   ',,,'],
#  ['나', '잤다', '그냥', '영화관', '에', '팝콘', '이나', '먹자'],
#  ['난', '재미있는데', 'ㅋ', '?'],
#  ['좋다'],
#  ['정말', '재밋', '게', '본', '작품', '이다', '..', '왜', '이제', '서야', '봤을까'],
#  ['왜', '한국인', '간', '들이', '배', '낀거있지', '?', '말', '않', '해도', '알꺼라'],
#  ['이',
#   '영화',
#   '는',
#   '재미',
#   '보다는',
#   '메세지',
#   '를',
#   '전',
#   '하는것',
#   '같네요',
#   '잔잔하면서도',
#   '그다음',
#   '장면',
#   '이',
#   '궁금하게',
#   '만드는',
#   '영화',
#   '.'],
#  ['Gooooooooood', '민세', '연', '박영린', '넘', '이쁘다'],
#  ['딱히',
#   '노래',
#   '말고는',
#   '건질게',
#   '없는',
#   '..',
#   '남녀',
#   '캐릭터',
#   '가',
#   '매력',
#   '적',
#   '이지',
#   '않다는',
#   '게',
#   '가장',
#   '큰',
#   '문제',
#   '고',
#   ',',
#   '내용',
#   '도',
#   '너무',
#   '유치하게',
#   '흘러간다는',
#   '것',
#   '.'],
#  ['추천', '할만', '한', '경', '제', '영화', '였음'],
#  ['시나리오', '는', '별로', '인데', '배우', '들', '이', '살린', '영화', '..'],
#  ['세영', '어느', '정도', '것', '해야지', '욕', '나오도록', '천', '사표', '..', 'OO'],
#  ['보지',
#   '도',
#   '못',
#   '한',
#   '사람',
#   '들',
#   '이',
#   '왜',
#   '.',
#   '평점',
#   '달',
#   '지',
#   '?',
#   '그나저나',
#   '이',
#   '게',
#   '있다는게',
#   '신기하',
#   '넹',
#   'ㅋ',
#   '30분',
#   '짜리영화',
#   '돈',
#   '다주',
#   '고',
#   '봤었는데',
#   'ㅋㅋ'],
#  ['완존', '재밌어'],
#  ['차가',
#   '아니고',
#   '괴물',
#   '이면',
#   '괴물',
#   '이지',
#   '문',
#   '은',
#   '왜',
#   '잠기냐',
#   'ㅋㅋ',
#   '괴물',
#   '이',
#   '초능력',
#   '도',
#   '쓰냐',
#   '?'],
#  ['I', 'wonder', 'this', 'movie', '.'],
#  ['호프만',
#   '과',
#   '핵',
#   '크만을',
#   '동시',
#   '에',
#   '볼',
#   '수',
#   '있다는',
#   '것',
#   '만으로',
#   '10',
#   '점',
#   '이다',
#   '.',
#   '개연',
#   '성',
#   '에는',
#   '다소',
#   '무리',
#   '가',
#   '있었지만',
#   '색다른',
#   '시도',
#   '가',
#   '좋았다',
#   '.'],
#  ['이건', '또', '뭐임', '이', '거뭐', '중국영화', '임', '?'],
#  ['리얼리티', '감동'],
#  ['자각', '과', '깨달음', '의', '무서움', '!!'],
#  ['재미있네요', '커플', '들', '끼리', '보면', '좋을거', '같네요', '^^'],
#  ['원주율', '좀', '만들어', '보자', '.,.,'],
#  ['아주', '썩어', '빠진', '영화'],
#  ['료코', '짱'],
#  ['결국', '종', '을', '울리는', '구나', '...'],
#  ['헐', '...', '죄송합니다', '이건', '아니', '네', '여'],
#  ['옼', '케이', '앟', '~', '드르륵', '손', '으로', '싹', '싹', '~', '킁', '~'],
#  ['재미있고', '흥미진진', '함', '강', '추합니다', '!'],
#  ['보면서', '상당히', '당황', '했던', '....'],
#  ['뼈채', '먹을', '코', '메디'],
#  ['난', '진짜', '재밌게', '봤어요', '신세경', '연기', '가', '약간', '좀', '그랬지만'],
#  ['무엇', '보다도', '발연기', '가', '영화', '집중', '하는데', '큰', '방해', '요소', '였다', '-_-'],
#  ['섬세함을', '요하', '는', '영화', '인데', '섬세함이', '없는', '영화', ';;'],
#  ['얍얍', '콩', '나와라', '뚝딱', '!!!'],
#  ['이렇게',
#   '단순한',
#   '이야기',
#   '를',
#   '지루하게',
#   '2시간',
#   '이나',
#   '넘게',
#   '찍은',
#   '것',
#   '도',
#   '참',
#   '한심함',
#   '.',
#   '사무라이',
#   '를',
#   '욕먹이는',
#   '영화'],
#  ['남매',
#   '는',
#   '그런게',
#   '아닐까',
#   '?',
#   '때로는',
#   '엄마',
#   '같은',
#   '누나',
#   ',',
#   '때로는',
#   '오빠',
#   '같은',
#   '동생',
#   ',',
#   '잔잔함',
#   '그리고',
#   '일본',
#   '특',
#   '유의',
#   '소박함이',
#   '묻어나는',
#   '따스한',
#   '영화',
#   '.'],
#  ['마지막', '윌', '이', '아들', '을', '향', '해', '소리치는건', '정말', '기억', '에', '남습니다', '.'],
#  ['아', '진짜', '재밌게', '봤습니다', '♥♥'],
#  ['개인',
#   '적',
#   '평점',
#   '은',
#   '6',
#   '점',
#   '이지만',
#   '좋은',
#   '원작',
#   '과',
#   '배우',
#   '들',
#   '로',
#   '영화',
#   '를',
#   '이따위',
#   '로',
#   '만든',
#   '죄',
#   '가',
#   '더',
#   '크다',
#   '결정',
#   '적',
#   '인',
#   '건',
#   '벨아미',
#   '란',
#   '제목',
#   '처',
#   '첨',
#   '로버트패틴슨',
#   '이',
#   '아름다운',
#   '남자',
#   '로',
#   '보이지',
#   '도',
#   '않았다'],
#  ['흠',
#   '...',
#   '관객',
#   '들',
#   '가지',
#   '고',
#   '노',
#   '는',
#   '건가',
#   '?',
#   '상영',
#   '도',
#   '안',
#   '하는데',
#   '..'],
#  ['황추생',
#   '이랑',
#   '오진우',
#   '의',
#   '엄청난',
#   '악역',
#   '연기',
#   '가',
#   '막장',
#   '스토리',
#   '에',
#   '묻혀',
#   '버려서',
#   '아쉬운',
#   '작품',
#   '..'],
#  ['일본인',
#   '팼다',
#   '뭐',
#   '그런',
#   '걸',
#   '떠나서',
#   '웬만하면',
#   '중국영화',
#   '는',
#   '평점',
#   '높게',
#   '안',
#   '주는데',
#   '괜찮은',
#   '영화인',
#   '듯'],
#  ['나도', '다큐', '나', '찍어', '볼까'],
#  ['이딴', '걸', '방송', '이라고', '쳐', '만들', '엇', '나', 'ㅋ', '욕', '만', '나오네', 'ㅗ'],
#  ['보는',
#   '내내',
#   '가슴',
#   '이',
#   '아팠지만',
#   '이',
#   '게',
#   '현실',
#   '이라는',
#   '게',
#   '참으로',
#   '속상했습니다',
#   '.'],
#  ['기대', '된디'],
#  ['정준', '용씨', '연기', '넘', '멋져용', '!!!'],
#  ['캐롤',
#   '의',
#   '첫사랑',
#   '이라는',
#   '제목',
#   '으로',
#   '일본',
#   '에서',
#   '개봉',
#   '했죠',
#   '...',
#   '괜찮은',
#   '영화',
#   '입니다',
#   '..'],
#  ['디카프리오', '는', '진리', '다', '미친', '연기력', '에', '빠져들었다'],
#  ['감독', '을', '마파도', '로', '보내고', '싶다', '.'],
#  ['잔잔하고',
#   '짧지만',
#   '감동',
#   '은',
#   '확실하네요',
#   '.',
#   '엄마',
#   '에',
#   '대해',
#   '생각',
#   '할',
#   '수',
#   '있는',
#   '기회',
#   '였어요',
#   '.'],
#  ['저희',
#   '엄마',
#   '도',
#   '재밌다고',
#   '하고',
#   '곰',
#   '도',
#   '귀엽고',
#   '웃기면서',
#   '감동',
#   '적이네요',
#   '추천',
#   '합니다'],
#  ['진심', '핵', '노잼', '감독', '의', '역량', '을', '따져', '볼', '필요성', '을', '느끼는', '영화'],
#  ['이건', '정말', '명작', '이네', '요'],
#  ['6월', '6일', '현충일', '.', '감사합니다', '.'],
#  ['다람쥐', '들', '이', '귀', '여울', '뿐', '아무', '것', '도', '없다'],
#  ['저',
#   '한테',
#   '황금',
#   '시간',
#   '인',
#   '밤',
#   '10시',
#   '에',
#   '지상파',
#   '가',
#   '아니',
#   '케이블',
#   '보게',
#   '만들었어요',
#   '..',
#   '정말',
#   '대단함',
#   'ㅎㅎ',
#   '그녀',
#   '의',
#   '신화',
#   '너무',
#   '재밌',
#   'ㅇ',
#   '어요',
#   '..',
#   '한',
#   '회',
#   '한',
#   '회볼때',
#   '마다',
#   '지루하지',
#   '않고',
#   '시간',
#   '가는줄',
#   '모르겠어요',
#   '~',
#   '지상파',
#   '면',
#   '완전',
#   '대박',
#   '인데',
#   '아쉽네요',
#   '..',
#   'ㅠㅠㅠ'],
#  ['역시', '명작', '~', '최고', '입니다'],
#  ['농담', '따먹기', '수준', '도', '안', '된다'],
#  ['진짜',
#   '한번',
#   '더보',
#   '고',
#   '싶은',
#   '영화',
#   '입니다',
#   '콩코드기',
#   '가',
#   '나오는',
#   '영화',
#   '인데',
#   '....',
#   '끝',
#   '장면',
#   '이',
#   '참',
#   '안타까운',
#   '영화',
#   '이지',
#   '요'],
#  ['그', '시', '대', '그', '시절', '의', '청춘', '상', '.', '아련하고', '우습고', '짠하다'],
#  ['못', '해도', '8', '점', '은', '되야지', '7', '점', '은', '아닌듯'],
#  ['이', '영화', '를', '보기', '전', '으로', '돌아가고', '싶어요'],
#  ['꿀잼', '허니', '잼', '포도', '잼', '딸기', '잼'],
#  ['생각나서', '들렀는데', '평점', '왜', '이렇지', '....'],
#  ['청리',
#   '중국사람',
#   '입니다',
#   '.',
#   '청리',
#   '를',
#   '보조',
#   '하는',
#   '애가',
#   '한국',
#   '마크',
#   '달',
#   '고',
#   '잇',
#   '엇',
#   '지'],
#  ['이렇게', '멋진', '영화', '를', '이제', '서', '보다니', '..'],
#  ['교육',
#   '이',
#   '무너진',
#   '근본',
#   '적',
#   '인',
#   '원인',
#   '에',
#   '대해',
#   '잘',
#   '보여준',
#   '영화',
#   '...',
#   '어른',
#   '들',
#   '의',
#   '과오',
#   ',',
#   '부모',
#   '와',
#   '사회',
#   '의',
#   '몰락',
#   '이',
#   '순수한',
#   '아이',
#   '들',
#   '의',
#   '행동',
#   '들',
#   '로',
#   '보여지는',
#   '것'],
#  ['좀더', '재미있게', '만들면', '..'],
#  ['혼자',
#   '보기',
#   '에는',
#   '정말',
#   '좋은',
#   '영화',
#   '임',
#   '^^',
#   '나름',
#   '작품',
#   '이해',
#   '하려',
#   '노력',
#   '하고',
#   '심취',
#   '하니',
#   '재밌더라고요'],
#  ['이상하다', '나카타', '감독', '링', '은', '잘', '만들었는데', '이건', '왠지', '...;;.'],
#  ['재미', '만', '있구만', 'ㅋ', '뭔', '작품', '성', '따지고', '보냐', 'ㅋㅋ'],
#  ['존내', '멋', '잇어', 'ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ'],
#  ['이',
#   '영화',
#   '는',
#   '진짜',
#   '아름다운',
#   '영화',
#   '다',
#   '이렇게',
#   '아름다운',
#   '영화',
#   '를',
#   '만들수',
#   '있다는것에',
#   '놀랐다'],
#  ['슈퍼맨', '死', '-', '최악', '의', '편', '.'],
#  ['공유', '보려고', '보는', '영화'],
#  ['약간',
#   '아쉬운면도',
#   '없지',
#   '않았지만',
#   '제',
#   '기',
#   '대',
#   '이상',
#   '이었습니다',
#   '배우',
#   '들',
#   '의',
#   '연기',
#   '가',
#   '너무',
#   '좋아서',
#   '특히',
#   '마이',
#   '한테',
#   '감정이입',
#   '이',
#   '저절로',
#   '되드라구',
#   '요',
#   '잘',
#   '봤습니다',
#   '!'],
#  ['어렸을',
#   '때',
#   '봤을',
#   '때',
#   '영화',
#   '속',
#   '인어',
#   '속',
#   '꼬리',
#   '가',
#   '너무나',
#   '신비롭게',
#   '보였던',
#   '.'],
#  ['여기', '나오는', '아줌마', '들', '다', '귀', '여', '움', '^^..', '끝', '까지', '..'],
#  ['깡패',
#   '같은',
#   '세상',
#   '깡',
#   '으로',
#   '뭘',
#   '버텨',
#   '?',
#   '연출',
#   '이',
#   '깡패',
#   '다',
#   '갈래',
#   '가',
#   '뭐',
#   '냐',
#   '삼계탕',
#   '조금',
#   '먹고',
#   '후라이드',
#   '한',
#   '입',
#   '먹고',
#   '삼겹살',
#   '먹는',
#   '식이',
#   '다'],
#  ['진짜', '소름', '이', '돋는다'],
#  ['이도영', '오빠', '화이팅', '!', '힝', '상응', '원해요'],
#  ['지하실',
#   '에',
#   '갖혀서',
#   '속',
#   '고사',
#   '는',
#   '건',
#   '어쩌면',
#   ',',
#   '우리',
#   '일지',
#   '도',
#   '몰라',
#   '.'],
#  ['간만', '에', '쓰레기', '영', '화보', '네', '요', 'ㅋ'],
#  ['완전',
#   '잼있네요',
#   'ㅋㅋ',
#   '근데',
#   '이',
#   '거',
#   '2',
#   '편',
#   '을',
#   '계획',
#   '하고',
#   '끝낸거',
#   '같은데',
#   '....',
#   '2',
#   '편',
#   '은',
#   '어찌',
#   '...?;;',
#   'ㅜㅡ'],
#  ['이건', '1', '점도', '아까운', '영화', '.'],
#  ['밀양',
#   '성폭행',
#   '가해자',
#   '들',
#   '이',
#   '부디',
#   '지옥',
#   '깊숙히',
#   '떨어지',
#   '기를',
#   '기원',
#   '합니다',
#   '^^'],
#  ['뭥미', '?', '헐', '~'],
#  ['Wow',
#   '~!',
#   '멋진',
#   '반전',
#   '!!!!',
#   '온',
#   '몸',
#   '에',
#   '전율',
#   '이',
#   '흐르는',
#   '영화',
#   '!!!!'],
#  ['너무',
#   ',,,',
#   '당황',
#   ',',
#   '비',
#   '때문',
#   '에',
#   '봤지만',
#   '너무',
#   '몰상식해서',
#   '다',
#   '안',
#   '봤다',
#   '.'],
#  ['최고', '의', '사랑', '을', '느끼게', '해준', '영화'],
#  ['리암',
#   '니',
#   '슨',
#   '형',
#   '엄청',
#   '고생',
#   '하면서',
#   '찍었는데',
#   '영화',
#   '자체',
#   '는',
#   '드럽게',
#   '잼없드',
#   '라',
#   '.'],
#  ['너무', '재밌게', '봤어요', '...'],
#  ['학생',
#   '(',
#   '중',
#   '~',
#   '대',
#   ')',
#   '절때',
#   '로',
#   '보지말',
#   '껏',
#   ',',
#   '어린',
#   '아들',
#   '캐',
#   '초딩',
#   '들',
#   '만',
#   '관람',
#   '할',
#   '껏'],
#  ['영화', '내공', '향상', '을', '위해', '이를', '악물고', '..', '감내해', '야할', '성', '장통'],
#  ['쓰레기', 'ㅡㅡ'],
#  ['맨', '땅', '에', '시청률'],
#  ['개인',
#   '적',
#   '점수',
#   '는',
#   '9',
#   '점',
#   '.',
#   '김희선',
#   '의',
#   '재',
#   '발견',
#   '에',
#   '+',
#   '1',
#   '점',
#   '.',
#   '합',
#   '이',
#   '10',
#   '점',
#   '.',
#   '취향',
#   '을',
#   '탈거',
#   '같으면서도',
#   '의외로',
#   '누구',
#   '나',
#   '빠져드는',
#   '영화',
#   '.'],
#  ['로버트',
#   '드니',
#   '로',
#   '+',
#   '알파',
#   '치노',
#   '=',
#   '명화',
#   '.',
#   'bacause',
#   'she',
#   'got',
#   'a',
#   'great',
#   'ass',
#   '!!',
#   'ㅋㅋㅋㅋ'],
#  ['짜고치는', '고스톱', '에', '마지막', '장면', '진짜', '허무함', '.', 'ㅡㅡ'],
#  ['코믹', '호러', '용치', '고', '수작', '인데', '평점', '너무', '낮다'],
#  ['영화',
#   '대박',
#   '!!!!!!',
#   '노래',
#   '도',
#   '너무',
#   '좋고',
#   '무엇',
#   '보다',
#   '항상',
#   '열심히',
#   '하는',
#   '모습',
#   '이',
#   '너무',
#   '좋아요',
#   '.'],
#  ['지루하다가',
#   '결말',
#   '은',
#   '어이없이',
#   '허무하게',
#   '끝남',
#   ',,',
#   '극장',
#   '에서',
#   '안',
#   '봐도',
#   '될',
#   '영화',
#   ',',
#   '그리고',
#   '굳이',
#   '안',
#   '봐도',
#   '될',
#   '영화'],
#  ['킹오파', '영화', '랑', '이', '거', '랑', '비교', '해봐라', '이', '게', '훨씬', '명작', '이다'],
#  ['등장인물', '외오고', '봐야', '할', '영화', '지만', '스토리', '는', '완벽합니다', '.'],
#  ['세상', '에는', '보이는것보다', '보이지', '않는것이', '더', '많다'],
#  ['정말',
#   '역사',
#   '에',
#   '남',
#   '을',
#   '만',
#   '한',
#   '소름끼치는',
#   '작품',
#   '인데',
#   '평점',
#   '은',
#   '양',
#   '아치',
#   '조폭',
#   '형사',
#   '살인',
#   '범',
#   '쳐',
#   '나오는',
#   '몇몇',
#   '한국영',
#   '화',
#   '따위',
#   '보다도',
#   '낮네',
#   '?',
#   '안타깝다',
#   '안타까워',
#   '!!'],
#  ['중학교',
#   '시절',
#   '재',
#   '밋게봣',
#   '엇',
#   '는데',
#   '요',
#   '새',
#   '다시',
#   '생각',
#   '이나',
#   '서',
#   '찾아보니',
#   '감회',
#   '가',
#   '새',
#   '롭고',
#   '또',
#   '재밌네요',
#   '조금',
#   '만',
#   '더있음',
#   '10년',
#   '전',
#   '영화',
#   '임',
#   '에도',
#   '촌스럽다는',
#   '느낌',
#   '이적',
#   '네',
#   '요',
#   '궁',
#   '2',
#   '가',
#   '나오길',
#   '그렇게',
#   '바랫',
#   '건만',
#   '갑자기',
#   '또',
#   '아쉬운',
#   '생각',
#   '이드',
#   '네',
#   '요'],
#  ['액션',
#   '이',
#   '대단했습니다',
#   '..',
#   '몰입',
#   '감도',
#   '좋았구요',
#   '..',
#   '개인',
#   '적',
#   '으로',
#   '아저씨',
#   '의',
#   '원빈',
#   '보다',
#   '멋있었네요',
#   ';;',
#   '더',
#   '고생',
#   '한',
#   '거',
#   '같구요',
#   '..'],
#  ['에이', '모야'],
#  ['아름다운', '감동', '.', '실화', '에', '기초', '했다니', '놀라', '움'],
#  ['진짜',
#   '머',
#   '하자는거냐',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '좀비',
#   '영화',
#   '보고',
#   '악플',
#   '처음',
#   'ㄱ',
#   'ㅐ',
#   '재미',
#   '업다',
#   '진짜',
#   '로'],
#  ['가족', '과', '같은', '느낌', '을', '주는', '영화', '^^'],
#  ['이', '시리즈', '가', '3', '까지', '나오넥', '기적', '이다'],
#  ['그렇게', '대단하지', '않다'],
#  ['씁쓸한',
#   '것',
#   '같지만',
#   '뭔가',
#   '깊은',
#   '여운',
#   '이',
#   '남았다',
#   '.',
#   '물론',
#   '스웨덴',
#   '의',
#   '분위기',
#   '는',
#   '쫓아가지',
#   '못',
#   '했지만',
#   '재밌게',
#   '봤다',
#   '.',
#   '클로이',
#   '사랑',
#   '함',
#   '흐헬'],
#  ['얼굴', '시꺼먼게', '먼', '죄', '냥', '....'],
#  ['<',
#   '진심',
#   '>',
#   '이란',
#   '게',
#   '어떤',
#   '건지',
#   '제대로',
#   '보여주는',
#   '영화',
#   '.',
#   '98%',
#   '가',
#   '이슬람교',
#   '인',
#   '<',
#   '이란',
#   '>',
#   '이기',
#   '에',
#   '더',
#   '절묘해진',
#   '영화',
#   '.'],
#  ['감독', '은', '원작', '을', '보았는지', '의문', '스럽다'],
#  ['4000원', '보다', '아까운건', '120분', '의', '시간', '이다'],
#  ['아래', '평점', '에', '속', '았', '다', '...'],
# ...
#   '희망',
#   '가족',
#   '과',
#   '함께',
#   '지금',
#   '현재',
#   '우리',
#   '의',
#   '삶',
#   '의',
#   '감사함을',
#   '느끼게',
#   '한다',
#   '.',
#   '잊혀져',
#   '가는',
#   '기',
#   '부문',
#   '화',
#   '가',
#   '다시',
#   '회복',
#   '되길',
#   '바랍니다',
#   '.~'],
#  ['클레멘타인', '7', '광구', '그리고', 'r', '2', 'b'],
#  ['Hugh',
#   'Grant',
#   '-',
#   'Don',
#   "'",
#   't',
#   'Write',
#   'Me',
#   'Off',
#   ',',
#   'Hugh',
#   'Grant',
#   '&',
#   'Haley',
#   'Bennett',
#   '-',
#   'Way',
#   'Back',
#   'Into',
#   'Love',
#   '....',
#   '乃'],
#  ['별로', '같은', '뎅', '..'],
#  ['매', '순간', '최선', '을', '.', '그런다면', '내게도', '최상', '의', '결과', '가', '생길지도', '!'],
#  ['역시', '충분히', '재밌음', '.'],
#  ['정말',
#   '무서운',
#   '영화',
#   '다',
#   '감독',
#   '이',
#   '무섭고',
#   '진짜',
#   '무서운',
#   '반전',
#   '은',
#   '2',
#   '편이',
#   '나올까봐',
#   '무섭다',
#   '오',
#   '인천',
#   '감독',
#   '은',
#   '세계',
#   '적',
#   '거장',
#   '우베',
#   '볼',
#   '을',
#   '잇는',
#   '진정',
#   '한국',
#   '의',
#   '우베',
#   '볼',
#   '이다'],
#  ['사랑',
#   '하는',
#   '사람과',
#   '함께',
#   '늙을수',
#   '없는것',
#   '그것',
#   '이',
#   '주인공',
#   '에게',
#   '내려진',
#   '저주',
#   '이다'],
#  ['재밌는데', '평점', '이', '과소', '하여', '10', '점'],
#  ['말로', '표현', '못', '함', 'ㄷㄷ', '진짜'],
#  ['뭔가',
#   '역',
#   '동',
#   '적',
#   '인',
#   '씬',
#   '없이',
#   '잔잔하게',
#   '흘러가도',
#   '묵직한',
#   '분위기',
#   '로',
#   '보는',
#   '이를',
#   '장악',
#   '함',
#   '.',
#   '김기덕',
#   '감독',
#   '영화',
#   '처음',
#   '보는데',
#   '잘',
#   '만들었다는',
#   '생각',
#   '이',
#   '절로',
#   '들었다',
#   '.'],
#  ['마음', '이', '따뜻해', '지는', '영화', '.'],
#  ['성유리', ',', '정겨운', ',', '김민준', '등', '정말', '재밌게', '연기', '잘하네요', '..'],
#  ['정말',
#   '막장',
#   '...',
#   '그렇게',
#   '당',
#   '하고도',
#   '지네',
#   '작업실',
#   '문',
#   '절대',
#   '안',
#   '잠그고',
#   '맨날',
#   '도난',
#   '당',
#   '하고',
#   '..',
#   '초등학생',
#   '애',
#   '들',
#   '도',
#   '이러게',
#   '망청',
#   '한',
#   '짓',
#   '들',
#   '은',
#   '안',
#   '하겠다',
#   '.',
#   '짜증나서',
#   '다시는',
#   '안',
#   '볼꺼',
#   '임',
#   '..'],
#  ['정신',
#   '줄',
#   '놓고',
#   '만들',
#   '엇',
#   '나',
#   '?',
#   '줄거리',
#   '에',
#   '수꼴',
#   '이란',
#   '말',
#   '이',
#   '나오네',
#   '거기',
#   '다',
#   '할아버지',
#   '를',
#   '죽여',
#   '?',
#   '좌빨',
#   '들',
#   '의',
#   '인민재판',
#   '엔',
#   '가족',
#   '도',
#   '나이',
#   '도',
#   '없다는거',
#   '광고',
#   '하는',
#   '영',
#   '화구',
#   '나',
#   '북한',
#   '에',
#   '보내라',
#   '.',
#   '김정은',
#   '좋아하겟다'],
#  ['시리즈', '물', '영화', '중', '최고', '캐리비안', '의', '해적', '~'],
#  ['어수선하고',
#   '뭘',
#   '말',
#   '하고자',
#   '하는지',
#   '모르겠고',
#   ',',
#   '그냥',
#   '감옥',
#   '에서',
#   '일어나는',
#   '오',
#   '바',
#   '소동',
#   '들',
#   '오렌지',
#   '이즈',
#   '더',
#   '뉴',
#   '블랙',
#   '하고',
#   '비슷하지만',
#   ',',
#   '재미',
#   '는',
#   '반도',
#   '못',
#   '따라감'],
#  ['뚱보흑', '인', '사무라이', '라', '...', '-_-;;', '말', '이', '안', '나왔다', '.'],
#  ['지루한', '앞', '부분', '허무한', '뒷', '부분'],
#  ['취향', '의', '차이', '를', '확인', '하다', '.'],
#  ['대학',
#   '등록금',
#   '이랑',
#   '몸',
#   '파는',
#   '거',
#   '랑',
#   '무슨',
#   '의미',
#   '가',
#   '있다는',
#   '건지',
#   '?',
#   '돈',
#   '이',
#   '없으면',
#   '대학',
#   '안',
#   '가면',
#   '되는',
#   '거고',
#   '꼭',
#   '가고싶으면',
#   '노동',
#   '을',
#   '해서',
#   '정당하게',
#   '돈',
#   '을',
#   '벌면',
#   '되는거지',
#   '몸',
#   '파는걸',
#   '정당화',
#   '시킬려고',
#   '하네',
#   'ㅋㅋ',
#   '저런',
#   '인간',
#   '들',
#   '이',
#   '지',
#   '능력',
#   '은',
#   '인정',
#   '못',
#   '하고',
#   '주변',
#   '환경',
#   '탓',
#   '하',
#   '거나',
#   '신',
#   '세',
#   '타령',
#   '만',
#   '늘어놓지'],
#  ['평점',
#   '4',
#   '점',
#   '대',
#   '감안',
#   '해봐서',
#   '기',
#   '대안',
#   '하고',
#   '봤는데',
#   '기대',
#   '이하',
#   '를',
#   '보여주는',
#   '영화',
#   '..',
#   'ㅅㅅ',
#   '씬',
#   '은',
#   '필요없어',
#   '보이는데',
#   '왜',
#   '넣',
#   '엇',
#   '지'],
#  ['강', '시숙', '숙', '(', '강시선생', '4', ')', '이', '제일', '재미', '잇음'],
#  ['너무', '잘', '봤음', '....', '눈물', '이', 'ㅠ'],
#  ['양심', '없는', '서', '퉁', '의', '울', '궈', '먹기', '는', '이제', '그만'],
#  ['영화',
#   '라고',
#   '쓴',
#   '분',
#   '들',
#   '옆',
#   '에',
#   '다큐멘터리',
#   '라',
#   '쓰인건',
#   '안',
#   '보이시나',
#   '봐요',
#   '^^;'],
#  ['너무',
#   '저',
#   '평가',
#   '된',
#   '영화',
#   '.',
#   '뭘',
#   '더',
#   '바라는가',
#   '?',
#   '정말',
#   '잘빠졌다',
#   '.',
#   '보는',
#   '내내',
#   '황홀하고',
#   '우아한',
#   '에스',
#   '피오',
#   '나지',
#   '영화',
#   '의',
#   '모범',
#   '!'],
#  ['주연',
#   '여배우',
#   '..',
#   '연기',
#   '를',
#   '보면',
#   '겁',
#   '을',
#   '먹은',
#   '건지',
#   '그냥',
#   '아무',
#   '생각',
#   '이',
#   '없는',
#   '건지'],
#  ['마지막',
#   '에',
#   '!',
#   '이제껏',
#   '엮',
#   '인',
#   '실',
#   '타레가',
#   '시원하게',
#   '풀리는것',
#   '같은',
#   '느낌',
#   '!!'],
#  ['명작',
#   '...',
#   '액션',
#   '이',
#   '면서',
#   '가볍지',
#   '안아서',
#   '좋다',
#   '..',
#   '액션',
#   '도',
#   '좋고',
#   '..'],
#  ['♥'],
#  ['미루다', '미루다가', '이제', '봤네요', '볼', '만', '합니다', '.'],
#  ['로버트',
#   '다우니',
#   '주니어',
#   '의',
#   '연기',
#   '에',
#   '다시',
#   '한번',
#   '놀란',
#   '작품',
#   '이었고',
#   '오랜',
#   '만',
#   '에',
#   '깊은',
#   '여운',
#   '이',
#   '남는듯',
#   '한',
#   '작품',
#   '을',
#   '만난거',
#   '같아',
#   '반가웠다'],
#  ['팔레스타인', '의', '고뇌', '하지만', '좀', '이념', '영화', '같은면'],
#  ['보다가',
#   '열',
#   '받아서',
#   '죽',
#   '을',
#   '가능성',
#   '이',
#   '매우',
#   '높으니',
#   '심장',
#   '이',
#   '안',
#   '좋으면',
#   '삼',
#   '가할',
#   '것',
#   '.'],
#  ['징그럽게',
#   '꾸준히도',
#   '나오는',
#   '파라',
#   '노말',
#   '시리즈',
#   '...',
#   '허',
#   '접',
#   '한',
#   '스토리',
#   '에',
#   '어색한',
#   '연기',
#   '...',
#   '패러디',
#   '물',
#   '로',
#   '만들었으면',
#   '그나마',
#   '나았을',
#   '것',
#   '을',
#   '...'],
#  ['결말',
#   '이',
#   '예상',
#   '되는',
#   '영화',
#   '지만',
#   '재밌네요',
#   '!',
#   '웃음',
#   '도',
#   '났다가',
#   '울음',
#   '도',
#   '났다가',
#   '합니다'],
#  ['멋지다', '조문탁', '!'],
#  ['놀라운건',
#   '감독',
#   ',',
#   '음악',
#   ',',
#   '연출',
#   '모두',
#   '주걸륜',
#   '이',
#   '만들었다는거',
#   '..',
#   '헐',
#   '천재',
#   '였네'],
#  ['비',
#   '이',
#   '성적',
#   '신념',
#   '의',
#   '광기',
#   '.',
#   '권위',
#   '에',
#   '대한',
#   '집착',
#   '.',
#   '자신',
#   '의',
#   '결정',
#   '으로',
#   '인해',
#   '발생',
#   '한',
#   '포',
#   '클',
#   '랜드',
#   '사건',
#   '을',
#   '자신',
#   '의',
#   '재정',
#   '축소',
#   '정책',
#   '을',
#   '뒤집으며',
#   '처리',
#   '하는',
#   '집착',
#   '.',
#   '영국',
#   '의',
#   '스탈린',
#   '이군',
#   '.'],
#  ['장혁', '진짜', '...', '개', '소름', '..', '여운', '이', '너무', '길었음'],
#  ['소문',
#   '만',
#   '듣다가',
#   '직접',
#   '보니',
#   '이정',
#   '도일',
#   '줄',
#   '은',
#   '...',
#   '극장',
#   '서',
#   '본',
#   '분들',
#   '내',
#   '상이',
#   '심할',
#   '듯'],
#  ['좋은', '소재', '와', '탄탄하지', '못', '한', '스토리'],
#  ['심혜진', '은', '이제', '역사', '의', '뒤안길', '로', '사라지고', '있다', '.'],
#  ['아니',
#   '이딴',
#   '걸',
#   '...',
#   '영화',
#   '채널',
#   '에선',
#   '왜',
#   '자꾸',
#   '틀어주지',
#   '...',
#   '암',
#   '걸리게',
#   '할려고',
#   '작정',
#   '했나',
#   '...'],
#  ['유료',
#   '보기',
#   '로',
#   '사천원',
#   '내고',
#   '봤지만',
#   ',',
#   '어지간한',
#   '영화',
#   '만원',
#   '짜리',
#   '보다',
#   'ㅎ',
#   '훨씬',
#   '유익한',
#   '시간',
#   '이었다',
#   '.'],
#  ['좋다'],
#  ['별', '시리', '감동', '은', '없는데', '..', '전도연', '아직', '예쁘단', '생각', '뿐', 'ㅋㅋ'],
#  ['아무', '생각', '없이', '막', '찍어', '대고', '편집', '으로', '이야기', '만들어내는', '감독'],
#  ['정말',
#   '이런',
#   '영화',
#   '만들지',
#   '마세요',
#   '...',
#   '감동',
#   '을',
#   '주든',
#   ',',
#   '재미',
#   '를',
#   '주든',
#   ',',
#   '교훈',
#   '을',
#   '주든',
#   ',',
#   '감정',
#   '을',
#   '주든',
#   '...',
#   '영화',
#   '의',
#   '목적',
#   '이',
#   '전혀',
#   '없는',
#   '그냥',
#   '싸이코',
#   '영화로',
#   '봤습니다',
#   '.',
#   '이글',
#   '보고',
#   '감독',
#   '님',
#   '이',
#   '상처',
#   '받을',
#   '수도',
#   '있을까',
#   '도',
#   '생각',
#   '하는데',
#   '감독',
#   '님',
#   '상처',
#   '좀',
#   '받아야',
#   '합니다',
#   '...'],
#  ['평점', '이', '누가', '보면', '초', '걸작', '인', '줄', '알겠다', '..', '재밌기는', '재밌었음'],
#  ['어찌', '보면', '단순한', '러브스토리', '기도', '하지만', ',', '감동', '이', '있네요', '~'],
#  ['아버지', '의', '사랑', '..', '멋지다', '..'],
#  ['이건', '뭘', '까요', '?'],
#  ['어른',
#   '들',
#   '모',
#   '다',
#   '아이',
#   '들',
#   '이',
#   '더',
#   '많이',
#   '등장',
#   '해서',
#   '더',
#   '재밌는것',
#   '같다',
#   '.'],
#  ['어설픈', '택시', '드라이버', '아', '류', '영화', '.'],
#  ['정말',
#   '뻔한',
#   '반전',
#   '아닌가',
#   '?',
#   '송윤아',
#   '의',
#   '영화',
#   '불운',
#   '은',
#   '어디',
#   '까지',
#   '일까',
#   '?'],
#  ['진짜', '사랑', '이란', '건', '이런', '것', '일테지', '.'],
#  ['삶',
#   '의',
#   '이유',
#   '라는',
#   '너무나',
#   '큰',
#   '주제',
#   '를',
#   '다루려고',
#   '했는데',
#   '영화',
#   '가',
#   '전혀',
#   '이를',
#   '따라가지',
#   '못',
#   '합니다',
#   '.',
#   '즉',
#   ',',
#   '전혀',
#   '영화',
#   '에',
#   '공감',
#   '이',
#   '안되더군요',
#   '.',
#   '대사',
#   ',',
#   '주인공',
#   '들',
#   '각자',
#   '의',
#   '개',
#   '인사',
#   '들',
#   '을',
#   '보여주는데',
#   '있어',
#   '모두',
#   '겉',
#   '돌고',
#   '있고',
#   '자연',
#   '스럽게',
#   '인도',
#   '에',
#   '녹',
#   '아들',
#   '지',
#   '못',
#   '합니다',
#   '.',
#   '아쉽고',
#   '안타깝습니다',
#   '.'],
#  ['기대했던', '만큼', '재밍', '있었습니다'],
#  ['염정', '화', '억지로', '벗게', '했는다는', '영화', '군', '..', '감독', '이', '변탠', '가'],
#  ['어이', '없어요', '.', '내용', '이', '너무', '하네요'],
#  ['저', '평가', '된', '007'],
#  ['다큐',
#   '형식',
#   '이지만',
#   '끝',
#   '까지',
#   '지루하지',
#   '않고',
#   '재미있다',
#   '.',
#   '마음',
#   '은',
#   '쓸쓸하지만',
#   '.',
#   '인생',
#   '이',
#   '꼭',
#   '해피앤드',
#   '란',
#   '보장',
#   '은',
#   '없으니까',
#   '.'],
#  ['tv', '전', '기세', '가', '아깝다', '!!!'],
#  ['뭐', '냐', '이', '게'],
#  ['월리스',
#   '와',
#   '그루밋때',
#   '부터',
#   '팬',
#   '이',
#   '여서',
#   '...',
#   '시리즈',
#   '라',
#   '생각',
#   '해',
#   '보았으나',
#   '난',
#   '이',
#   '스토리',
#   '를',
#   '즐',
#   '기기',
#   '엔',
#   '너무',
#   '늙어',
#   '버렸다',
#   '.',
#   '명절',
#   '날',
#   '조카',
#   '가',
#   '틀어놓으면',
#   '전부',
#   '치',
#   '며',
#   '볼듯',
#   '!',
#   '성인',
#   '들',
#   '이',
#   '볼',
#   '극',
#   '장용',
#   '무비',
#   '는',
#   '아님'],
#  ['재난영화', '길래', '봤더니', '자동차', '광고', '영화', '인줄', ',,,'],
#  ['이건', '좀', '심했다', '겁나', '재미없음', 'ㅡㅡ'],
#  ['최고', '.', '영화', '를', '안', '본', '사람', '은', '절대', '이해', '못', '할', '감격', '.'],
#  ['만',
#   '개',
#   '한',
#   '꽃',
#   '보다는',
#   '피어나려는',
#   '꽃봉오리',
#   '를',
#   ',',
#   '분별',
#   '있는',
#   '성인',
#   '보다는',
#   '청소년',
#   '이',
#   '멋있을',
#   '수',
#   '있다'],
#  ['토끼', '귀여워요', '!!!'],
#  ['각각',
#   '의',
#   '삶',
#   '속',
#   '에',
#   '흐르는',
#   '시간',
#   '에',
#   '대한',
#   ',',
#   '머리',
#   '로는',
#   '이해',
#   '못',
#   '할',
#   '독특한',
#   '이야기',
#   '.'],
#  ['오죽하면',
#   '이',
#   '시대',
#   '에',
#   '이',
#   '영화',
#   'DVD',
#   '조차',
#   '안',
#   '나왔다면',
#   '할',
#   '말',
#   '다',
#   '했지',
#   '.'],
#  ['그냥', '친구', '가', '되는', '줄', '알았는데', '반전', '있는', '결말', ';;;'],
#  ['조', '쉬', '하트넷', '너무', '귀엽다', '..', 'ㅋㅋ', '계속', '웃으면서', '본', '영화'],
#  ['이서진', '의', '최악', '의', '영화', '랄', '까', 'ㅋㅋㅋ'],
#  ['마음', '이', '정화', '되는', '느낌', '이다', '.', '최고'],
#  ['인생', '을', '살아가는데', '지표', '가', '될만', '한', '메시지', '를', '전', '해준다', '.'],
#  ['바이러스', '성', '연쇄살인범', '이라는', '소재', '를', '진부하게', '이끌어', '나갔음'],
#  ['어덜트', '비디오', '용'],
#  ['보는',
#   '순간',
#   '마다',
#   '푹',
#   '빠져서',
#   '재밌게',
#   '봤습니다',
#   '.',
#   '감사합니다',
#   '.',
#   '영화',
#   '를',
#   '다',
#   '보고',
#   '철수',
#   '가',
#   '불쌍하단',
#   '생각',
#   '이',
#   '들었지만',
#   '철수',
#   '가',
#   '행복해',
#   '보이니',
#   '그',
#   '걸',
#   '로',
#   '된거',
#   '겠죠',
#   '.'],
#  ['시작', '은', '있으나', '끝', '이', '없다', '.'],
#  ['쓰레기', '는', '쓰레기통', '으로'],
#  ['이런', '소름끼치는', '명작', '을', '이제', '서야', '보다니', '이제', '까지', '영화', '헛봤다', '!'],
#  ['음악', '영', '상미', '둘다', '최고', '감동', '까지', 'ㅠ', '.', 'ㅠ'],
#  ['자기', '색깔', '을', '내려는', '시도', '는', '있으나', '방향성', '이', '없다'],
#  ['이', '흥행', '보증', '배우', '로', '망한', '영화', '.'],
#  ['진짜', '재미없는', '드라마', '!'],
#  ['sf', '가', '지루한면도', '있는거지', '그러면', '니', '들', '이', '영화', '를', '만들던가'],
#  ['이', '게', '어떻게', '6', '점', '이', '넘는지', '이해', '가', '...'],
#  ['난이',
#   '드라마',
#   '세번',
#   '봤음',
#   '내',
#   '생애',
#   '최고',
#   '의',
#   '드라마',
#   '.',
#   '짱',
#   '임',
#   '!!',
#   '이런',
#   '드라마',
#   '또',
#   '나왔음',
#   '좋겠다',
#   '.'],
#  ['니', '네', '문학', '반', '만', '따라가', '봐라'],
#  ['나름', '재미있네요', 'ㅎ'],
#  ['재미있어요'],
#  ['무거우면서도',
#   '유쾌하게',
#   '인상',
#   '깊은',
#   '영화',
#   '입니다',
#   '.',
#   '전수진',
#   ',',
#   '이은우',
#   '두',
#   '배우',
#   '연기',
#   '가',
#   '대단합니다'],
#  ['3.5',
#   '/',
#   '줄거리',
#   '는',
#   '3',
#   '류',
#   '에',
#   ',',
#   '개연',
#   '성도',
#   '없고',
#   ',',
#   '감동',
#   '도',
#   '없고',
#   '...',
#   '가장',
#   '문제',
#   '는',
#   '지루하다는',
#   '것',
#   '...'],
#  ['밤', '에', '잠', '않', '올', '때', '보는', '영화로', '추천', '합니다'],
#  ['디카프리오', ',', '끝'],
#  ['MMORPG',
#   '즐기지',
#   '않는',
#   '사람',
#   '에게는',
#   '주석',
#   '을',
#   '달',
#   '아',
#   '달란',
#   '말',
#   '이다',
#   '.'],
#  ['그렇게', '나', '는', '시간', '을', '낭비했다', '...-_=;'],
#  ['베네딕트', '컴버배치', '는', '목소리', '만으로', '압도', '함', '!!'],
#  ['지루하고', '선정', '적', '이고', '당황', '스럽다'],
#  ['지루하고',
#   '따분하고',
#   '특별한',
#   '느낌',
#   '도',
#   '없고',
#   '.',
#   '괜히',
#   '목',
#   '에',
#   '힘',
#   '만',
#   '준',
#   '영화',
#   '.',
#   '나도',
#   '영화광',
#   '이지만',
#   '이',
#   '영화',
#   '에',
#   '대한',
#   '평론가',
#   '들',
#   '높은',
#   '평점',
#   '은',
#   '공감',
#   '이',
#   '전혀',
#   '안된다',
#   '.'],
#  ['김동완',
#   '은',
#   '보이지',
#   '않고',
#   '이육사만',
#   '보였다',
#   ';',
#   '누구',
#   '나오는지',
#   '안보',
#   '고',
#   '봤더니',
#   '김동완',
#   '인',
#   '줄',
#   '도',
#   '모르고',
#   '봤음',
#   ';;',
#   '완전',
#   '딴사람',
#   '인',
#   '줄',
#   ';',
#   '진짜',
#   '이육사',
#   '같았음',
#   '..'],
#  ['최근',
#   '에',
#   '심심해서',
#   '지식인',
#   '돌아보다가',
#   '우연',
#   '하게',
#   '알',
#   '게',
#   '되서',
#   '봤습니다',
#   '.',
#   '재밌네요'],
#  ['타짜',
#   '는',
#   '10',
#   '점',
#   '받아',
#   '마땅하다',
#   '.',
#   '영화',
#   '의',
#   '모든',
#   '부분',
#   '이다',
#   '재밌었다',
#   '.',
#   '캐릭터',
#   '들',
#   '은',
#   '원작',
#   '보다',
#   '훨씬',
#   '더',
#   '매력',
#   '적',
#   '으로',
#   '재현',
#   '됐고',
#   ',',
#   '단역',
#   '까지',
#   '모든',
#   '캐릭터',
#   '가',
#   '제',
#   '몫',
#   '을',
#   '했다',
#   '.',
#   '긴이야',
#   '기를아주',
#   '딱',
#   '맞게',
#   '압축',
#   '했다',
#   '.',
#   '전국',
#   '중',
#   '고딩',
#   '에게',
#   '섯다',
#   '열풍',
#   '을',
#   '몰',
#   '고온',
#   ',',
#   '막판',
#   '고니',
#   '와',
#   '아귀',
#   '의',
#   '설전',
#   '을',
#   '전',
#   '국민',
#   '이',
#   '외우게',
#   '만든',
#   '작품',
#   '.',
#   '영화사',
#   '에',
#   '남',
#   '을',
#   '장면',
#   '들',
#   '이',
#   '가득',
#   '담겨있는',
#   '선물',
#   '세트'],
#  ['대놓고', '코미디', '가', '아닌', '은근', '히', '웃기는게', '재밌었어요', 'ㅋㅋ'],
#  ['더', '이상', '자세한', '설명', '은', '생략', '한다', '.'],
#  ['시간', '잘', '때웠', '습', '니당'],
#  ['악당',
#   '삼',
#   '인',
#   '방',
#   '에서',
#   '조',
#   '드',
#   '장군',
#   '하고',
#   '여자',
#   '가',
#   '매력',
#   '적',
#   '..',
#   '찾아보니',
#   '브이',
#   '에도',
#   '나왔었네'],
#  ['왜',
#   '이런',
#   '감동',
#   '적이면서도',
#   '쩌',
#   '는',
#   '명품',
#   '애니',
#   '가',
#   "'",
#   '8',
#   "'",
#   '점',
#   '대',
#   '??'],
#  ['내',
#   '가',
#   '본',
#   '성룡',
#   '영화',
#   '중',
#   '최고',
#   '였지만',
#   '주연',
#   '은',
#   '홍금보',
#   '외',
#   '5',
#   '명',
#   '이었다',
#   '.'],
#  ['러브', '라인', '은', '이', '제', '그만', '내용', '팍팍', '나가자구', '용', '지루해져요'],
#  ['명작', '이', '될', '수도', '있었던', '영화'],
#  ['정말', '재미있어요', 'ㅇㅇㅇ', '굿'],
#  ['왜캐', '평점', '높음', '쓰레기', '임'],
#  ['이지현', '의', '육체', '에', '뿅', '간', '여균동', '..', 'ㅋ'],
#  ['원래',
#   '10',
#   '점',
#   '잘안주는데',
#   '너무',
#   '뭉클하고',
#   '감동',
#   '적',
#   '인',
#   '스토리',
#   '에',
#   '엄청',
#   '울었습니다',
#   '꼭',
#   '봐',
#   '야하는',
#   '영화',
#   '!!',
#   '★'],
#  ['50년',
#   '대에',
#   '이런',
#   '연출',
#   '이',
#   '가능하다니',
#   '어떤',
#   '경지',
#   '를',
#   '보는',
#   '것',
#   '같다',
#   '.',
#   '시대',
#   '를',
#   '역행',
#   '한',
#   '작품'],
#  ['역사',
#   '적',
#   '인',
#   '부분',
#   '도',
#   '굉장히',
#   '중요하지만',
#   '정치',
#   '적',
#   '인',
#   '부분',
#   '싫으신',
#   '분',
#   '들',
#   '도',
#   '가족',
#   '애',
#   '라는',
#   '큰',
#   '주제가',
#   '있기',
#   '때문',
#   '에',
#   '그',
#   '누구',
#   '든지',
#   '보셔도',
#   '좋은',
#   '영화',
#   '입니다',
#   '.'],
#  ['정말', '마음', '이', '따뜻해지는', '영화', '네', '요', '재미있었어요', '진', '이씨', '멋있었어요', 'ㅋ'],
#  ['모든', '모습', '은', '이', '안', '에', '일부', '가', '스며들어있다', '.'],
#  ['감독',
#   '리들리',
#   '스콧',
#   '과',
#   '주연',
#   '러셀',
#   '크로우',
#   '는',
#   '각각',
#   '의',
#   '역할',
#   '에',
#   '미스',
#   '캐스팅',
#   '이고',
#   ',',
#   '허세',
#   '가득하고',
#   '공감',
#   '되지',
#   '않는',
#   '이야기',
#   '는',
#   '처음',
#   '부터',
#   '끝',
#   '까지',
#   '진부해서',
#   '지루하다',
#   '.'],
#  ['진짜진짜',
#   '보다보다',
#   '이렇게',
#   '지겨운',
#   '만화',
#   '첨',
#   '입니다',
#   '딸램',
#   '보여주려',
#   '갔',
#   '더',
#   '만',
#   '헉',
#   '포스터',
#   '사기',
#   '입니다',
#   '포스터',
#   '색감',
#   '이라도',
#   '되면',
#   '좋으려',
#   '만시',
#   '커',
#   '한',
#   '바다',
#   '우울한',
#   '대',
#   '사',
#   '더빙',
#   '엉망',
#   '임',
#   '이렇게',
#   '재미없을수있나요',
#   '극장',
#   '서',
#   '중간',
#   '애',
#   '들',
#   '이',
#   '졸리다고',
#   '난리',
#   'ㅡㅡ'],
#  ['총',
#   '을',
#   '쏘았다는데',
#   '총알',
#   '이',
#   '없어',
#   '.',
#   '탄피',
#   '도',
#   '없어',
#   '.',
#   '다쳤는데',
#   '왜',
#   '다쳤는지를',
#   '모르겠네',
#   '.',
#   '개',
#   '법부',
#   '를',
#   '엎',
#   '어',
#   '버려야지',
#   '원'],
#  ['오',
#   ',',
#   '의외로',
#   '스토리',
#   '가',
#   '탄탄한데요',
#   '?',
#   '저',
#   '도',
#   '통',
#   '크게',
#   '10',
#   '점',
#   '드립니다',
#   '^^'],
#  ['창작', '의', '괴로움', '이', '이리', '돋보이리', '랴', '!'],
#  ['오래전', '에', '본', '영화', '인데', '도', '지금', '도', '유효한', '놀라운', '메시지', '!!!'],
#  ['물론', '만화', '같기는', '했지만', '첫', '번째', '액션씬', '이', '계속', '머리', '에', '남는다'],
#  ['흠', '...', '테이큰', '보다', '이', '거', '보니', '드럽게', '재미없네', '.'],
#  ['복수',
#   '라는',
#   '타이틀',
#   '을',
#   '달지말던가',
#   '.',
#   '복수',
#   '영화',
#   '.',
#   '느와르',
#   '영화',
#   '에서는',
#   '최소한',
#   '의',
#   '규칙',
#   '이',
#   '있어',
#   '.',
#   '전개',
#   '스타일',
#   '.',
#   '슬로우',
#   '느낌',
#   '.',
#   '다',
#   '좋다고',
#   '근데',
#   '말',
#   '야',
#   '복수',
#   '가',
#   '복수',
#   '다',
#   '워',
#   '야',
#   '지',
#   '.',
#   '뭐',
#   '냐',
#   '고',
#   '원숭이',
#   '같이',
#   '생긴',
#   '싸이코패스',
#   '경찰서',
#   '장이',
#   '주인공',
#   '이네',
#   '.',
#   '복수',
#   '를',
#   '해야',
#   '할',
#   '라이언',
#   '고',
#   '슬링',
#   '은',
#   '허',
#   '접때',
#   '기',
#   '로나',
#   '오네'],
#  ['진국', '시나리오'],
#  ['킬링타임', '용', '으론', '상당한', '수작'],
#  ['일본', '가', '이런', '말', '할', '자격', '이', '잇나', '?'],
#  ['잼있구만',
#   '~',
#   '여배우',
#   '이쁘구',
#   '~',
#   '평점',
#   '보고',
#   '안',
#   '봤으면',
#   '후회',
#   '했겠다',
#   '..',
#   '네이버',
#   '평점',
#   '은',
#   '믿을게',
#   '안데'],
#  ['세',
#   '아들',
#   '의',
#   '비참한',
#   '결과',
#   '의',
#   '근본',
#   '은',
#   '아버지',
#   '의',
#   '악',
#   '(',
#   '정욕',
#   '등',
#   ')',
#   '으로',
#   '인했다',
#   '.',
#   '그러나',
#   '세',
#   '아들',
#   '과',
#   '중국인',
#   '조차도',
#   '각자',
#   '마다',
#   '이',
#   '악한',
#   '세상',
#   '가운데',
#   '쉼을',
#   '얻을',
#   '수',
#   '있는',
#   '엄마',
#   '의',
#   '품',
#   '을',
#   '가장',
#   '그리워',
#   '할',
#   '것',
#   '이다',
#   '.'],
#  ['정말', '감동', '받았어요', 'ㅠㅠㅠ', '이건', '꼭', '봐야되', '요', '!!!'],
#  ['와우', '저', '펜'],
#  ['1시간',
#   '30분',
#   '정도의',
#   '시간',
#   '을',
#   '버린',
#   '기분',
#   '로버트',
#   '패틴슨',
#   '의',
#   '연기력',
#   '만은',
#   '훌륭하다',
#   '.'],
#  ['소재', '빼고', '전부', '엉망', '진창', '.'],
#  ['야웅', '~', '잼있겠다', '옹', '~~'],
#  ['재미있게', '봤어', '~', '어렸지만', '사랑', '에', '희생', '정신', '이', '좋았어', '~~'],
#  ['이', '정도', '면', '봐줄만', '하다'],
#  ['샘', '라일', '리', '.', '아름답다', '.'],
#  ['스토리',
#   '도',
#   '좋고',
#   ',',
#   '캐스팅',
#   '도',
#   '괜찮았고',
#   '..',
#   '정말',
#   '좋은',
#   '드라마',
#   '^^',
#   '이승기',
#   '한효주',
#   '씨',
#   '최고',
#   '였음'],
#  ...]

# %%
# 2. tfidfvectorizer 속성에 저장된 토큰들 넣기
from sklearn.feature_extraction.text import TfidfVectorizer
test_vectorizer = TfidfVectorizer(tokenizer=loaded_tokenized_data)
clean_texts = ['아 더빙 진짜 짜증나네요 목소리',
 '원작의 긴장감을 제대로 살려내지못했다',
 '울면서 손들고 횡단보도 건널때 뛰쳐나올뻔 이범수 연기 드럽게못해',
 '이건 정말 깨알 캐스팅과 질퍽하지않은 산뜻한 내용구성이 잘 버무러진 깨알일드',
 '주제는 좋은데 중반부터 지루하다']

# 3. vectorizer도 저장된 토큰에 fit_transform하고 저장
# X = test_vectorizer.fit_transform(clean_texts)

# 그러면 모델학습 테스트 데이터
# 1. 테스트 데이터들 okt().morphs 토큰화를 먼저하고
# 2. 불러온 vectorizer객체에 transform()해서 model.predict에 넣기

# %%
test_vectorizer.get_feature_names_out
# Out:
# <bound method CountVectorizer.get_feature_names_out of TfidfVectorizer(tokenizer=[['아', '더빙', '..', '진짜', '짜증나네요', '목소리'],
#                            ['원작', '의', '긴장감', '을', '제대로', '살려내지못', '했다', '.'],
#                            ['울면', '서', '손', '들', '고', '횡단보도', '건널', '때', '뛰',
#                             '쳐나', '올', '뻔', '이범수', '연기', '드럽게', '못', '해'],
#                            ['이건', '정말', '깨알', '캐스팅', '과', '질퍽', '하', '지', '않은',
#                             '산뜻한', '내', '용구성', '이', '잘', '버무러진', '깨알', '일드',
#                             '!!', '♥'],
#                            ['주제', '는', '좋은데', '중반', '부터', '지루하다'],
#                            ['엄포스', '의', '위력', '을', '다시', '한번', '깨닫게...
#                             '안', '섞인', '채', '짬뽕', '그릇', '에', '담겨있다', '.'],
#                            ['재미있다고', '허풍', '떨지', '마세요'],
#                            ['그만', '좀', '끌', '고', '이제', '끝내', '라', '.', '지겹다',
#                             '지겨워', '.'],
#                            ['배우', '들', '은', '지네', '들', '안', '뜨니까', '이런', '영화',
#                             '찍을껀데', '???', '왜', '안', '뜨는지', '진짜', '모르는거야', '?',
#                             '면상', '딱', '보면', '알겠구만', '...', '왜', '지네', '자신',
#                             '들', '은', '모를까', '?'],
#                            ['오랜', '만', '에', '재밋', '는', '영화', '봤네요'],
#                            ['소파', '에', '죽', '치고', '앉아', '지켜', '볼', '이유', '가',
#                             '없는', '작품', '.'],
#                            ['알바', '는', '꺼', '저', '라'], ...])>

# %%
# df_train.iloc[:,0]
from konlpy.tag import Okt

#문장을 토큰화한것만 따로 저장
# tokenized_data =[]

# for i in df_train.iloc[:,0]:
#     tokenized_data.append(Okt().morphs( i ))

# %%
import pickle

#토근화된 데이터를 저장하였음
# with open('tokenized_data.pkl','wb') as f:
#     pickle.dump(tokenized_data,f)

#토큰화된 데이터 불러오기
# with open('tokenized_data.pkl','rb') as f:
#     tokenized_data_loaded = pickle.load(f)

# tokenized_data_loaded

# %%
#라벨별로 분리해본것
bad = df_train[df_train.iloc[:,1]==0]
good = df_train[df_train.iloc[:,1]==1]


df_train = df_train[::4]

from sklearn.feature_extraction.text import TfidfVectorizer
from konlpy.tag import Okt

vectorizer=TfidfVectorizer(tokenizer=Okt().morphs)
X = vectorizer.fit_transform( df_train.iloc[:,0])
y = df_train.iloc[:,1]
# Out:
# c:\Users\uk246\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_extraction\text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
df_train[df_train.iloc[:,1]==0]  #18678 
df_train[df_train.iloc[:,1]==1]  #18822
df_train.shape
# Out:
# (37500, 2)

# %%
# 토큰화하고 빈도수(tfidf)에 기반한 벡터표현이 생성된 X를 따로저장
from scipy.sparse import save_npz ,load_npz

#vectorizer.fit_transform한것을 희소행렬로로 저장
# save_npz('37500개_vectorized_data.npz', X)

#저장된 희소행렬을 불러오기
# X_loaded = load_npz('37500개_vectorized_data.npz')

#이렇게 불러온 X_loaded는 바로 모델학습에 사용가능

# %%
import numpy as np
X_train_dense = np.expand_dims( X.toarray(), axis=-1 )
# X_train_dense.shape
# X_loaded.shape[1]
# X_loaded.toarray().shape[1]

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization , Input, Dropout
# from tensorflow.keras import Input
# 모델 구성deep nueral network
# input_layer = Input(shape=(X_loaded.shape[1],), sparse=True)

#flatten 사용하는것 알아보기

model = Sequential([
    # input_layer,
    Input(shape=(X_train_dense.shape[1],)),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.6),
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dropout(0.6),
    Dense(1, activation='sigmoid')
])

# 모델 컴파일 및 학습
model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])

# model.fit(X.toarray(), y, epochs = 10, batch_size = 500, validation_split=0.2)  #0.8417
model.fit(X.toarray(), y, epochs = 10, batch_size = 20, validation_split=0.3)  #0.8417
# Out:
# c:\Users\uk246\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\data_adapter.py:1696: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   return t[start:end]
# Epoch 1/10
# 1313/1313 [==============================] - 44s 30ms/step - loss: 0.5788 - accuracy: 0.7039 - val_loss: 0.4331 - val_accuracy: 0.8047
# Epoch 2/10
# 1313/1313 [==============================] - 30s 23ms/step - loss: 0.4476 - accuracy: 0.7979 - val_loss: 0.4013 - val_accuracy: 0.8164
# Epoch 3/10
# 1313/1313 [==============================] - 28s 22ms/step - loss: 0.4056 - accuracy: 0.8261 - val_loss: 0.3935 - val_accuracy: 0.8208
# Epoch 4/10
# 1313/1313 [==============================] - 29s 22ms/step - loss: 0.3737 - accuracy: 0.8421 - val_loss: 0.3940 - val_accuracy: 0.8219
# Epoch 5/10
# 1313/1313 [==============================] - 26s 20ms/step - loss: 0.3584 - accuracy: 0.8526 - val_loss: 0.4147 - val_accuracy: 0.8083
# Epoch 6/10
# 1313/1313 [==============================] - 29s 22ms/step - loss: 0.3678 - accuracy: 0.8474 - val_loss: 0.3993 - val_accuracy: 0.8182
# Epoch 7/10
# 1313/1313 [==============================] - 29s 22ms/step - loss: 0.3398 - accuracy: 0.8645 - val_loss: 0.4036 - val_accuracy: 0.8241
# Epoch 8/10
# 1313/1313 [==============================] - 30s 23ms/step - loss: 0.3055 - accuracy: 0.8827 - val_loss: 0.4139 - val_accuracy: 0.8140
# Epoch 9/10
# 1313/1313 [==============================] - 31s 24ms/step - loss: 0.3097 - accuracy: 0.8781 - val_loss: 0.4271 - val_accuracy: 0.8140
# Epoch 10/10
# 1313/1313 [==============================] - 31s 23ms/step - loss: 0.2938 - accuracy: 0.8865 - val_loss: 0.4177 - val_accuracy: 0.8185

# %%
test = ['정말 별로 입니다. 이게뭐니']

# 학습된 TF-IDF 벡터라이저로 테스트 데이터 변환
X_test_sample = vectorizer.transform(test)
X_test_sample_dense = X_test_sample.toarray()

# 모델을 사용하여 예측 수행
predictions = model.predict(X_test_sample_dense)
print(predictions)

# 예측 결과 출력 (긍정: 1, 부정: 0)
print("예측 결과:", np.round( predictions ).astype(int))
# Out:
# 1/1 [==============================] - 0s 464ms/step
# [[0.03403642]]
# 예측 결과: [[0]]

# %% [markdown]
# 닉네임기준으로
# 카톡대화내용을 기준으로 테스트 문장을 여러개 불러와서 예측 후 그 값의 비율을 계산 출력해준다.

# %%
# model.save('기본 DNN 적용모델.h5')
