# %%
#코랩 실행시 주석해체
# !pip install tokenizers
# !pip install transformers
# !pip install konlpy
# !pip install soynlp

# %% [markdown]
# 모델_2
# 메켑미적용 => 워드피스토큰화 => (커스텀레이어 추가된)가벼운 BERT모델 적용
#
# ==마디별 워드피스 토큰화==

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import re
from soynlp.normalizer import repeat_normalize
from sklearn.feature_extraction.text import TfidfVectorizer
import pickle
from collections import Counter

#필요없는 경고무시
import warnings
warnings.filterwarnings('ignore')

#시각화용 임포트 모음
import matplotlib.pyplot as plt
import seaborn as sns
from plotly import graph_objs as go

# %%
#한국어 감성사전 불러온다.
with open('../SentiWord_Dict.txt', 'r', encoding='utf-8') as f:
    SentiWord_Dict = f.read()


#데이터 프레임 생성
df_train = pd.DataFrame({
    'Sentiword': [line.split('\t')[0] for line in SentiWord_Dict.split('\n') if len(line.split('\t')) >= 2],
    'Point': [int(line.split('\t')[1]) for line in SentiWord_Dict.split('\n') if len(line.split('\t')) >= 2]
})


#널값있는지 확인
empty_string_exists = any(list(map(lambda x, y: x == "" or y == "", df_train['Sentiword'], df_train['Point'])))

if empty_string_exists:
    print("널값이 존재합니다.")
    df_train[{'Sentiword','Point'}].replace('', np.nan, inplace=True)
    df_train.dropna( inplace=True)
    print("널값 제거하였습니다.")
else:
    print("널값이 없습니다.")
# Out:
# 널값이 없습니다.

# %%
df_train
# Out:
#       Sentiword  Point
# 0           (-;      1
# 1         (;_;)     -1
# 2          (^^)      1
# 3         (^-^)      1
# 4          (^^*      1
# ...         ...    ...
# 14851     내팽개치다     -2
# 14852        횡령     -2
# 14853       불안증     -2
# 14854      어쩔티비     -1
# 14855         ?      1
#
# [14856 rows x 2 columns]

# %%
#메켑 토큰화
from konlpy.tag import Mecab
mecab = Mecab(dicpath=r'C:/mecab/mecab-ko-dic/')

df_train['Sentiword'] = df_train['Sentiword'].apply(lambda x : mecab.morphs(x))
# Out:
#        Sentiword  Point
# 0        [(, -;]      1
# 1      [(, ;_;)]     -1
# 2       [(, ^^)]      1
# 3      [(, ^-^)]      1
# 4       [(, ^^*]      1
# ...          ...    ...
# 14851  [내팽개치, 다]     -2
# 14852       [횡령]     -2
# 14853      [불안증]     -2
# 14854   [어쩔, 티비]     -1
# 14855        [?]      1
#
# [14856 rows x 2 columns]

# %%
df_train [:20]
# Out:
#           Sentiword  Point
# 0           [(, -;]      1
# 1         [(, ;_;)]     -1
# 2          [(, ^^)]      1
# 3         [(, ^-^)]      1
# 4          [(, ^^*]      1
# 5         [(, ^_^)]      1
# 6         [(, ^_^;]     -1
# 7     [(, ^, o, ^)]      1
# 8         [(, -_-)]     -1
# 9   [(, T, _, T, )]     -1
# 10       [(, ㅡㅡ, )]     -1
# 11          [), -:]     -1
# 12           [*^^*]      1
# 13    [/, ^, o, ^\]      1
# 14           [:, (]      1
# 15         [:, '-(]      1
# 16          [:, -(]      1
# 17           [:, )]     -1
# 18          [:, -)]      1
# 19           [:, /]     -1

# %%
# 감성 단어 길이 분포 확인
print('리뷰의 최대 길이 :',max(len(review) for review in df_train['Sentiword']))
print('리뷰의 평균 길이 :',sum(map(len, df_train['Sentiword']))/len(df_train['Sentiword']))
plt.hist([len(review) for review in df_train['Sentiword']], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()

max_length = max(len(review) for review in df_train['Sentiword'])
# Out:
# 리뷰의 최대 길이 : 16
# 리뷰의 평균 길이 : 3.1712439418416802

# %% [markdown]
# word piece시작

# %%
from transformers import BertTokenizerFast, AlbertModel
tokenizer = BertTokenizerFast.from_pretrained("kykim/albert-kor-base")
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'AlbertTokenizerFast'.
# The class this function is called from is 'BertTokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'AlbertTokenizerFast'.
# The class this function is called from is 'BertTokenizerFast'.

# %%
# # WordPiece 토큰화를 위한 사전 훈련된 모델 불러오기
# from transformers import BertTokenizer
# tokenizer = BertTokenizer.from_pretrained('klue/bert-base')

# %%
(df_train['Sentiword'].tolist())
# Out:
# [['(', '-;'],
#  ['(', ';_;)'],
#  ['(', '^^)'],
#  ['(', '^-^)'],
#  ['(', '^^*'],
#  ['(', '^_^)'],
#  ['(', '^_^;'],
#  ['(', '^', 'o', '^)'],
#  ['(', '-_-)'],
#  ['(', 'T', '_', 'T', ')'],
#  ['(', 'ㅡㅡ', ')'],
#  [')', '-:'],
#  ['*^^*'],
#  ['/', '^', 'o', '^\\'],
#  [':', '('],
#  [':', "'-("],
#  [':', '-('],
#  [':', ')'],
#  [':', '-)'],
#  [':', '/'],
#  [':', '|'],
#  [':', 'D'],
#  [':', '-', 'D'],
#  [':', 'p'],
#  [':', '-', 'P'],
#  [';'],
#  [';)'],
#  [';-)'],
#  [';', 'ㅅ', ';'],
#  ['^///^'],
#  ['^^'],
#  ['^^//'],
#  ['^-^;'],
#  ['^-^;;'],
#  ['^-^;;;;;'],
#  ['-_-^'],
#  ['<', '3'],
#  ['=)'],
#  ['8', '-)'],
#  ['B', '-)'],
#  ['XD'],
#  ['ㄱ', 'ㅅ'],
#  ['ㄱ', 'ㅇㄷ'],
#  ['가격', '이', '싸', '다'],
#  ['가까스로'],
#  ['가까이', '사귀', '어'],
#  ['가까이', '하', '다'],
#  ['가꾸', '러', '뜨리', '다'],
#  ['가꾸', '러', '트', '리다'],
#  ['가난'],
#  ['가난뱅이'],
#  ['가난살이'],
#  ['가난살이', '하', '다'],
#  ['가난', '설음'],
#  ['가난', '에'],
#  ['가난', '에', '쪼', '들려서'],
#  ['가난', '하', '게'],
#  ['가난', '하', '고'],
#  ['가난', '하', '고', '어렵', '다'],
#  ['가난', '하', '고', '천한'],
#  ['가난', '하', '다'],
#  ['가난', '하', '여'],
#  ['가난', '한'],
#  ['가난', '한', '데', '다가'],
#  ['가난', '한', '사람', '을'],
#  ['가난히'],
#  ['가년', '스럽', '다'],
#  ['가', '념', '하', '다'],
#  ['가녕', '스럽', '다'],
#  ['가누', '기', '어려워하', '다'],
#  ['가누', '지', '못하', '고'],
#  ['가누', '지', '못하', '다'],
#  ['가누', '지', '못할'],
#  ['가누', '지', '못할', '정도', '로'],
#  ['가누', '지', '못함'],
#  ['가눌', '수', '없', '게'],
#  ['가눌', '수', '없', '을'],
#  ['가눌', '수', '없이'],
#  ['가능', '성', '이', '늘어나', '다'],
#  ['가능', '성', '이', '있', '다고'],
#  ['가능', '하', '다'],
#  ['가닐가닐', '하', '다'],
#  ['가다듬', '어'],
#  ['가다듬', '어', '수습', '하', '는'],
#  ['가다듬', '어', '수습', '하', '다'],
#  ['가다듬', '어', '정하', '다'],
#  ['가당찮', '다'],
#  ['가당찮이'],
#  ['가당히'],
#  ['가두', '거나'],
#  ['가두', '거나', '해치', '거나'],
#  ['가드', '올려'],
#  ['가뜬', '하', '게'],
#  ['가라앉', '다'],
#  ['가라앉', '지', '않', '은'],
#  ['가라앉혀', '바로잡', '다'],
#  ['가래'],
#  ['가래', '따위', '가'],
#  ['가래', '가'],
#  ['가래', '가', '섞인'],
#  ['가량', '맞', '고'],
#  ['가량', '맞', '고', '야살', '스러운'],
#  ['가량', '맞', '고', '야살', '스러움'],
#  ['가려서', '좋', '아', '하', '다'],
#  ['가려운'],
#  ['가려운', '느낌', '이'],
#  ['가려운', '증상', '을'],
#  ['가련', '하', '게'],
#  ['가련', '하', '게', '여기', '다'],
#  ['가련', '하', '게', '여김'],
#  ['가련', '한'],
#  ['가련', '한', '듯', '하', '다'],
#  ['가렵', '고'],
#  ['가로막', '아서'],
#  ['가로채', '서'],
#  ['가로채', '어'],
#  ['가르치', '며'],
#  ['가르침'],
#  ['가르침', '을', '받', '아'],
#  ['가리', '지', '못하', '다'],
#  ['가리', '지', '않', '고'],
#  ['가마득', '하', '다'],
#  ['가만', '있', '지', '못하', '고'],
#  ['가망', '없', '는'],
#  ['가망', '이', '없', '게'],
#  ['가벼운', '마음', '으로'],
#  ['가벼운', '말', '이나'],
#  ['가벼운', '상처'],
#  ['가벼운', '슬픔'],
#  ['가벼운', '행동', '으로'],
#  ['가볍', '게'],
#  ['가볍', '게', '까부', '는'],
#  ['가볍', '게', '까불', '다'],
#  ['가볍', '게', '쑤시', '듯'],
#  ['가볍', '게', '웃', '다'],
#  ['가볍', '게', '채신없이'],
#  ['가볍', '게', '행동', '하', '거나'],
#  ['가볍', '게', '행동', '하', '는'],
#  ['가볍', '게', '행동', '하', '다'],
#  ['가볍', '고'],
#  ['가볍', '고', '보드랍', '게'],
#  ['가볍', '고', '상쾌', '하', '다'],
#  ['가볍', '고', '상쾌', '한'],
#  ['가볍', '고', '시원', '하', '게'],
#  ['가볍', '고', '편안', '하', '게'],
#  ['가볍', '고', '환하', '게'],
#  ['가분가분'],
#  ['가분히'],
#  ['가뿐가뿐'],
#  ['가뿐가뿐', '하', '다'],
#  ['가뿐가뿐히'],
#  ['가뿐', '하', '게'],
#  ['가뿐', '하', '다'],
#  ['가뿐', '한'],
#  ['가뿐', '한', '느낌'],
#  ['가뿐', '한', '느낌', '이'],
#  ['가뿐히'],
#  ['가쁘', '게'],
#  ['가쁘', '게', '쉬', '다'],
#  ['가쁘', '고'],
#  ['가쁘', '고', '거칠', '게'],
#  ['가쁘', '고', '급하', '게'],
#  ['가쁜'],
#  ['가쁜', '증상'],
#  ['가살', '스럽', '다'],
#  ['가소', '롭', '게'],
#  ['가소', '롭', '다'],
#  ['가스', '중독', '이나'],
#  ['가슴', '아파하', '다'],
#  ['가슴', '아파', '함'],
#  ['가슴', '아프', '게'],
#  ['가슴', '아프', '고'],
#  ['가슴', '아프', '다'],
#  ['가슴', '속', '에', '근심', '이나'],
#  ['가슴앓이'],
#  ['가슴앓이', '하', '다'],
#  ['가슴', '이', '갑갑', '할'],
#  ['가슴', '이', '괴롭', '거나'],
#  ['가슴', '이', '그득', '한'],
#  ['가슴', '이', '답답', '하', '고'],
#  ['가슴', '이', '답답', '하', '다'],
#  ['가슴', '이', '답답', '하', '며'],
#  ['가슴', '이', '답답', '하', '여'],
#  ['가슴', '이', '답답', '한'],
#  ['가슴', '이', '답답', '해진다'],
#  ['가슴', '이', '아프', '다'],
#  ['가슴', '이', '아픈'],
#  ['가슴', '이', '울렁거리', '는'],
#  ['가슴', '이', '울렁거리', '다'],
#  ['가슴', '이', '찢어질'],
#  ['가습', '이', '답답', '하', '고'],
#  ['가엽', '다'],
#  ['가엾', '게'],
#  ['가엾', '게', '여겨'],
#  ['가엾', '게', '여기', '다'],
#  ['가엾', '고'],
#  ['가엾', '고', '불쌍', '하', '다'],
#  ['가엾', '고', '불쌍', '하', '여'],
#  ['가엾', '고', '불쌍', '한'],
#  ['가엾', '고', '불쌍', '함'],
#  ['가엾', '고', '애처', '롭', '다'],
#  ['가엾', '다'],
#  ['가운데', '에서', '뛰어남'],
#  ['가위눌리', '다'],
#  ['가음', '아프', '고'],
#  ['가장', '거룩', '한'],
#  ['가장', '뛰어나'],
#  ['가장', '뛰어난'],
#  ['가장', '올바르', '게'],
#  ['가장', '좋', '은'],
#  ['가장', '중요', '한'],
#  ['가증', '맞', '다'],
#  ['가증', '스럽', '다'],
#  ['가지런', '하', '게', '하', '는'],
#  ['가지런', '하', '게', '하', '다'],
#  ['가지런', '하', '다'],
#  ['가지런', '하', '지', '아니하', '다'],
#  ['가지런', '하', '지', '아니한'],
#  ['가짜'],
#  ['가책', '이', '되', '어'],
#  ['가치'],
#  ['가치', '없', '는'],
#  ['가치', '있', '는'],
#  ['가치', '있', '다'],
#  ['가치', '가'],
#  ['가치', '가', '없', '다'],
#  ['가치', '가', '없', '을'],
#  ['가치', '가', '없이'],
#  ['가치', '가', '있', '다'],
#  ['가치', '를', '믿', '다'],
#  ['가치', '를', '인정', '하', '다'],
#  ['가치', '보다', '비싼'],
#  ['가치', '없', '는'],
#  ['가치', '있', '는'],
#  ['가치작', '거리', '는'],
#  ['가치작', '거리', '는', '모양'],
#  ['가치작', '거리', '는', '소리'],
#  ['가탈', '스럽', '다'],
#  ['가혹', '하', '게'],
#  ['가혹', '하', '게', '착취', '하', '여'],
#  ['각근', '하', '지', '못하', '여'],
#  ['각별나', '다'],
#  ['각별', '하', '다'],
#  ['간', '장애'],
#  ['간', '질', '환의'],
#  ['간드러진'],
#  ['간드러진', '느낌', '이'],
#  ['간사', '스럽', '게'],
#  ['간사', '스럽', '게', '행동', '하', '는'],
#  ['간사', '스럽', '게', '행동', '하', '다'],
#  ['간사', '하', '고'],
#  ['간사', '하', '다'],
#  ['간사', '한'],
#  ['간사', '한', '사람', '이나'],
#  ['간사', '한', '짓', '을'],
#  ['간섭', '받', '고'],
#  ['간섭', '하', '거나'],
#  ['간섭', '하', '거나', '방해', '하', '여'],
#  ['간섭', '하', '고'],
#  ['간섭', '하', '다'],
#  ['간섭', '하', '여'],
#  ['간신히', '짜내', '는'],
#  ['간절', '하', '다'],
#  ['간지러워서'],
#  ['간지럽', '게'],
#  ['간지럽', '고'],
#  ['간지럽', '고', '자릿', '한'],
#  ['간직', '하', '다'],
#  ['간직', '하', '지', '아니하', '고'],
#  ['간질'],
#  ['간질간질', '하', '다'],
#  ['간질간질', '한'],
#  ['간질간질', '한', '느낌'],
#  ['간편', '하', '거나'],
#  ['간편', '하', '다'],
#  ['갈강병', '균', '이'],
#  ['갈라서', '다'],
#  ['갈라지', '는', '피부병'],
#  ['갈색굳음병'],
#  ['갈증', '이', '나', '고'],
#  ['갈증', '이', '심하', '게'],
#  ['갈팡질팡'],
#  ['갈팡질팡', '하', '다'],
#  ['갈팡질팡', '하', '며'],
#  ['갈피', '를', '잡', '을', '수', '없', '다'],
#  ['갈피', '를', '잡', '지', '못하', '고'],
#  ['갈피', '를', '잡', '지', '못하', '고', '이리저리', '헤매', '는', '모양'],
#  ['갈피', '를', '잡', '지', '못하', '는'],
#  ['갈피', '를', '잡', '지', '못하', '다'],
#  ['감각', '이', '둔하', '고'],
#  ['감각', '이', '마비', '되', '고'],
#  ['감각', '적', '이', '다'],
#  ['감감히'],
#  ['감개무량', '하', '다'],
#  ['감격'],
#  ['감격성'],
#  ['감격', '스럽', '다'],
#  ['감격', '스레'],
#  ['감격', '이'],
#  ['감격', '적'],
#  ['감격', '하', '다'],
#  ['감격', '하', '여'],
#  ['감금', '하', '여'],
#  ['감기'],
#  ['감기', '가'],
#  ['감기', '가', '들', '어'],
#  ['감기', '나'],
#  ['감기', '나', '천식'],
#  ['감기', '로'],
#  ['감기', '로', '인하', '여'],
#  ['감당', '하', '다'],
#  ['감동'],
#  ['감동', '시킬'],
#  ['감동', '시킬', '만', '한'],
#  ['감동', '을', '받', '아'],
#  ['감동', '을', '일으킬'],
#  ['감동', '을', '주', '거나'],
#  ['감동', '이'],
#  ['감동', '이', '되', '는'],
#  ['감동', '이나'],
#  ['감동', '이나', '고마움', '을'],
#  ['감동', '하', '는'],
#  ['감동', '하', '다'],
#  ['감동', '하', '여'],
#  ['감동', '함'],
#  ['감명', '되', '다'],
#  ['감명', '적'],
#  ['감명', '하', '다'],
#  ['감모'],
#  ['감미', '롭', '다'],
#  ['감병'],
#  ['감복', '하', '다'],
#  ['감복', '하', '여'],
#  ['감사'],
#  ['감사', '를', '표', '하', '다'],
#  ['감사', '하', '는'],
#  ['감사', '하', '는', '마음', '으로'],
#  ['감사', '하', '다'],
#  ['감싸', '고'],
#  ['감싸', '고', '달래', '다'],
#  ['감옥'],
#  ['감옥', '에'],
#  ['감정', '사납', '게'],
#  ['감정', '을', '건드려'],
#  ['감정', '의', '불화'],
#  ['감정', '이', '거칠어져'],
#  ['감정', '이', '북받쳐'],
#  ['감칠맛', '이', '있', '을'],
#  ['감탄'],
#  ['감탄', '스러울'],
#  ['감탄', '스러울', '때'],
#  ['감탄', '스럽', '다'],
#  ['감탄', '적', '으로'],
#  ['감탄', '하', '다'],
#  ['감탄', '할'],
#  ['감탄', '할', '때'],
#  ['감회', '가', '새롭', '거나'],
#  ['감회', '에', '젖', '음'],
#  ['갑갑', '궁금', '하', '다'],
#  ['갑갑', '하', '고', '궁금', '하', '다'],
#  ['갑갑', '하', '다'],
#  ['갑갑', '한'],
#  ['갑갑', '한', '증상'],
#  ['갑갑', '할'],
#  ['갑갑', '할', '정도', '로'],
#  ['갑', '분', '띠'],
#  ['갑', '분', '싸'],
#  ['갑자기', '게우', '는'],
#  ['갑자기', '놀라', '거나'],
#  ['갑자기', '놀라', '서'],
#  ['갑자기', '무섭', '거나'],
#  ['갑자기', '분별없이'],
#  ['갑자기', '서늘', '한'],
#  ['갑자기', '서늘', '한', '서늘', '한', '느낌', '이'],
#  ['갑자기', '성', '을'],
#  ['갑자기', '소란', '스럽', '게'],
#  ['갑자기', '소름', '이'],
#  ['갑자기', '어지러워'],
#  ['갑작', '스러워', '두렵', '거나'],
#  ['갑작스럽', '게', '화', '를'],
#  ['값', '을', '매길', '수', '없', '을', '만큼'],
#  ['값진'],
#  ['강간죄'],
#  ['강개무량'],
#  ['강개무량', '하', '다'],
#  ['강구', '하', '다'],
#  ['강도', '가'],
#  ['강등', '하', '여'],
#  ['강렬', '하', '게'],
#  ['강박'],
#  ['강박', '하', '여'],
#  ['강세'],
#  ['강인', '하', '다'],
#  ['강인한'],
#  ['강제', '로'],
#  ['강제', '로', '누르', '는'],
#  ['강제', '로', '누르', '다'],
#  ['강제', '로', '누름'],
#  ['강제', '로', '빼앗', '는'],
#  ['강제', '로', '빼앗', '다'],
#  ['강제', '로', '빼앗', '아'],
#  ['강제', '로', '빼앗', '음'],
#  ['강제', '로', '요구', '하', '다'],
#  ['강제', '적', '으로'],
#  ['강추'],
#  ['강탈'],
#  ['강탈', '하', '다'],
#  ['강퇴'],
#  ['강하', '게'],
#  ['강하', '게', '만들', '다'],
#  ['강하', '게', '하', '다'],
#  ['강하', '고'],
#  ['강하', '고', '야무지', '게'],
#  ['강하', '고', '야무지', '다'],
#  ['강하', '고', '튼튼', '하', '게'],
#  ['강하', '다'],
#  ['강한', '비판', '이나'],
#  ['강한', '충격', '을'],
#  ['강화', '하', '다'],
#  ['갖', '지', '아니하', '게'],
#  ['갖추', '다'],
#  ['갖추', '지', '못한'],
#  ['같잖', '다'],
#  ['같잖', '아서'],
#  ['같잖', '아서', '우스운'],
#  ['같', '잖은'],
#  ['같잖', '은', '꼴', '로'],
#  ['갚', '지', '않', '다'],
#  ['개', '가', '무섭', '거나'],
#  ['개', '가', '아프', '거나'],
#  ['개선'],
#  ['개선', '방도', '를'],
#  ['개선', '하', '고'],
#  ['개선', '하', '다'],
#  ['개선', '함'],
#  ['개성'],
#  ['개성', '있', '는'],
#  ['개성', '있', '다'],
#  ['개운', '치', '않', '거나'],
#  ['개운', '하', '게'],
#  ['개운', '하', '고'],
#  ['개운', '하', '고', '시원', '한'],
#  ['개운', '하', '고', '홀가분', '해', '지', '다'],
#  ['개운', '하', '다'],
#  ['개운', '하', '지', '않', '고'],
#  ['개으름', '을'],
#  ['개', '이득'],
#  ['개짓', '하', '다'],
#  ['개회', '하', '다'],
#  ['갠소'],
#  ['갸륵', '한'],
#  ['갸륵', '한', '데', '가'],
#  ['갸름', '하', '다'],
#  ['거꾸러뜨리', '다'],
#  ['거꾸로', '넘어지', '거나'],
#  ['거두', '지', '못한'],
#  ['거드럭거드럭'],
#  ['거드럭거리', '다'],
#  ['거들먹거들먹'],
#  ['거들먹거들먹', '하', '다'],
#  ['거들먹거리', '다'],
#  ['거들먹대', '다'],
#  ['거', '들', '먹이', '다'],
#  ['거듭', '따뜻이'],
#  ['거듭', '죄', '를'],
#  ['거뜬', '하', '다'],
#  ['거래', '가', '금지', '된'],
#  ['거룩', '한'],
#  ['거룩', '한', '모습'],
#  ['거룩', '한', '사람'],
#  ['거리끼', '어'],
#  ['거리낌', '없이'],
#  ['거만', '스럽', '게'],
#  ['거만', '을'],
#  ['거만', '을', '떠', '는'],
#  ['거만', '을', '떨', '다'],
#  ['거만', '하', '게'],
#  ['거만', '하', '게', '행동', '하', '는'],
#  ['거만', '하', '게', '행동', '하', '다'],
#  ['거만', '하', '고'],
#  ['거만', '하', '다'],
#  ['거만', '한'],
#  ['거만', '한', '태도', '로'],
#  ['거무스름', '한', '피고름', '이'],
#  ['거', '볍', '게', '까부', '는'],
#  ['거', '볍게', '성', '을'],
#  ['거', '볍', '게', '채신없이'],
#  ['거', '볍게', '행동', '하', '거나'],
#  ['거', '볍게', '행동', '하', '는'],
#  ['거', '볍게', '행동', '하', '다'],
#  ['거', '볍고', '온화', '하', '게'],
#  ['거부', '감'],
#  ['거부', '감', '없이'],
#  ['거부', '하', '거나'],
#  ['거부', '하', '다'],
#  ['거북', '스럽', '게'],
#  ['거북', '스럽', '게', '저', '는'],
#  ['거북', '스럽', '게', '절', '다'],
#  ['거북', '하', '거나'],
#  ['거북', '하', '거나', '괴로움'],
#  ['거북', '하', '거나', '괴롭', '다'],
#  ['거북', '하', '거나', '더럽', '고'],
#  ['거북', '하', '게'],
#  ['거북', '하', '고'],
#  ['거북', '하', '고', '불편', '한'],
#  ['거북', '하', '고', '주체', '스럽', '게'],
#  ['거북', '하', '다'],
#  ['거북', '한'],
#  ['거북', '한', '모양'],
#  ['거북', '한', '상태', '로'],
#  ['거북', '한', '소리', '가'],
#  ['거북', '할'],
#  ['거북', '할', '만큼'],
#  ['거세', '고'],
#  ['거세', '고', '급하', '다'],
#  ['거슬려'],
#  ['거슬려', '불쾌', '하', '다'],
#  ['거슬리', '거나'],
#  ['거슬리', '거나', '마음', '이'],
#  ['거슬리', '게'],
#  ['거슬리', '게', '싫', '다'],
#  ['거슬리', '는'],
#  ['거슬리', '는', '느낌', '이'],
#  ['거슬리', '다'],
#  ['거슬림', '이', '없이'],
#  ['거역', '하', '다'],
#  ['거역', '함'],
#  ['거의', '없', '다'],
#  ['거절', '하', '거나'],
#  ['거절', '하', '거나', '싫', '다는'],
#  ['거절', '하', '다'],
#  ['거짓'],
#  ['거짓', '없', '다'],
#  ['거짓말'],
#  ['거짓말', '을'],
#  ['거짓', '없', '다'],
#  ['거짓', '으로'],
#  ['거짓', '으로', '감정', '이나'],
#  ['거짓', '으로', '꾸며서'],
#  ['거짓', '으로', '꾸미', '는'],
#  ['거짓', '으로', '꾸미', '다'],
#  ['거짓', '으로', '꾸민'],
#  ['거짓', '으로', '속이', '다'],
#  ['거짓', '으로', '속임'],
#  ['거짓', '을', '버리', '고'],
#  ['거짓', '이', '없', '고'],
#  ['거짓', '이', '없', '다'],
#  ['거짓', '이', '없이'],
#  ['거짓', '이나'],
#  ['거추장', '스러워서'],
#  ['거추장', '스러워서', '거슬리', '거나'],
#  ['거추장', '스럽', '거나'],
#  ['거추장', '스럽', '거나', '성가시', '어'],
#  ['거추장', '스럽', '게'],
#  ['거추장', '스럽', '게', '걸리', '거나'],
#  ['거추장', '스럽', '다'],
#  ['거추장스레'],
#  ['거치적거리', '는'],
#  ['거치적거리', '는', '소리'],
#  ['거치적거치적'],
#  ['거치적거치적', '하', '다'],
#  ['거친'],
#  ['거친', '데', '가'],
#  ['거친', '말', '로'],
#  ['거친', '모양'],
#  ['거친', '목소리', '로'],
#  ['거친', '성질', '이나'],
#  ['거친', '소리', '가'],
#  ['거칠', '거나', '사납', '게'],
#  ['거칠', '게'],
#  ['거칠', '게', '나', '는'],
#  ['거칠', '게', '된'],
#  ['거칠', '게', '말다툼', '하', '다'],
#  ['거칠', '게', '말', '함'],
#  ['거칠', '게', '몰아쉬', '는'],
#  ['거칠', '게', '몰아쉬', '다'],
#  ['거칠', '게', '소리', '가'],
#  ['거칠', '게', '쉬', '는'],
#  ['거칠', '게', '울려'],
#  ['거칠', '게', '일', '다'],
#  ['거칠', '게', '잇따라'],
#  ['거칠', '게', '행동', '하', '는'],
#  ['거칠', '게', '행동', '하', '다'],
#  ['거칠', '고'],
#  ['거칠', '고', '가쁘', '게'],
#  ['거칠', '고', '격한'],
#  ['거칠', '고', '깔끄럽', '게'],
#  ['거칠', '고', '껄끄럽', '게'],
#  ['거칠', '고', '나쁘', '다'],
#  ['거칠', '고', '무뚝뚝', '하', '다'],
#  ['거칠', '고', '사나우', '며'],
#  ['거칠', '고', '세차', '다'],
#  ['거칠', '고', '심하', '다'],
#  ['거칠', '고', '험하', '게'],
#  ['거칠', '고', '험한'],
#  ['거칠', '다'],
#  ['거칠', '면서'],
#  ['거칠', '면서', '가쁘', '고'],
#  ['거칠', '어', '져'],
#  ['거침새', '가', '없', '고'],
#  ['거침없이'],
#  ['거침', '이', '없', '는'],
#  ['걱정'],
#  ['걱정', '같', '은'],
#  ['걱정', '따위', '로'],
#  ['걱정', '없이'],
#  ['걱정거리'],
#  ['걱정', '과'],
#  ['걱정', '과', '근심'],
#  ['걱정', '되', '거나'],
#  ['걱정', '스러워서'],
#  ['걱정', '스럽', '거나'],
#  ['걱정', '스럽', '거나', '조바심', '이'],
#  ['걱정', '스럽', '다'],
#  ['걱정', '으로'],
#  ['걱정', '을'],
#  ['걱정', '이'],
#  ['걱정', '이', '되', '거나'],
#  ['걱정', '이', '되', '는'],
#  ['걱정', '이', '되', '어'],
#  ['걱정', '이', '없', '고'],
#  ['걱정', '이', '없', '는'],
#  ['걱정', '이나'],
#  ['걱정', '이나', '근심'],
#  ['걱정', '이나', '근심', '에'],
#  ['걱정', '이나', '언짢', '은'],
#  ['걱정', '인', '해', '를'],
#  ['걱정', '하', '기', '는'],
#  ['걱정', '하', '기', '는', '하나'],
#  ['걱정', '하', '는'],
#  ['걱정', '하', '는', '게'],
#  ['걱정', '하', '다'],
#  ['건강', '에', '긍정', '적', '인'],
#  ['건강', '에', '좋', '은'],
#  ['건강', '에', '해로운'],
#  ['건강', '하', '고'],
#  ['건강', '하', '고', '온전', '하', '다'],
#  ['건강', '하', '고', '온전', '한'],
#  ['건강', '하', '다'],
#  ['건강', '하', '여'],
#  ['건강', '하', '여', '아름다운'],
#  ['건강', '하', '지', '못하', '다'],
#  ['건강', '한'],
#  ['건달', '처럼'],
#  ['건둥건둥'],
#  ['건둥건둥', '하', '다'],
#  ['건둥반둥', '하', '다'],
#  ['건드려', '귀찮', '게'],
#  ['건들거리', '고'],
#  ['건들거리', '고', '벙글거리', '며'],
#  ['건들건들'],
#  ['건들건들', '지내', '다'],
#  ['건들대', '다'],
#  ['건망증', '이'],
#  ['건망증', '이', '심하', '며'],
#  ['건방져'],
#  ['건방지', '게'],
#  ['건방지', '게', '행동', '하', '다'],
#  ['건방지', '네'],
#  ['건방지', '다'],
#  ['건방지', '며'],
#  ['건방진'],
#  ['건방짐'],
#  ['건성', '기침'],
#  ['건성', '으로'],
#  ['건성', '으로', '묻', '다'],
#  ['건장', '하', '다'],
#  ['건장', '한'],
#  ['건장', '한', '모양'],
#  ['건전', '하', '고'],
#  ['건전', '하', '고', '착실', '한'],
#  ['건전', '하', '지', '못하', '고'],
#  ['건전', '하', '지', '못한'],
#  ['건전', '하', '지', '아니하', '게'],
#  ['건전', '한'],
#  ['건전', '함'],
#  ['건정히'],
#  ['걷', '지', '못하', '고'],
#  ['걷', '지', '못하', '는'],
#  ['걸리', '거나'],
#  ['걸리', '거나', '막히', '는'],
#  ['걸리', '다'],
#  ['걸리적대', '다'],
#  ['걸핏', '하', '면'],
#  ['검사', '에', '불합격', '한'],
#  ['검소', '하', '다'],
#  ['검소', '한'],
#  ['검', '은', '티끌', '이', '라는'],
#  ['검질기', '게', '구', '는'],
#  ['검질기', '게', '굴', '다'],
#  ['겁'],
#  ['겁나', '게'],
#  ['겁나게', '하', '기'],
#  ['겁나', '다'],
#  ['겁내', '다'],
#  ['겁', '에'],
#  ['겁', '에', '지리', '다'],
#  ['겁', '에', '질려'],
#  ['겁', '에', '질려서'],
#  ['겁', '에', '질리', '거나'],
#  ['겁', '을'],
#  ['겁', '을', '내', '거나'],
#  ['겁', '을', '내', '다'],
#  ['겁', '을', '먹', '거나'],
#  ['겁', '을', '먹', '어'],
#  ['겁', '을', '주', '며'],
#  ['겁', '이', '나', '거나'],
#  ['겁', '이', '나', '서'],
#  ['겁', '이', '많', '고'],
#  ['겁', '이', '많', '다'],
#  ['겁', '이', '많', '아'],
#  ['겁', '이', '많', '은'],
#  ['겁', '이', '많', '음'],
#  ['겁', '자기', '부서지', '거나'],
#  ['겁쟁이'],
#  ['것', '같이', '아프', '다'],
#  ['것', '보다', '낫', '다'],
#  ['것', '을', '샘', '하', '여'],
#  ['것', '을', '짓밟', '다'],
#  ['것', '이', '거북', '하', '거나'],
#  ['것', '이', '깨끗', '하', '고'],
#  ['것', '이', '해결', '되', '어'],
#  ['겉', '만', '그럴듯한'],
#  ['겉면', '이', '매끄럽', '고'],
#  ['겉모양', '의', '아름다움', '과'],
#  ['겉치레'],
#  ['게걸', '스럽', '게'],
#  ['게걸', '스럽', '게', '돌아다니', '는'],
#  ['게걸', '스럽', '게', '돌아다니', '다'],
#  ['게우', '는'],
#  ['게우', '는', '소리'],
#  ['게우', '는', '소리', '가'],
#  ['게울'],
#  ['게울', '듯이'],
#  ['게워'],
#  ['게워', '내', '는'],
#  ['게워', '내', '다'],
#  ['게으르', '거나'],
#  ['게으르', '게'],
#  ['게으르', '게', '놀', '며'],
#  ['게으르', '게', '행동', '하', '는'],
#  ['게으르', '게', '행동', '하', '다'],
#  ['게으르', '고'],
#  ['게으르', '다'],
#  ['게으름'],
#  ['게으름', '을'],
#  ['게으름', '을', '피우', '며'],
#  ['게으름', '이'],
#  ['게으름', '이', '나', '는'],
#  ['게으름', '이나'],
#  ['게으름', '이나', '싫증'],
#  ['게을러빠지', '다'],
#  ['게을러터지', '다'],
#  ['게을리', '하', '지', '않', '고'],
#  ['겐트', '위한'],
#  ['겨를', '이', '없', '음'],
#  ['겨우', '빠듯', '하', '게'],
#  ['겨우겨우'],
#  ['겨우겨우', '살', '기', '를'],
#  ['겨운'],
#  ['겨운', '일', '에'],
#  ['격노'],
#  ['격노', '하', '다'],
#  ['격동', '시키', '다'],
#  ['격려', '되', '다'],
#  ['격려', '하', '다'],
#  ['격분'],
#  ['격분', '하', '다'],
#  ['격식', '에', '맞', '아'],
#  ['격식', '을', '갖추', '지', '않', '고'],
#  ['격', '에', '어울리', '지'],
#  ['격하', '게'],
#  ['격하', '게', '되', '다'],
#  ['격하', '다'],
#  ['격하', '시키', '다'],
#  ['격한'],
#  ['격한', '감정', '이'],
#  ['격한', '기운', '이'],
#  ['격한', '느낌', '이'],
#  ['겪', '거나', '불쌍', '한'],
#  ['견고', '하', '다'],
#  ['견디', '기', '어렵', '게'],
#  ['견디', '기', '가', '어려울'],
#  ['견디', '어', '내', '다'],
#  ['견딜', '수', '없', '는'],
#  ['견줄', '수', '없', '을', '정도', '로'],
#  ['결기', '가'],
#  ['결기', '가', '나', '다'],
#  ['결단성', '없', '다'],
#  ['결단성', '없이'],
#  ['결단성', '이', '없', '고'],
#  ['결단성', '이', '없', '다'],
#  ['결단', '을', '못', '내리', '는'],
#  ['결딴날'],
#  ['결딴날', '듯이'],
#  ['결막염'],
#  ['결석'],
#  ['결석', '하', '다'],
#  ['결심', '없이'],
#  ['결점'],
#  ['결점', '이', '없', '도록'],
#  ['결정', '을', '못', '하', '고'],
#  ['결정', '하', '지', '못하', '고'],
#  ['결정', '하', '지', '못하', '는'],
#  ['결정', '하', '지', '못하', '다'],
#  ['결정', '하', '지', '못함'],
#  ['결핍'],
#  ['결핍증'],
#  ['결함'],
#  ['결함', '을'],
#  ['결함', '을', '드러내', '어'],
#  ['결함', '을', '들추', '어'],
#  ['결함', '을', '풍자', '하', '였', '다'],
#  ['결함', '이', '없이'],
#  ['결함', '이', '있', '다'],
#  ['결함', '이나'],
#  ['결함', '이나', '잘못'],
#  ['결함', '이나', '잘못', '에'],
#  ['결핵'],
#  ['겸손', '하', '게'],
#  ['겸손', '하', '게', '이르', '는'],
#  ['겸손', '하', '고'],
#  ['겸손', '하', '고', '예의'],
#  ['겸손', '하', '고', '예의', '바른'],
#  ['겸손', '하', '다'],
#  ['겸손', '한'],
#  ['겸연쩍', '고'],
#  ['겸연쩍', '다'],
#  ['겹', '거나'],
#  ['겹', '게'],
#  ['겹', '게', '여기', '다'],
#  ['경건', '하', '다'],
#  ['경건', '한'],
#  ['경련'],
#  ['경련', '을', '일으키', '다'],
#  ['경련', '이'],
#  ['경련', '이', '일어나'],
#  ['경망', '스러우', '며'],
#  ['경망', '스러우', '며', '추잡', '하', '다'],
#  ['경망', '스러운'],
#  ['경망', '스러운', '여자', '를'],
#  ['경망', '스럽', '게'],
#  ['경망', '스럽', '게', '까부', '는'],
#  ['경망', '스럽', '게', '내', '어'],
#  ['경망', '스럽', '게', '내흔들', '거나'],
#  ['경망', '스럽', '게', '놀려'],
#  ['경망', '스럽', '게', '덤비', '며'],
#  ['경망', '스럽', '게', '떠벌리', '는'],
#  ['경망', '스럽', '게', '이리저리'],
#  ['경망', '스럽', '게', '추', '켰', '다'],
#  ['경망', '스럽', '게', '행동', '하', '는'],
#  ['경망', '스럽', '게', '행동', '하', '다'],
#  ['경망', '스럽', '고'],
#  ['경망', '스럽', '고', '가볍', '게'],
#  ['경망', '스럽', '고', '방정맞', '은'],
#  ['경망', '스럽', '다'],
#  ['경망', '하', '게'],
#  ['경망', '하', '게', '행동', '하', '는'],
#  ['경망', '하', '게', '행동', '하', '다'],
#  ['경망', '한'],
#  ['경망', '한', '짓'],
#  ['경멸'],
#  ['경멸', '하', '다'],
#  ['경멸', '히'],
#  ['경멸', '히', '여겨'],
#  ['경박', '스럽', '게'],
#  ['경박', '스럽', '게', '함부로'],
#  ['경박', '하', '게'],
#  ['경박', '하', '다'],
#  ['경박', '한'],
#  ['경박', '한', '행동', '을'],
#  ['경사', '스러운'],
#  ['경사', '스러운', '일', '을'],
#  ['경상'],
#  ['경솔', '하', '게'],
#  ['경솔', '하', '게', '까부', '는'],
#  ['경솔', '하', '게', '말', '하', '며'],
#  ['경솔', '하', '게', '행동', '하', '는'],
#  ['경솔', '하', '게', '행동', '하', '다'],
#  ['경솔', '하', '게', '행동', '하', '여'],
#  ['경솔', '하', '고'],
#  ['경솔', '하', '고', '방정맞', '게'],
#  ['경솔', '하', '다'],
#  ['경솔', '한'],
#  ['경솔', '한', '모양'],
#  ['경이', '로운'],
#  ['경이롭', '다'],
#  ['경치', '좋', '은'],
#  ['경치', '가', '뛰어나', '거나'],
#  ['경치', '가', '맑', '고'],
#  ['경치', '가', '아름다움을'],
#  ['경치', '가', '아름답', '다'],
#  ['경치', '가', '좋', '거나'],
#  ['경치', '도', '좋', '음'],
#  ['경치', '를', '즐기', '는'],
#  ['경쾌', '하', '다'],
#  ['경험', '이', '많', '고'],
#  ['경험', '이', '적', '거나'],
#  ['경황', '이', '없', '어'],
#  ['계급', '을', '올림'],
#  ['계급', '이', '오름'],
#  ['계속', '게워'],
#  ['계속', '공허', '하', '다'],
#  ['계속', '공허', '한'],
#  ['계속', '까부', '는'],
#  ['계속', '까불', '다'],
#  ['계속', '놀리', '다'],
#  ['계속', '다투', '다'],
#  ['계속', '떠들', '어'],
#  ['계속', '밉살', '스럽', '게'],
#  ['계속', '부정', '하', '다'],
#  ['계속', '불평', '을'],
#  ['계속', '서운', '하', '다'],
#  ['계속', '서운', '한'],
#  ['계속', '성', '을'],
#  ['계속', '아첨', '하', '는'],
#  ['계속', '어지럽', '고'],
#  ['계속', '쩔쩔매', '거나'],
#  ['계속', '토할'],
#  ['계속', '헤프', '게'],
#  ['계속', '흥겹', '게'],
#  ['고결', '함'],
#  ['고결', '한', '풍채', '를'],
#  ['고귀', '한'],
#  ['고귀', '한', '사람'],
#  ['고급'],
#  ['고급', '스럽', '다'],
#  ['고급', '지', '다'],
#  ['고까', '워', '하', '는'],
#  ['고까', '워', '하', '는', '데', '가'],
#  ['고까', '워', '하', '는', '태도', '가'],
#  ['고까', '워', '하', '는', '태도', '를'],
#  ['고난'],
#  ['고단', '하', '다'],
#  ['고단', '하', '여'],
#  ['고달프', '다'],
#  ['고도', '화'],
#  ['고도', '화', '되', '다'],
#  ['고되', '다'],
#  ['고르', '고'],
#  ['고르', '고', '반듯', '하', '게'],
#  ['고르', '고', '야무지', '다'],
#  ['고르', '다'],
#  ['고르', '지', '못하', '거나'],
#  ['고르', '지', '못한'],
#  ['고르', '지', '아니하', '게'],
#  ['고르', '지', '아니하', '고'],
#  ['고르', '지', '않', '고'],
#  ['고름'],
#  ['고름', '이', '나오', '는'],
#  ['고름', '이', '생기', '는'],
#  ['고름', '이', '생기', '다'],
#  ['고름집'],
#  ['고리', '게'],
#  ['고마운'],
#  ['고마운', '마음'],
#  ['고마운', '마음', '이'],
#  ['고마움'],
#  ['고마움', '을'],
#  ['고마움', '을', '깊이'],
#  ['고마움', '을', '나타내', '거나'],
#  ['고마움', '을', '나타내', '는'],
#  ['고마워', '하', '다'],
#  ['고맙', '게'],
#  ['고맙', '게', '베풀', '어'],
#  ['고맙', '게', '여기', '는'],
#  ['고맙', '게', '여기', '다'],
#  ['고맙', '게', '여김'],
#  ['고맙', '다'],
#  ['고백'],
#  ['고부라지', '거나'],
#  ['고부라지', '거나', '비틀어지', '며'],
#  ['고분고분', '하', '게'],
#  ['고분고분', '하', '고'],
#  ['고분고분', '하', '고', '온순', '하', '게'],
#  ['고분고분', '하', '고', '온순', '하', '다'],
#  ['고분고분', '하', '다'],
#  ['고분고분', '하', '지', '못하', '고'],
#  ['고비', '를'],
#  ['고상', '하', '고'],
#  ['고상', '하', '다'],
#  ['고상', '한'],
#  ['고상', '한', '기질', '과'],
#  ['고상', '한', '남자'],
#  ['고상', '한', '이야기'],
#  ['고상', '한', '인품', '을'],
#  ['고상', '한', '풍채'],
#  ['고생', '스러운'],
#  ['고생', '을'],
#  ['고생', '을', '격', '다'],
#  ['고생', '을', '하', '다'],
#  ['고생', '이나'],
#  ['고생', '하', '거나'],
#  ['고생', '하', '거나', '두려워하', '여'],
#  ['고생', '하', '다'],
#  ['고', '성능'],
#  ['고소', '공포증'],
#  ['고약', '하', '게'],
#  ['고약', '하', '다'],
#  ['고약', '함'],
#  ...]

# %%
#전처리 함수정의
#리스트형태로 모델에 들어간다
train_encodings = tokenizer(df_train['Sentiword'].tolist(), truncation=True, padding=True, max_length=max_length)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\uk246\Desktop\일억조 프로젝트\models\Preprocessing\전처리기_4 Wordpiece\모델_2\메켑 적용\ALBERT.ipynb 셀 12 in 3
#       <a href='vscode-notebook-cell:/c%3A/Users/uk246/Desktop/%EC%9D%BC%EC%96%B5%EC%A1%B0%20%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8/models/Preprocessing/%EC%A0%84%EC%B2%98%EB%A6%AC%EA%B8%B0_4%20Wordpiece/%EB%AA%A8%EB%8D%B8_2/%EB%A9%94%EC%BC%91%20%EC%A0%81%EC%9A%A9/ALBERT.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> #전처리 함수정의
#       <a href='vscode-notebook-cell:/c%3A/Users/uk246/Desktop/%EC%9D%BC%EC%96%B5%EC%A1%B0%20%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8/models/Preprocessing/%EC%A0%84%EC%B2%98%EB%A6%AC%EA%B8%B0_4%20Wordpiece/%EB%AA%A8%EB%8D%B8_2/%EB%A9%94%EC%BC%91%20%EC%A0%81%EC%9A%A9/ALBERT.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> #리스트형태로 모델에 들어간다
# ----> <a href='vscode-notebook-cell:/c%3A/Users/uk246/Desktop/%EC%9D%BC%EC%96%B5%EC%A1%B0%20%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8/models/Preprocessing/%EC%A0%84%EC%B2%98%EB%A6%AC%EA%B8%B0_4%20Wordpiece/%EB%AA%A8%EB%8D%B8_2/%EB%A9%94%EC%BC%91%20%EC%A0%81%EC%9A%A9/ALBERT.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> train_encodings = tokenizer(df_train['Sentiword'].tolist(), truncation=True, padding=True, max_length=max_length)
#
# File c:\Users\uk246\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\tokenization_utils_base.py:2530, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2528     if not self._in_target_context_manager:
#    2529         self._switch_to_input_mode()
# -> 2530     encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#    2531 if text_target is not None:
#    2532     self._switch_to_target_mode()
#
# File c:\Users\uk246\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\tokenization_utils_base.py:2616, in PreTrainedTokenizerBase._call_one(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2611         raise ValueError(
#    2612             f"batch length of `text`: {len(text)} does not match batch length of `text_pair`:"
#    2613             f" {len(text_pair)}."
#    2614         )
#    2615     batch_text_or_text_pairs = list(zip(text, text_pair)) if text_pair is not None else text
# -> 2616     return self.batch_encode_plus(
#    2617         batch_text_or_text_pairs=batch_text_or_text_pairs,
#    2618         add_special_tokens=add_special_tokens,
#    2619         padding=padding,
#    2620         truncation=truncation,
#    2621         max_length=max_length,
#    2622         stride=stride,
#    2623         is_split_into_words=is_split_into_words,
#    2624         pad_to_multiple_of=pad_to_multiple_of,
#    2625         return_tensors=return_tensors,
#    2626         return_token_type_ids=return_token_type_ids,
#    2627         return_attention_mask=return_attention_mask,
#    2628         return_overflowing_tokens=return_overflowing_tokens,
#    2629         return_special_tokens_mask=return_special_tokens_mask,
#    2630         return_offsets_mapping=return_offsets_mapping,
#    2631         return_length=return_length,
#    2632         verbose=verbose,
#    2633         **kwargs,
#    2634     )
#    2635 else:
#    2636     return self.encode_plus(
#    2637         text=text,
#    2638         text_pair=text_pair,
#    (...)
#    2654         **kwargs,
#    2655     )
#
# File c:\Users\uk246\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\tokenization_utils_base.py:2807, in PreTrainedTokenizerBase.batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2797 # Backward compatibility for 'truncation_strategy', 'pad_to_max_length'
#    2798 padding_strategy, truncation_strategy, max_length, kwargs = self._get_padding_truncation_strategies(
#    2799     padding=padding,
#    2800     truncation=truncation,
#    (...)
#    2804     **kwargs,
#    2805 )
# -> 2807 return self._batch_encode_plus(
#    2808     batch_text_or_text_pairs=batch_text_or_text_pairs,
#    2809     add_special_tokens=add_special_tokens,
#    2810     padding_strategy=padding_strategy,
#    2811     truncation_strategy=truncation_strategy,
#    2812     max_length=max_length,
#    2813     stride=stride,
#    2814     is_split_into_words=is_split_into_words,
#    2815     pad_to_multiple_of=pad_to_multiple_of,
#    2816     return_tensors=return_tensors,
#    2817     return_token_type_ids=return_token_type_ids,
#    2818     return_attention_mask=return_attention_mask,
#    2819     return_overflowing_tokens=return_overflowing_tokens,
#    2820     return_special_tokens_mask=return_special_tokens_mask,
#    2821     return_offsets_mapping=return_offsets_mapping,
#    2822     return_length=return_length,
#    2823     verbose=verbose,
#    2824     **kwargs,
#    2825 )
#
# File c:\Users\uk246\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\tokenization_utils_fast.py:428, in PreTrainedTokenizerFast._batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose)
#     419 # Set the truncation and padding strategy and restore the initial configuration
#     420 self.set_truncation_and_padding(
#     421     padding_strategy=padding_strategy,
#     422     truncation_strategy=truncation_strategy,
#    (...)
#     425     pad_to_multiple_of=pad_to_multiple_of,
#     426 )
# --> 428 encodings = self._tokenizer.encode_batch(
#     429     batch_text_or_text_pairs,
#     430     add_special_tokens=add_special_tokens,
#     431     is_pretokenized=is_split_into_words,
#     432 )
#     434 # Convert encoding to dict
#     435 # `Tokens` has type: Tuple[
#     436 #                       List[Dict[str, List[List[int]]]] or List[Dict[str, 2D-Tensor]],
#     437 #                       List[EncodingFast]
#     438 #                    ]
#     439 # with nested dimensions corresponding to batch, overflows, sequence length
#     440 tokens_and_encodings = [
#     441     self._convert_encoding(
#     442         encoding=encoding,
#    (...)
#     451     for encoding in encodings
#     452 ]
#
# TypeError: TextEncodeInput must be Union[TextInputSequence, Tuple[InputSequence, InputSequence]]

# %%
#수치형 데이터
print(train_encodings['input_ids'][10035])
#토큰화된 텍스트
print(tokenizer.convert_ids_to_tokens(train_encodings['input_ids'][10035]))
#원본텍스트
print(tokenizer.convert_tokens_to_string(tokenizer.convert_ids_to_tokens(train_encodings['input_ids'][10035])))
# Out:
# [2, 5790, 8391, 8121, 14300, 3201, 8048, 3, 0, 0, 0, 0, 0, 0, 0, 0]
# ['[CLS]', '움', '##츠', '##러', '##드는', '데', '##가', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# [CLS] 움츠러드는 데가 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]

# %%
train_encodings.keys()
max_length = len(train_encodings.input_ids[0])
max_length
# Out:
# 16

# %%
# 입력 데이터로 변환
train_input_ids = np.array(train_encodings['input_ids'])
train_attention_mask = np.array(train_encodings['attention_mask'])
train_token_type_ids = np.array(train_encodings['token_type_ids'])

train_labels = np.array(df_train['Point'].apply(lambda x: x+2).tolist())

# %%
from transformers import AlbertConfig, TFAlbertForSequenceClassification
from tensorflow.keras.layers import Dense, Dropout,BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

bert_model = TFAlbertForSequenceClassification.from_pretrained("kykim/albert-kor-base",num_labels=5)

# BERT 모델 불러오기
# config = AlbertConfig.from_pretrained(
#     "albert-base-v2",
#     num_labels=5,
#     hidden_dropout_prob=0.3,
# )
# bert_model = TFAlbertForSequenceClassification.from_pretrained("albert-base-v2",config=config)
# Out:
# All model checkpoint layers were used when initializing TFAlbertForSequenceClassification.
#
# Some layers of TFAlbertForSequenceClassification were not initialized from the model checkpoint at kykim/albert-kor-base and are newly initialized: ['classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# 입력 정의 
input_ids = tf.keras.layers.Input(shape=(max_length,), dtype=tf.int32, name="input_ids")
attention_mask = tf.keras.layers.Input(shape=(max_length,), dtype=tf.int32, name="attention_mask")


# BERT 출력 얻기
bert_output = bert_model(input_ids, attention_mask=attention_mask)
sequence_output = bert_output[0]

# 커스텀 레이어 정의
x = Dense(64, activation='relu')(sequence_output)
x = BatchNormalization()(x)
x = Dropout(0.4)(x)
output = Dense(5, activation='softmax')(x)

# 모델 생성
custom_bert_model = Model(inputs=[input_ids, attention_mask], outputs=output)

# %%
custom_bert_model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_ids (InputLayer)         [(None, 16)]         0           []
#
#  attention_mask (InputLayer)    [(None, 16)]         0           []
#
#  tf_albert_for_sequence_classif  TFSequenceClassifie  13190661   ['input_ids[0][0]',
#  ication_4 (TFAlbertForSequence  rOutput(loss=None,               'attention_mask[0][0]']
#  Classification)                logits=(None, 5),
#                                  hidden_states=None
#                                 , attentions=None)
#
#  dense_10 (Dense)               (None, 64)           384         ['tf_albert_for_sequence_classifi
#                                                                  cation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64)          256         ['dense_10[0][0]']
#  rmalization)
#
#  dropout_34 (Dropout)           (None, 64)           0           ['batch_normalization_5[0][0]']
#
#  dense_11 (Dense)               (None, 5)            325         ['dropout_34[0][0]']
#
# ==================================================================================================
# Total params: 13,191,626
# Trainable params: 13,191,498
# Non-trainable params: 128
# __________________________________________________________________________________________________

# %%
# 컴파일
custom_bert_model.compile(
    optimizer=Adam(learning_rate=2e-5, epsilon=1e-08, clipnorm=1.0),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

early_stop=tf.keras.callbacks.EarlyStopping(
    monitor='accuracy',
    patience=5,
    restore_best_weights=True
)

# 모델 학습
custom_bert_model.fit(
    [train_input_ids, train_attention_mask],
    train_labels,
    batch_size=32, epochs=10, validation_split=0.25, 
    callbacks=[early_stop]
)
# Out:
# Epoch 1/10
#   3/349 [..............................] - ETA: 22:41 - loss: 2.1406 - accuracy: 0.1667
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\uk246\Desktop\일억조 프로젝트\models\Preprocessing\전처리기_4 Wordpiece\모델_2\메켑 미적용\ALBERT.ipynb 셀 17 in 1
#       <a href='vscode-notebook-cell:/c%3A/Users/uk246/Desktop/%EC%9D%BC%EC%96%B5%EC%A1%B0%20%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8/models/Preprocessing/%EC%A0%84%EC%B2%98%EB%A6%AC%EA%B8%B0_4%20Wordpiece/%EB%AA%A8%EB%8D%B8_2/%EB%A9%94%EC%BC%91%20%EB%AF%B8%EC%A0%81%EC%9A%A9/ALBERT.ipynb#X21sZmlsZQ%3D%3D?line=7'>8</a> early_stop=tf.keras.callbacks.EarlyStopping(
#       <a href='vscode-notebook-cell:/c%3A/Users/uk246/Desktop/%EC%9D%BC%EC%96%B5%EC%A1%B0%20%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8/models/Preprocessing/%EC%A0%84%EC%B2%98%EB%A6%AC%EA%B8%B0_4%20Wordpiece/%EB%AA%A8%EB%8D%B8_2/%EB%A9%94%EC%BC%91%20%EB%AF%B8%EC%A0%81%EC%9A%A9/ALBERT.ipynb#X21sZmlsZQ%3D%3D?line=8'>9</a>     monitor='accuracy',
#      <a href='vscode-notebook-cell:/c%3A/Users/uk246/Desktop/%EC%9D%BC%EC%96%B5%EC%A1%B0%20%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8/models/Preprocessing/%EC%A0%84%EC%B2%98%EB%A6%AC%EA%B8%B0_4%20Wordpiece/%EB%AA%A8%EB%8D%B8_2/%EB%A9%94%EC%BC%91%20%EB%AF%B8%EC%A0%81%EC%9A%A9/ALBERT.ipynb#X21sZmlsZQ%3D%3D?line=9'>10</a>     patience=5,
#      <a href='vscode-notebook-cell:/c%3A/Users/uk246/Desktop/%EC%9D%BC%EC%96%B5%EC%A1%B0%20%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8/models/Preprocessing/%EC%A0%84%EC%B2%98%EB%A6%AC%EA%B8%B0_4%20Wordpiece/%EB%AA%A8%EB%8D%B8_2/%EB%A9%94%EC%BC%91%20%EB%AF%B8%EC%A0%81%EC%9A%A9/ALBERT.ipynb#X21sZmlsZQ%3D%3D?line=10'>11</a>     restore_best_weights=True
#      <a href='vscode-notebook-cell:/c%3A/Users/uk246/Desktop/%EC%9D%BC%EC%96%B5%EC%A1%B0%20%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8/models/Preprocessing/%EC%A0%84%EC%B2%98%EB%A6%AC%EA%B8%B0_4%20Wordpiece/%EB%AA%A8%EB%8D%B8_2/%EB%A9%94%EC%BC%91%20%EB%AF%B8%EC%A0%81%EC%9A%A9/ALBERT.ipynb#X21sZmlsZQ%3D%3D?line=11'>12</a> )
#      <a href='vscode-notebook-cell:/c%3A/Users/uk246/Desktop/%EC%9D%BC%EC%96%B5%EC%A1%B0%20%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8/models/Preprocessing/%EC%A0%84%EC%B2%98%EB%A6%AC%EA%B8%B0_4%20Wordpiece/%EB%AA%A8%EB%8D%B8_2/%EB%A9%94%EC%BC%91%20%EB%AF%B8%EC%A0%81%EC%9A%A9/ALBERT.ipynb#X21sZmlsZQ%3D%3D?line=13'>14</a> # 모델 학습
# ---> <a href='vscode-notebook-cell:/c%3A/Users/uk246/Desktop/%EC%9D%BC%EC%96%B5%EC%A1%B0%20%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8/models/Preprocessing/%EC%A0%84%EC%B2%98%EB%A6%AC%EA%B8%B0_4%20Wordpiece/%EB%AA%A8%EB%8D%B8_2/%EB%A9%94%EC%BC%91%20%EB%AF%B8%EC%A0%81%EC%9A%A9/ALBERT.ipynb#X21sZmlsZQ%3D%3D?line=14'>15</a> custom_bert_model.fit(
#      <a href='vscode-notebook-cell:/c%3A/Users/uk246/Desktop/%EC%9D%BC%EC%96%B5%EC%A1%B0%20%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8/models/Preprocessing/%EC%A0%84%EC%B2%98%EB%A6%AC%EA%B8%B0_4%20Wordpiece/%EB%AA%A8%EB%8D%B8_2/%EB%A9%94%EC%BC%91%20%EB%AF%B8%EC%A0%81%EC%9A%A9/ALBERT.ipynb#X21sZmlsZQ%3D%3D?line=15'>16</a>     [train_input_ids, train_attention_mask],
#      <a href='vscode-notebook-cell:/c%3A/Users/uk246/Desktop/%EC%9D%BC%EC%96%B5%EC%A1%B0%20%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8/models/Preprocessing/%EC%A0%84%EC%B2%98%EB%A6%AC%EA%B8%B0_4%20Wordpiece/%EB%AA%A8%EB%8D%B8_2/%EB%A9%94%EC%BC%91%20%EB%AF%B8%EC%A0%81%EC%9A%A9/ALBERT.ipynb#X21sZmlsZQ%3D%3D?line=16'>17</a>     train_labels,
#      <a href='vscode-notebook-cell:/c%3A/Users/uk246/Desktop/%EC%9D%BC%EC%96%B5%EC%A1%B0%20%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8/models/Preprocessing/%EC%A0%84%EC%B2%98%EB%A6%AC%EA%B8%B0_4%20Wordpiece/%EB%AA%A8%EB%8D%B8_2/%EB%A9%94%EC%BC%91%20%EB%AF%B8%EC%A0%81%EC%9A%A9/ALBERT.ipynb#X21sZmlsZQ%3D%3D?line=17'>18</a>     batch_size=32, epochs=10, validation_split=0.25,
#      <a href='vscode-notebook-cell:/c%3A/Users/uk246/Desktop/%EC%9D%BC%EC%96%B5%EC%A1%B0%20%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8/models/Preprocessing/%EC%A0%84%EC%B2%98%EB%A6%AC%EA%B8%B0_4%20Wordpiece/%EB%AA%A8%EB%8D%B8_2/%EB%A9%94%EC%BC%91%20%EB%AF%B8%EC%A0%81%EC%9A%A9/ALBERT.ipynb#X21sZmlsZQ%3D%3D?line=18'>19</a>     callbacks=[early_stop]
#      <a href='vscode-notebook-cell:/c%3A/Users/uk246/Desktop/%EC%9D%BC%EC%96%B5%EC%A1%B0%20%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8/models/Preprocessing/%EC%A0%84%EC%B2%98%EB%A6%AC%EA%B8%B0_4%20Wordpiece/%EB%AA%A8%EB%8D%B8_2/%EB%A9%94%EC%BC%91%20%EB%AF%B8%EC%A0%81%EC%9A%A9/ALBERT.ipynb#X21sZmlsZQ%3D%3D?line=19'>20</a> )
#
# File c:\Users\uk246\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\uk246\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py:1650, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1642 with tf.profiler.experimental.Trace(
#    1643     "train",
#    1644     epoch_num=epoch,
#    (...)
#    1647     _r=1,
#    1648 ):
#    1649     callbacks.on_train_batch_begin(step)
# -> 1650     tmp_logs = self.train_function(iterator)
#    1651     if data_handler.should_sync:
#    1652         context.async_wait()
#
# File c:\Users\uk246\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\uk246\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:880, in Function.__call__(self, *args, **kwds)
#     877 compiler = "xla" if self._jit_compile else "nonXla"
#     879 with OptionalXlaContext(self._jit_compile):
# --> 880   result = self._call(*args, **kwds)
#     882 new_tracing_count = self.experimental_get_tracing_count()
#     883 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\uk246\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:912, in Function._call(self, *args, **kwds)
#     909   self._lock.release()
#     910   # In this case we have created variables on the first call, so we run the
#     911   # defunned version which is guaranteed to never create variables.
# --> 912   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913 elif self._variable_creation_fn is not None:
#     914   # Release the lock early so that multiple threads can perform the call
#     915   # in parallel.
#     916   self._lock.release()
#
# File c:\Users\uk246\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:134, in TracingCompiler.__call__(self, *args, **kwargs)
#     131 with self._lock:
#     132   (concrete_function,
#     133    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134 return concrete_function._call_flat(
#     135     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File c:\Users\uk246\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1745, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1741 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1742 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1743     and executing_eagerly):
#    1744   # No tape is watching; skip to running the function.
# -> 1745   return self._build_call_outputs(self._inference_function.call(
#    1746       ctx, args, cancellation_manager=cancellation_manager))
#    1747 forward_backward = self._select_forward_and_backward_functions(
#    1748     args,
#    1749     possible_gradient_type,
#    1750     executing_eagerly)
#    1751 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\uk246\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:378, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     376 with _InterpolateFunctionError(self):
#     377   if cancellation_manager is None:
# --> 378     outputs = execute.execute(
#     379         str(self.signature.name),
#     380         num_outputs=self._num_outputs,
#     381         inputs=args,
#     382         attrs=attrs,
#     383         ctx=ctx)
#     384   else:
#     385     outputs = execute.execute_with_cancellation(
#     386         str(self.signature.name),
#     387         num_outputs=self._num_outputs,
#    (...)
#     390         ctx=ctx,
#     391         cancellation_manager=cancellation_manager)
#
# File c:\Users\uk246\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %%
custom_bert_model.save('albert-kor-base.h5')

# %%
# 예측 예시
example_texts = ['회식끝나고 집가는중','개꿀잼이네','진짜 너무 별로다.','ㅋㅋㅋㅋㅋㅋㅋㅋ재밌따','나는 잘봤다.']
#정제
clean_test_texts=[]
for i in example_texts:
    clean_test_texts.append(clean_korean_text(i))


clean_test_texts
# Out:
# ['회식끝나고 집가는중', '개꿀잼이네', '진짜 너무 별로다', 'ㅋ재밌따', '나는 잘봤다']

# %%
#정제된 텍스트를 벡터화하기전에 토큰화한다
from konlpy.tag import Okt
mecab=Okt()

clean_test_texts1 = [ mecab.morphs(i) for i in clean_test_texts]
print(clean_test_texts1)

clean_test_texts2=[]
for i in clean_test_texts1:
    clean_test_texts2.append(' '.join(i))
print(clean_test_texts2)
# Out:
# [['회식', '끝나고', '집가는', '중'], ['개꿀잼', '이네'], ['진짜', '너무', '별로', '다'], ['ㅋ', '재밌', '따'], ['나', '는', '잘', '봤다']]
# ['회식 끝나고 집가는 중', '개꿀잼 이네', '진짜 너무 별로 다', 'ㅋ 재밌 따', '나 는 잘 봤다']

# %%
predicted = pipeline(clean_test_texts2)
print("Prediction:", predicted)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-f7d0ae88ab9e> in <cell line: 1>()
# ----> 1 predicted = pipeline(clean_test_texts2)
#       2 print("Prediction:", predicted)
#
# NameError: name 'pipeline' is not defined

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
#테스트문장 입력
test = ['회식끝나고 집가는중','개꿀잼이네','진짜 너무 별로다.','ㅋㅋㅋㅋㅋㅋㅋㅋ재밌따']

#정제
clean_test_texts=[]
for i in test:
    clean_test_texts.append(clean_korean_text(i))

max_length = 64
# 텍스트 데이터 토큰화
tokenized_test_texts = [tokenizer.encode(text, max_length=max_length, pad_to_max_length=True) for text in clean_test_texts]
tokenized_test_texts

# 토큰화된 텍스트를 Numpy 배열로 변환
tokenized_test_texts = np.array(tokenized_test_texts)
tokenized_test_texts

#벡터화
x_test = pad_sequences(tokenized_test_texts,padding='post',maxlen=max_length) 

#예측
prediction = model.predict(x_test)  

for i in np.round(prediction):
    print(int(i))
# Out:
# 1/1 [==============================] - 1s 561ms/step
# 0
# 1
# 0
# 1

# %% [markdown]
# # 서비스 테스트

# %%
#모델 불러오기
from tensorflow.keras.models import load_model
loaded_model= load_model('./wordpiece_test.h5')

# #저장된 vectorizer 불러오기
# import pickle
# with open('./lstm_tokenizer.pkl', 'rb') as f:
#     loaded_test_vectorizer = pickle.load(f)

# %%
# 카톡대화 불러와서 정제,(정규화코드)하는 함수
import re

def get_from_txt(txt):
    data= open(txt,"r", encoding='utf-8').read().split('\n')
    sentences=[]
    for line in data:
        pattern = r'\[(.*?)\]\s+\[(.*?)\]\s+(.+)'
        match = re.match(pattern, line)
        if match:
            name = match.group(1)  # 첫 번째 대괄호 안의 단어 추출
            time = match.group(2)  # 두 번째 대괄호 안의 단어 추출
            content = match.group(3)  # 대괄호 뒤의 내용 추출
            # print(name, time, content)
            temp=[name,time,content]
            sentences.append(temp)    
    return sentences

#함수확인
get_from_txt('sample.txt')
# Out:
# [['김찬란', '오후 10:01', '사진'],
#  ['김찬란', '오후 9:38', 'https://youtube.com/watch?v=o1G7DWFFHso&feature=share'],
#  ['김찬란', '오후 10:42', '사진'],
#  ['김찬란', '오후 10:42', '사기치고다니는 한장규'],
#  ['김하영', '오후 10:45', '이야'],
#  ['김하영', '오후 10:46', '게임에서도 치네'],
#  ['김찬란', '오후 10:46', '진짜 니말이 맞다 진짜 친구면 친구한테 민폐되기 싫어서 돈빌려달란 소리도 안한다'],
#  ['김하영', '오전 12:25', '이모티콘'],
#  ['김하영', '오전 12:35', '회식끝나고 집가는중'],
#  ['김찬란', '오전 12:35', '음음 초밥집 회식은 어디서 하냐'],
#  ['김하영', '오전 12:35', '우리 실장형네 직이 고기집해서 글로갔다'],
#  ['김하영', '오전 12:36', '회식하면 맨날 돼지고기만 먹는다'],
#  ['김찬란', '오전 12:36', 'ㅋㅋㅋㅋㅋㅋ케'],
#  ['김하영', '오전 12:36', '이모티콘'],
#  ['김찬란', '오전 12:36', '아 내수용 회식'],
#  ['김찬란', '오전 12:36', '사진'],
#  ['김하영', '오전 12:36', 'ㅋㅋㅋㅋ 그런거 아니고 애들이 여기가 맛있다고 여기서먹음'],
#  ['김찬란', '오전 12:37', '고기 얘시하니까'],
#  ['김찬란', '오전 12:37', '나도 고기가 먹고 싶군'],
#  ['김하영', '오전 12:37', 'ㅋㅋㅋㅋ '],
#  ['김찬란', '오전 12:37', '낼 사먹어야겠다'],
#  ['김하영', '오전 12:37', '와라 엉아가 소고기 사줄께'],
#  ['김찬란', '오전 12:37', '내가 사야지 씹새야 입벌려'],
#  ['김찬란', '오전 12:37', '고기 들어간'],
#  ['김찬란', '오전 12:38', '너는 내가 사주고 싶으니까 '],
#  ['김찬란', '오전 12:38', '취직해서 올라가면 함보자'],
#  ['김하영', '오전 12:39', '어야~~ 언제 취직하냐 김짤랑'],
#  ['김찬란', '오전 12:39', '올 여름'],
#  ['김하영', '오전 12:39', 'ㅋㅋㅋㅋ 뭔데??'],
#  ['김하영', '오전 12:40', '공무원 김짤랑??'],
#  ['김찬란', '오전 12:40', '머신러닝 엔지니어'],
#  ['김하영', '오전 12:40', '그건또 뭔 하이테크냐??'],
#  ['김하영', '오전 12:40', '샵검색: #머신러닝'],
#  ['김찬란', '오전 12:41', '인공지능 로밧'],
#  ['김찬란', '오전 12:41', '인간시대의 끝이 도래한다'],
#  ['김하영', '오전 12:41', '저거 보들보들하냐??'],
#  ['김하영', '오전 12:41', '안무냐??'],
#  ['김찬란', '오전 12:41', '배만지면 통통햐'],
#  ['김찬란', '오전 12:41', '격렬하게 저항하는데'],
#  ['김찬란', '오전 12:41', '그것도 귀여움'],
#  ['김하영', '오전 12:42', 'ㅋㅋㅋㅋ 안물면 상관없다'],
#  ['김찬란', '오전 12:42', '계속만지면 자포자기하더라'],
#  ['김찬란', '오전 12:42', '포기하고 배를 내어쥼'],
#  ['김하영', '오전 12:42', '주인이랑 성격이 똑같네'],
#  ['김찬란', '오전 12:42', '?'],
#  ['김찬란', '오전 12:43', '츕다 '],
#  ['김찬란', '오전 12:43', '언능 들어가쇼'],
#  ['김찬란', '오전 12:43', '길바닥에서 얼어뒤짐'],
#  ['김하영', '오전 12:43', '이미 집왔다'],
#  ['김찬란', '오전 12:43', '맞나'],
#  ['김하영', '오전 12:43', '돈 편하게 많이 벌고싶다~~'],
#  ['김찬란', '오전 12:44', '넌 잘할둣'],
#  ['김찬란', '오전 12:44', '열심히 일하면 잘될겨'],
#  ['김하영', '오전 12:44', '지금 번아웃 온거같다'],
#  ['김찬란', '오전 12:44', '등꼴빼먹는 사기뀬만 안만나면'],
#  ['김하영', '오전 12:44', 'ㅋㅋㅋㅋ '],
#  ['김찬란', '오전 12:44', '번아웃 올정도로 열심히하나'],
#  ['김찬란', '오전 12:44', '얼마나 벌길래'],
#  ['김하영', '오전 12:45', '일단 세전 300에'],
#  ['김하영', '오전 12:45', '투자금+a'],
#  ['김찬란', '오전 12:45', '하루에 3시간씩자몀서 투잡 쓰리잡하는 사람도봄 '],
#  ['김하영', '오전 12:45', '투자금 0~300'],
#  ['김하영', '오전 12:45', '매달'],
#  ['김찬란', '오전 12:45', '나 세전 31만원'],
#  ['김하영', '오전 12:45', 'ㅋㅋㅋㅋ '],
#  ['김찬란', '오전 12:45', '코인 10'],
#  ['김하영', '오전 12:45', '코인뭔데'],
#  ['김찬란', '오전 12:46', '리플'],
#  ['김하영', '오전 12:46', 'ㅋㅋㅋㅋ '],
#  ['김찬란', '오전 12:46', 'ㅋㅋㅋㅋㅋ'],
#  ['김하영', '오전 12:46', 'ㅈㄴ 강제독립되가지고'],
#  ['김하영', '오전 12:46', '힘들다 숨만쉬어도 달에 170빠짐'],
#  ['김찬란', '오전 12:46', '와 '],
#  ['김찬란', '오전 12:46', '너무 많이 빠지는데'],
#  ['김찬란', '오전 12:46', '세금이랑 방ㅅ랑 합쳐도'],
#  ['김하영', '오전 12:47', '연봉으로 치면 5천 좀 넘는거같은데'],
#  ['김하영', '오전 12:47', '모이는게없음'],
#  ['김찬란', '오전 12:47', 'ㅇㅇ 마이 버네'],
#  ['김찬란', '오전 12:47', '글게'],
#  ['김하영', '오전 12:47', '여자친구 집에서 키우고'],
#  ['김하영', '오전 12:47', '외식을 줄여야하는데'],
#  ['김찬란', '오전 12:47', '여친이 있네'],
#  ['김찬란', '오전 12:47', '방금 프사 봄'],
#  ['김하영', '오전 12:47', '같이산다'],
#  ['김하영', '오전 12:47', 'ㅋㅋㅋㅋ '],
#  ['김하영', '오전 12:48', '5살 연하임'],
#  ['김찬란', '오전 12:48', '결혼람?'],
#  ['김찬란', '오전 12:48', '완전 도둑시키네'],
#  ['김하영', '오전 12:48', '이제 스물셋인ㄷ!?'],
#  ['김찬란', '오전 12:48', '라고할뻔'],
#  ['김찬란', '오전 12:48', '도랏나 완전 얼란데'],
#  ['김하영', '오전 12:48', '2년전에 많이들었다 이거'],
#  ['김찬란', '오전 12:49', '완전 도랏네 암튼 츅하한다'],
#  ['김하영', '오전 12:49', '이모티콘'],
#  ['김찬란', '오전 12:49', '와 나는 23살 이란 대화만 해도'],
#  ['김찬란', '오전 12:49', '세대차이 느껴지던대ㅔ'],
#  ['김하영', '오전 12:49', 'ㅈㄴ 웃기네 ㅋㅋㅋㅋ'],
#  ['김하영', '오전 12:49', '맞음'],
#  ['김찬란', '오전 12:49', '드라마,좋아하는노래 등등 세대가 달라'],
#  ['김찬란', '오전 12:50', '저번에 슴셋함테 이세돌아냐고 물어보ㅓㅆ다가'],
#  ['김하영', '오전 12:50', '얘네 친척언니들이 무슨 그렇게 나이 차이나는 남자 만나냐그럼'],
#  ['김찬란', '오전 12:50', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['김하영', '오전 12:50', '나랑 동갑이거든'],
#  ['김하영', '오전 12:50', 'ㅋㅋㅋㅋㅋㅋ '],
#  ['김찬란', '오전 12:50', 'ㅋㅋㅋㅋㅋㅋㅋ'],
#  ['김찬란', '오전 12:51', '아니 슴셋이랑 슴여덜'],
#  ['김찬란', '오전 12:51', '음 생각보다 안나는것같기도'],
#  ['김찬란', '오전 12:51', '나 고삼때 25 남자 만나던 애도'],
#  ['김찬란', '오전 12:51', '있었는데 그게 ㅈㄴ짜 개십새낒'],
#  ['김찬란', '오전 12:51', '라고할뻔'],
#  ['김하영', '오전 12:52', 'ㅋㅋㅋㅋ'],
#  ['김찬란', '오전 12:52', '여자애가'],
#  ['김하영', '오전 12:52', '이쁨??'],
#  ['김찬란', '오전 12:52', '고삼이 25남자 만나더라'],
#  ['김찬란', '오전 12:52', '이뻣음'],
#  ['김찬란', '오전 12:52', '내기준'],
#  ['김하영', '오전 12:52', '개웃기네'],
#  ['김하영', '오전 12:52', '이게 참 거시기함'],
#  ['김찬란', '오전 12:53', '내기준 이쁜사람'],
#  ['김찬란', '오전 12:53', '샵검색: #이수현'],
#  ['김찬란', '오전 12:53', '마지노선'],
#  ['김하영', '오전 12:54', 'ㅈㄴ 낮네'],
#  ['김찬란', '오전 12:54', 'ㅇㅇ 난 성격 많이봄'],
#  ['김하영', '오전 12:54', '짤랑 좋은 여자 만나겠네'],
#  ['김찬란', '오전 12:54', '근데 여자들이 날 안좋아하더라'],
#  ['김하영', '오전 12:54', '솔직히 나는 연애고 결혼이고 내가 좋아하는거보다'],
#  ['김하영', '오전 12:54', '아 시발'],
#  ['김찬란', '오전 12:55', 'ㅇㅇ'],
#  ['김찬란', '오전 12:55', '니가 좋아하는것보다 '],
#  ['김찬란', '오전 12:55', '좋아해주는 사람이 좋음?'],
#  ['김하영', '오전 12:55', '여자가 남자를 더 좋아해 주는게'],
#  ['김하영', '오전 12:55', '훨씬 좋다고 생각함'],
#  ['김찬란', '오전 12:55', '그런맛이 있지'],
#  ['김하영', '오전 12:55', '좀 이기적일수도 있는데'],
#  ['김찬란', '오전 12:56', '그게 이기적이면 대부분의 여자가 이기적인거지 ㅋㅋㅋㅋ'],
#  ['김찬란', '오전 12:56', '그럴슈도있지'],
#  ['김하영', '오전 12:56', '남자가 여자한테 매달리게되면 답이 없음'],
#  ['김하영', '오전 12:57', '퍼주고 끝나는거만 봐서'],
#  ['김찬란', '오전 12:57', '그런여자들은 좋은 사람 놓치는겨'],
#  ['김찬란', '오전 12:57', '그렇게 해주는 사람이 어딧냐'],
#  ['김하영', '오전 12:57', '이모티콘'],
#  ['김찬란', '오전 12:57', '시골은 그런사람 귀함'],
#  ['김찬란', '오전 12:57', '너도나도 시집가려할듯'],
#  ['김하영', '오전 12:58', '그놈의 시골'],
#  ['김하영', '오전 12:58', 'ㅋㅋㅋㅋ'],
#  ['김찬란', '오전 12:58', 'ㄹㅇ임'],
#  ['김하영', '오전 12:58', '남자없냐??'],
#  ['김찬란', '오전 12:58', '술만 안마셔도 바로 시집가는 사람도 있음'],
#  ['김찬란', '오전 12:58', '멀쫑한 남자가 별로없지'],
#  ['김찬란', '오전 12:59', '나도 집착 당해보고 싶다'],
#  ['김찬란', '오전 12:59', '상전이 된기뷴일둣'],
#  ['김하영', '오전 1:00', '언젠가는 생길거다'],
#  ['김하영', '오전 1:00', '일단'],
#  ['김하영', '오전 1:00', '살부터 빼 새끼야'],
#  ['김찬란', '오전 1:00', '나 74밖에 안나가 지굼'],
#  ['김찬란', '오전 1:00', '태퓽 불면 날아갈듯'],
#  ['김찬란', '오전 1:00', '아니 아이폰 미니 샀는데'],
#  ['김찬란', '오전 1:01', '오타 미친다 자찬 개짝음'],
#  ['김하영', '오전 1:01', 'ㅋㅋㅋㅋㅋㅋ'],
#  ['김하영', '오전 1:01', '플립이나 쓰지'],
#  ['김하영', '오전 1:01', '왜 아이폰 쓰냐'],
#  ['김하영', '오전 1:01', '플립 좋은데'],
#  ['김찬란', '오전 1:01', '사진'],
#  ['김찬란', '오전 1:01', '뇌섹녀다 '],
#  ['김하영',
#   '오전 1:01',
#   'https://m.blog.naver.com/PostView.naver?blogId=wax96&logNo=222870410153&proxyReferer='],
#  ['김하영', '오전 1:02', '이거 여자친구가 너 닮았데'],
#  ['김찬란', '오전 1:02', '나무늘보??'],
#  ['김하영', '오전 1:02', '맞데'],
#  ['김하영', '오전 1:02', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['김하영', '오전 1:02', '아 존나 웃기네'],
#  ['김찬란', '오전 1:02', 'ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['김찬란', '오전 1:02', '아니 나 만나는 사람마다 뭐 닮았데'],
#  ['김하영', '오전 1:03', '유니크 하긴해'],
#  ['김하영', '오전 1:03', '우리 짤랑이'],
#  ['김찬란', '오전 1:03', 'ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['김찬란', '오전 1:03', '오ㅑ 내개ㅏ 느그 짤랑이냐'],
#  ['김찬란', '오전 1:03', '우리 친형만이 부르는 별명이다'],
#  ['김하영', '오전 1:03', '그럼 누구네 짤랑이냐 너가'],
#  ['김하영', '오전 1:03', 'ㅋㅋㅋㅋㅋㅋ'],
#  ['김찬란', '오전 1:04', '자빠져 자시요'],
#  ['김찬란', '오전 1:04', '여친이랑 잘놀고'],
#  ['김찬란', '오전 1:04', '나 낼 경찰서 가야뎀'],
#  ['김하영', '오전 1:04', '사진'],
#  ['김찬란', '오전 1:05', '맨두?'],
#  ['김하영', '오전 1:05', '어야 난 여자친구 빵굽는거 보다가 겜좀 하고 자야겠당'],
#  ['김하영', '오전 1:05', '만두아니고'],
#  ['김하영', '오전 1:05', '소금빵이라고'],
#  ['김하영', '오전 1:05', '승질내는중'],
#  ['김하영', '오전 1:05', '잘자라 짤랑'],
#  ['김찬란', '오전 1:05', '앜ㅋㅋㅋㅋㅋㅋ'],
#  ['김찬란', '오전 1:06', '뀰잠 잘듯'],
#  ['김찬란', '오전 1:06', '두근두근 경찰서 모험'],
#  ['김하영', '오전 1:06', 'ㅋㅋㅋㅋ'],
#  ['김찬란', '오전 1:06', '경찰 아찌들 '],
#  ['김하영', '오전 1:06', '짤랑이 경찰서도 가고 많이 컷네'],
#  ['김찬란', '오전 1:06', '무섭다'],
#  ['김하영', '오전 1:06', '니가 범죄자만 아니면 친젏마'],
#  ['김찬란', '오전 1:06', '긍게'],
#  ['김찬란', '오전 1:06', '나 범죄자일지도'],
#  ['김하영', '오전 1:06', '뭐했는데 ㅋㅋㅋㅋ'],
#  ['김찬란', '오전 1:06', '돈 내놓으라고 협박하긴 랬음'],
#  ['김하영', '오전 1:06', '개웃기네 진짜'],
#  ['김찬란', '오전 1:06', '갚으라고'],
#  ['김하영', '오전 1:06', '신고할꺼라고?'],
#  ['김하영', '오전 1:07', '이게 진짜 거지같은게'],
#  ['김찬란', '오전 1:07', '사진'],
#  ['김하영', '오전 1:07', '빌려줄때는 애원하는데'],
#  ['김하영', '오전 1:07', '받을때는 내가 애원해야한다'],
#  ['김찬란', '오전 1:07', '개욕받았눈데'],
#  ['김하영', '오전 1:07', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['김하영', '오전 1:07', '존나 화났네'],
#  ['김찬란', '오전 1:07', '애원안하지왜해'],
#  ['김하영', '오전 1:07', '진짜 개귀엽네'],
#  ['김하영', '오전 1:07', '우리짤랑이'],
#  ['김찬란', '오전 1:07', '애교 부이면 돌돌려받나'],
#  ['김하영', '오전 1:08', 'ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['김하영', '오전 1:08', '주겠냐?'],
#  ['김하영', '오전 1:08', 'ㅋㅋㅋㅋㅋㅋ'],
#  ['김찬란', '오전 1:08', 'ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['김하영', '오전 1:08', '진짜 빌려줄때는'],
#  ['김하영', '오전 1:08', '얘한테는 안받아도 상관없어'],
#  ['김하영', '오전 1:08', '라는 놈들한테만'],
#  ['김하영', '오전 1:08', '빌려줘라'],
#  ['김하영', '오전 1:08', '몇만원이든 몇십이든 몇백이든'],
#  ['김찬란', '오전 1:08', '나 '],
#  ['김하영', '오전 1:08', '아무리 친해도 받기 힘듦'],
#  ['김찬란', '오전 1:08', '알면서 당한듯'],
#  ['김하영', '오전 1:09', 'ㅋㅋㅋㅋㅋ'],
#  ['김찬란', '오전 1:09', '알고도 당하는 매직'],
#  ['김하영', '오전 1:09', '마음이 약해서 그럼'],
#  ['김하영', '오전 1:09', '나도 진짜'],
#  ['김하영', '오전 1:09', '많이 당해서'],
#  ['김찬란', '오전 1:09', '친구 아버지 돕는다는 생각으로'],
#  ['김찬란', '오전 1:09', '시부랄'],
#  ['김하영', '오전 1:09', '맞지'],
#  ['김찬란', '오전 1:09', '좋는생각으로 빌려쥰건데'],
#  ['김찬란', '오전 1:09', '후 죽여버리고 싶다'],
#  ['김찬란', '오전 1:10', '후련하려나'],
#  ['김하영', '오전 1:10', 'ㅋㅋㅋㅋㅋㅋㅋ'],
#  ['김하영', '오전 1:10', '절대'],
#  ['김하영', '오전 1:10', '안 후련하다 절대로'],
#  ['김하영', '오전 1:10', '깜빵넣어도'],
#  ['김찬란', '오전 1:10', '아니야'],
#  ['김찬란', '오전 1:10', '존나 후련할듯'],
#  ['김하영', '오전 1:10', 'ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['김하영', '오전 1:10', '진정해라'],
#  ['김하영', '오전 1:10', '김짤랑'],
#  ['김찬란', '오전 1:10', '아 감빵은 감당 안된다'],
#  ['김찬란', '오전 1:10', '암살햐야지'],
#  ['김찬란', '오전 1:10', '내가 쥭인건 몰르게'],
#  ['김찬란', '오전 1:10', '후..'],
#  ['김하영', '오전 1:11', '도경이가'],
#  ['김하영', '오전 1:11', '젤불쌍하다'],
#  ['김찬란', '오전 1:11', 'ㅋㅋㅋㅋㅋㅋ '],
#  ['김하영', '오전 1:11', '진짜 착한애를 갖다가'],
#  ['김하영', '오전 1:11', '씹새끼'],
#  ['김하영', '오전 1:11', '짤랑이가 돈이 없어서 망정이지'],
#  ['김찬란', '오전 1:11', '진짜 사람 착하고 열심히사는사람린데'],
#  ['김하영', '오전 1:11', '진짜'],
#  ['김찬란', '오전 1:11', '도경이'],
#  ['김하영', '오전 1:11', '누구한테는 연봉인데'],
#  ['김찬란', '오전 1:12', '1 소나타'],
#  ['김찬란', '오전 1:12', '내 드림카임'],
#  ['김찬란', '오전 1:12', '멋뎌'],
#  ['김하영', '오전 1:13', '나는 재규어'],
#  ['김하영', '오전 1:13', '였는데 이제 우라칸'],
#  ['김찬란', '오전 1:17', '남자의 차'],
#  ['김찬란', '오전 1:18', '샵검색: #팰리세이드'],
#  ['김찬란', '오전 1:18', '잘빠졌다\\'],
#  ['김찬란', '오전 1:18', '샵검색: #재규어'],
#  ['김찬란', '오전 1:18', '삼촌 한분이 이거 애지중지하던데 비싼거였구나'],
#  ['김찬란', '오전 1:19', '맨날 손세차하더라 만날떄마다'],
#  ['김하영', '오전 1:26', 'ㅋㅋㅋㅋㅋㅋㅋ'],
#  ['김찬란', '오후 9:08', '파일: 고소장 초안.hwp'],
#  ['김찬란', '오후 9:08', '자새끼좀 감방에 넣어쥬세요 '],
#  ['김하영', '오후 9:16', 'ㅋㅋㅋㅋ'],
#  ['김하영', '오후 9:16', '아직 초안이넹'],
#  ['김찬란', '오후 9:57', '아이고 주민번호 그대로 올려버렸네'],
#  ['김하영', '오후 9:57', 'ㅋㅋㅋㅋ '],
#  ['김하영', '오후 9:57', '필요없다~~'],
#  ['김찬란', '오후 9:57', '하긴 쓸데없긴함'],
#  ['김하영', '오후 9:57', '개웃기네'],
#  ['김찬란', '오후 9:59', '기분이 너무안좋으니까 맜있는거라도 먹어야겠다'],
#  ['김하영', '오후 9:59', '난 여친와야 먹어서'],
#  ['김하영', '오후 9:59', '기다리는중'],
#  ['김찬란', '오후 9:59', '엄청 늦ㄱ오네'],
#  ['김찬란', '오후 10:00', '일하고 오는겨'],
#  ['김하영', '오후 10:00', '나 10시~10시 여자친구 2잡'],
#  ['김찬란', '오후 10:00', '와 다들 얄심히 사는구나'],
#  ['김하영', '오후 10:00', '10시반~4시 6시~10시반'],
#  ['김하영', '오후 10:01', '열심히 살아도 모자르다 인생이'],
#  ['김찬란', '오후 10:03', '진짜 얄심히구나 난 아직 취업을 안해서 남들 어떻게 사는지도 잘모르네'],
#  ['김하영', '오후 10:03', '다들 분수에 맞게 사는거지'],
#  ['김찬란', '오후 10:04', '같이 수업듣는 사람 한명이 엄청 성슉하고 어른 같아서 당연히 나보다 훨씬 어른 인줄알았는대'],
#  ['김찬란', '오후 10:04', '또래였름'],
#  ['김하영', '오후 10:04', '그 이상 잘살고싶으면 남들보다 열심히 해야하거'],
#  ['김하영', '오후 10:04', '한두살 많냐??'],
#  ['김찬란', '오후 10:04', '한살 많았음'],
#  ['김하영', '오후 10:05', '그냥 극 I라서 말수없고 내성적인거 아니고??'],
#  ['김찬란', '오후 10:05', 'ㅋㅋㅋㅋㅋ 그런가'],
#  ['김찬란', '오후 10:05', '긍데 알고 보니까 광고업체 사장이더라 '],
#  ['김하영', '오후 10:05', '힘들게 살'],
#  ['김하영', '오후 10:05', '뭐야시발'],
#  ['김찬란', '오후 10:05', '대단함'],
#  ['김하영', '오후 10:05', '금수저인가...?'],
#  ['김하영', '오후 10:05', '자영업 인가??'],
#  ['김찬란', '오후 10:05', '그건 모르는데 '],
#  ['김찬란', '오후 10:06', '수업 듣다가 중도 포기하고 가더라'],
#  ['김하영', '오후 10:06', '뭐 업체도 업체 나름 이지만'],
#  ['김하영', '오후 10:06', '열심히 사는쪽 사람같네'],
#  ['김찬란', '오후 10:06', '큰건 아닌거 닽고'],
#  ['김하영', '오후 10:07', '운이란건 준비된 놈이 가져가는거다 짤랑'],
#  ['김하영', '오후 10:07', '진화해라'],
#  ['김하영', '오후 10:07', '아구몬 마냥'],
#  ['김찬란', '오후 10:07', 'ㅋㅋㅋㅋㅋ'],
#  ['김찬란', '오후 10:07', '슬램덩크 보러 가야지'],
#  ['김하영', '오후 10:07', 'ㅋㅋㅋㅋㅋㅋ '],
#  ['김찬란', '오후 10:07', '아니'],
#  ['김하영', '오후 10:07', '이모티콘'],
#  ['김찬란', '오후 10:07', '넷플 더글로리 보삼'],
#  ['김하영', '오후 10:08', '봄'],
#  ['김찬란', '오후 10:08', '엤날 생각도 나고'],
#  ['김찬란', '오후 10:08', '암튼 그래'],
#  ['김하영', '오후 10:08', '짤랑이 내 고데기 온도좀 체크해줄래?'],
#  ['김찬란', '오후 10:08', '삼겹살 구워주게?'],
#  ['김하영', '오후 10:08', '그거 구워줘?'],
#  ['김찬란', '오후 10:08', '대패삽겹이면 되지 않을까'],
#  ['김찬란', '오후 10:09', '무슨 대화냐'],
#  ['김하영', '오후 10:09', '더글로리 심한거 같진않던데'],
#  ['김하영', '오후 10:09', '더한거 많이 봐서 그런가 어릴때'],
#  ['김찬란', '오후 10:09', '뭘봤기래'],
#  ['김하영', '오후 10:09', '전라도라 그런가'],
#  ['김하영', '오후 10:09', '중3 형들이 수금시키고'],
#  ['김하영', '오후 10:10', '왕따시키고'],
#  ['김찬란', '오후 10:10', '흠'],
#  ['김하영', '오후 10:10', '빵셔틀 맞짱 패싸움'],
#  ['김하영', '오후 10:10', '대가리끼리 일기토'],
#  ['김하영', '오후 10:10', '별에별거'],
#  ['김찬란', '오후 10:10', '나도 시골인데 일진들의 폭력은 항상 있었음'],
#  ['김하영', '오후 10:10', '시골이라 심한듯'],
#  ['김하영', '오후 10:10', '여기 애들이랑 얘기해보면'],
#  ['김하영', '오후 10:11', '안믿음'],
#  ['김찬란', '오후 10:11', '안믿기긴람'],
#  ['김하영', '오후 10:11', '여기 욕하고 주먹질하면 천박하다 그러면서 말싸움하는동네임'],
#  ['김하영', '오후 10:11', '강남이라 그런가'],
#  ['김찬란', '오후 10:12', 'ㅋㅋㅋㅋㅋ 뒷담하고 정치하고 그런거'],
#  ['김하영', '오후 10:12', '아리랑치기는 술취한사람 지갑훔치는거 아니냐??'],
#  ['김찬란', '오후 10:12', '아마 그런의미도 있울걸'],
#  ['김하영', '오후 10:12', '샵검색: #아리랑치기'],
#  ['김하영', '오후 10:12', '와'],
#  ['김하영', '오후 10:13', '국어사전에 있는말이네'],
#  ['김하영', '오후 10:13', '이딴게 사전?'],
#  ['김찬란', '오후 10:13', 'ㅋㅋㅋㅋ'],
#  ['김찬란', '오후 10:14', '아왠지 자꾸 고기 생각이 나더라니'],
#  ['김찬란', '오후 10:14', '먹을려고해ㅛ던 고기를 안먹어 줬네'],
#  ['김하영', '오후 10:14', 'ㅋㅋㅋㅋ '],
#  ['김하영', '오후 10:14', '냉장고에 주무시는중이냐??'],
#  ['김찬란', '오후 10:14', '장도 안봐왔음'],
#  ['김찬란', '오후 10:14', '깜빡함'],
#  ['김하영', '오후 10:18', '움직이기 귀찮다'],
#  ['김하영', '오후 10:18', '움직여라 몸'],
#  ['김찬란', '오후 10:19', '누가 칼들고 협박한다고 생각하면'],
#  ['김찬란', '오후 10:20', '빨리빨리 움직여짐'],
#  ['김찬란', '오후 10:20', '개뀰팁'],
#  ['김하영', '오후 10:20', '안무서우면?'],
#  ['김찬란', '오후 10:20', '그롬 진짜 뒤지는거지'],
#  ['김찬란', '오후 10:20', '칼맞고 '],
#  ['김하영', '오후 10:20', 'ㅋ!ㅋㅋㅋㅋ'],
#  ['김찬란', '오후 10:20', '너뮤 끔직했다'],
#  ['김하영', '오전 10:28', '이모티콘']]

# %%
#닉네임 입력단 
# target_name = str(input())
target_name = '김하영'
print(target_name)  #김하영 입력
# Out:
# 김하영

# %%
# 저장된 모델 불러오기
# from tensorflow.keras.models import load_models
# model= load_models('4_6_DNN 토큰화수정.h5')


#입력된 이름의 '대화내역만' 담기
received_texts= []
for i in get_from_txt('sample.txt'): 
    if i[0] == target_name:
        received_texts.append( i[2] )
        
# 이모티콘, 사진, 샵검색 제거 
clean_received_texts2 = []
for i in received_texts:
    if '샵검색:' not in i: 
        if "이모티콘" not in i:
            if '사진' not in i:
                clean_received_texts2.append(str(i))

#=========== 이쯤에서 답장시간 계산기 구현   =======================
          
          
#텍스트 정제  
clean_received_texts2= [clean_korean_text(i) for i in clean_received_texts2]
clean_received_texts2

# 텍스트 데이터 토큰화
tokenized_test_texts = [tokenizer.encode(text, max_length=max_length, pad_to_max_length=True) for text in clean_received_texts2]
tokenized_test_texts

# 토큰화된 텍스트를 Numpy 배열로 변환
tokenized_test_texts = np.array(tokenized_test_texts)
tokenized_test_texts

# 벡터데이터 변환
x_test = pad_sequences(tokenized_test_texts,padding='post',maxlen=64) 

# 모델을 사용하여 예측 수행
predictions = loaded_model.predict(x_test)
#예측 결과 출력 (긍정: 1, 부정: 0)
print(predictions.squeeze().tolist()) #차원을 축소하고 리스트객체로 변환

cnt0=0;cnt1=0; cnt2=0
for i in predictions.squeeze().tolist():
    if i <= 0.45:
        cnt0+=1
    elif i >= 0.55:
        cnt1+=1
    else :
        cnt2+=1
        
#부정과 긍정문의 갯수
print('부정문과 긍정문의 갯수:',cnt0,cnt1)
print('중립문장의 갯수:',cnt2)

#긍정과 부정의 비율( 긍정문의 수 / 부정문의 수)
print('긍정과 부정의 비율: ',cnt1/cnt0)
#숫자가 1이상이고 높을수록 긍정적이다.
# Out:
# 6/6 [==============================] - 0s 7ms/step
# [0.42015233635902405, 0.15778325498104095, 0.4034382998943329, 0.15830516815185547, 0.2756638824939728, 0.23274767398834229, 0.5671480298042297, 0.25340867042541504, 0.4362293481826782, 0.4002711772918701, 0.6111466884613037, 0.06004936248064041, 0.1837492287158966, 0.1312265843153, 0.2406095564365387, 0.08809877932071686, 0.3380661606788635, 0.17884549498558044, 0.544122040271759, 0.5671480298042297, 0.3253222107887268, 0.34540876746177673, 0.34540876746177673, 0.4286506474018097, 0.5671480298042297, 0.28317803144454956, 0.5671480298042297, 0.11938949674367905, 0.4006653428077698, 0.19541098177433014, 0.12212876230478287, 0.31381163001060486, 0.3801400661468506, 0.3815697431564331, 0.5671480298042297, 0.4159267246723175, 0.4814023971557617, 0.3980425298213959, 0.24305537343025208, 0.3207646906375885, 0.12008189409971237, 0.32288381457328796, 0.5671480298042297, 0.5671480298042297, 0.42395874857902527, 0.4516054093837738, 0.19916307926177979, 0.17710167169570923, 0.3446434736251831, 0.3221398591995239, 0.36690089106559753, 0.4423547089099884, 0.6835919618606567, 0.45752212405204773, 0.07972799986600876, 0.24436530470848083, 0.4788375198841095, 0.5671480298042297, 0.16693392395973206, 0.3681725263595581, 0.3044440746307373, 0.19991397857666016, 0.5671480298042297, 0.13648729026317596, 0.10646538436412811, 0.5727335810661316, 0.4273366630077362, 0.31937259435653687, 0.18155349791049957, 0.5671480298042297, 0.05404098704457283, 0.33300092816352844, 0.5323312282562256, 0.23986676335334778, 0.5671480298042297, 0.1815996766090393, 0.23627199232578278, 0.35293540358543396, 0.5466489195823669, 0.7386532425880432, 0.5671480298042297, 0.2090338170528412, 0.2131897360086441, 0.3723054826259613, 0.10942161083221436, 0.35384246706962585, 0.09760255366563797, 0.45055368542671204, 0.49469926953315735, 0.5671480298042297, 0.05789695307612419, 0.20494894683361053, 0.5323312282562256, 0.5671480298042297, 0.1672353297472, 0.5671480298042297, 0.5056499242782593, 0.20576699078083038, 0.2681855857372284, 0.3581780791282654, 0.458649605512619, 0.13020619750022888, 0.5671480298042297, 0.48770755529403687, 0.20475997030735016, 0.32316821813583374, 0.21003781259059906, 0.5671480298042297, 0.35974955558776855, 0.20553825795650482, 0.22599218785762787, 0.5671480298042297, 0.34924060106277466, 0.6169798374176025, 0.41802501678466797, 0.3524168133735657, 0.15273608267307281, 0.15412674844264984, 0.18172045052051544, 0.39534351229667664, 0.4118862748146057, 0.346030056476593, 0.4683348834514618, 0.5671480298042297, 0.5671480298042297, 0.534299910068512, 0.5671480298042297, 0.5615726709365845, 0.4516054093837738, 0.33542346954345703, 0.6546527147293091, 0.1683412492275238, 0.18384557962417603, 0.6903050541877747, 0.2354642152786255, 0.6377068758010864, 0.3281033933162689, 0.11135663837194443, 0.5609579682350159, 0.06333744525909424, 0.2450834959745407, 0.2972651720046997, 0.5098536014556885, 0.2831845283508301, 0.29847997426986694, 0.25938913226127625, 0.3997848629951477, 0.5671480298042297, 0.5094566345214844, 0.27755048871040344, 0.16885313391685486, 0.24273893237113953, 0.5033950805664062, 0.2808372974395752, 0.38967058062553406, 0.18036015331745148, 0.4271742105484009, 0.35212117433547974, 0.11354750394821167, 0.3229861259460449, 0.27055710554122925, 0.2640545070171356, 0.14100365340709686, 0.33285894989967346, 0.20114409923553467, 0.5538738965988159, 0.4364754557609558, 0.17719222605228424, 0.5671480298042297, 0.3712437152862549, 0.234401136636734, 0.33629289269447327, 0.30994677543640137, 0.5671480298042297]
# 부정문과 긍정문의 갯수: 120 35
# 중립문장의 갯수: 19
# 긍정과 부정의 비율:  0.2916666666666667

# %%
clean_received_texts2
